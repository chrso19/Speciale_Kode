# %%
import figure_module as modules

import os

# %%
naive_folder, MA_folder, seasonal_folder, final_eval_folder = modules.find_paths()

final_eval_folder = os.path.join(final_eval_folder, "With_noise")

print(final_eval_folder)
# Out:
# c:\Users\chris\Documents\Python\Speciale_Kode\Shallow learners\New_Eval\With_noise

# %%
file = "DK1_daily_results_naive.csv"

xpoints = modules.xpoints(naive_folder, file)

# %%
file = "DK1_daily_results_naive.csv"
model = "Naive Persistence"
price_zone = "DK1"
folder = naive_folder

modules.generate_metrics_graph_baseline(file, model, price_zone, xpoints, folder)

# %%
file = "DK2_daily_results_naive.csv"
model = "Naive Persistence"
price_zone = "DK2"
folder = naive_folder

modules.generate_metrics_graph_baseline(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_daily_results_MA.csv"
model = "Moving Average"
price_zone = "DK1"
folder = MA_folder

modules.generate_metrics_graph_baseline(file, model, price_zone, xpoints, folder)

# %%
file = "DK2_daily_results_MA.csv"
model = "Moving Average"
price_zone = "DK2"
folder = MA_folder

modules.generate_metrics_graph_baseline(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_daily_results_seasonal.csv"
model = "Seasonal Naive"
price_zone = "DK1"
folder = seasonal_folder

modules.generate_metrics_graph_baseline(file, model, price_zone, xpoints, folder)

# %%
file = "DK2_daily_results_seasonal.csv"
model = "Seasonal Naive"
price_zone = "DK2"
folder = seasonal_folder

modules.generate_metrics_graph_baseline(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_Lasso_predictions.csv"
model = "Lasso Regression"
price_zone = "DK1"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK2_Lasso_predictions.csv"
model = "Lasso Regression"
price_zone = "DK2"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_SVR_predictions.csv"
model = "Support Vector Regression"
price_zone = "DK1"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK2_SVR_predictions.csv"
model = "Support Vector Regression"
price_zone = "DK2"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_XGBoost_predictions.csv"
model = "XGBoost"
price_zone = "DK1"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK2_XGBoost_predictions.csv"
model = "XGBoost"
price_zone = "DK2"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_LightGBM_predictions.csv"
model = "LightGBM"
price_zone = "DK1"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK2_LightGBM_predictions.csv"
model = "LightGBM"
price_zone = "DK2"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_RF_predictions.csv"
model = "Random Forest"
price_zone = "DK1"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK2_RF_predictions.csv"
model = "Random Forest"
price_zone = "DK2"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_ARIMA_predictions.csv"
model = "ARIMA"
price_zone = "DK1"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

file = "DK2_ARIMA_predictions.csv"
model = "ARIMA"
price_zone = "DK2"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
file = "DK1_ARIMAX_predictions.csv"
model = "ARIMAX"
price_zone = "DK1"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

file = "DK2_ARIMAX_predictions.csv"
model = "ARIMAX"
price_zone = "DK2"
folder = final_eval_folder

modules.generate_metrics_graph(file, model, price_zone, xpoints, folder)

# %%
price_zone = "DK1"

modules.generate_smape_graph_baseline(price_zone, xpoints, naive_folder, MA_folder, seasonal_folder)

# %%
price_zone = "DK2"

modules.generate_smape_graph_baseline(price_zone, xpoints, naive_folder, MA_folder, seasonal_folder)

# %%
price_zone = "DK1"

modules.generate_rmse_graph_baseline(price_zone, xpoints, naive_folder, MA_folder, seasonal_folder)

# %%
price_zone = "DK2"

modules.generate_rmse_graph_baseline(price_zone, xpoints, naive_folder, MA_folder, seasonal_folder)

# %%
price_zone = "DK1"

modules.generate_mae_graph_baseline(price_zone, xpoints, naive_folder, MA_folder, seasonal_folder)

# %%
price_zone = "DK2"

modules.generate_mae_graph_baseline(price_zone, xpoints, naive_folder, MA_folder, seasonal_folder)

# %%
price_zone = "DK1"

modules.generate_smape_graph(price_zone, xpoints, final_eval_folder)

# %%
price_zone = "DK2"

modules.generate_smape_graph(price_zone, xpoints, final_eval_folder)

# %%
price_zone = "DK1"

modules.generate_rmse_graph(price_zone, xpoints, final_eval_folder)

# %%
price_zone = "DK2"

modules.generate_rmse_graph2(price_zone, xpoints, final_eval_folder)

# %%
price_zone = "DK1"

modules.generate_mae_graph(price_zone, xpoints, final_eval_folder)

# %%
price_zone = "DK2"

modules.generate_mae_graph2(price_zone, xpoints, final_eval_folder)

# %%
price_zone = "DK1"

modules.generate_quarterly_smape_graph(price_zone, xpoints, final_eval_folder)

# %%
price_zone = "DK2"

modules.generate_quarterly_smape_graph(price_zone, xpoints, final_eval_folder)

# %%
price_zone = "DK1"

modules.generate_quarterly_smape_graph_baseline(price_zone, xpoints, naive_folder, MA_folder, seasonal_folder)

# %%
price_zone = "DK2"

modules.generate_quarterly_smape_graph_baseline(price_zone, xpoints, naive_folder, MA_folder, seasonal_folder)

# %%
naive_smape_DK1, naive_rmse_DK1, naive_mae_DK1 = modules.baseline_data("DK1_daily_results_naive.csv", naive_folder)
MA_smape_DK1, MA_rmse_DK1, MA_mae_DK1 = modules.baseline_data("DK1_daily_results_MA.csv", MA_folder)
seasonal_smape_DK1, seasonal_rmse_DK1, seasonal_mae_DK1 = modules.baseline_data("DK1_daily_results_seasonal.csv", seasonal_folder)

price_zone = "DK1"

modules.baseline_7_day_smape(naive_smape_DK1, MA_smape_DK1, seasonal_smape_DK1, price_zone)
modules.baseline_7_day_rmse(naive_rmse_DK1, MA_rmse_DK1, seasonal_rmse_DK1, price_zone)
modules.baseline_7_day_mae(naive_mae_DK1, MA_mae_DK1, seasonal_mae_DK1, price_zone)

# %%
naive_smape_DK2, naive_rmse_DK2, naive_mae_DK2 = modules.baseline_data("DK2_daily_results_naive.csv", naive_folder)
MA_smape_DK2, MA_rmse_DK2, MA_mae_DK2 = modules.baseline_data("DK2_daily_results_MA.csv", MA_folder)
seasonal_smape_DK2, seasonal_rmse_DK2, seasonal_mae_DK2 = modules.baseline_data("DK2_daily_results_seasonal.csv", seasonal_folder)

price_zone = "DK2"

modules.baseline_7_day_smape(naive_smape_DK2, MA_smape_DK2, seasonal_smape_DK2, price_zone)
modules.baseline_7_day_rmse(naive_rmse_DK2, MA_rmse_DK2, seasonal_rmse_DK2, price_zone)
modules.baseline_7_day_mae(naive_mae_DK2, MA_mae_DK2, seasonal_mae_DK2, price_zone)

# %%
price_zone = "DK1"

lasso_DK1, svr_DK1, xgb_DK1, lightgbm_DK1, rf_DK1, arima_DK1, arimax_DK1 = modules.read_shallow_results(final_eval_folder, price_zone)

modules.shallow_7_day_smape(lasso_DK1, svr_DK1, xgb_DK1, lightgbm_DK1, rf_DK1, arima_DK1, arimax_DK1, price_zone)

# %%
price_zone = "DK2"

lasso_DK2, svr_DK2, xgb_DK2, lightgbm_DK2, rf_DK2, arima_DK2, arimax_DK2 = modules.read_shallow_results(final_eval_folder, price_zone)

modules.shallow_7_day_smape(lasso_DK2, svr_DK2, xgb_DK2, lightgbm_DK2, rf_DK2, arima_DK2, arimax_DK2, price_zone)

# %%
price_zone = "DK1"

lasso_rmse, lasso_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK1_Lasso_predictions.csv", price_zone)
svr_rmse, svr_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK1_SVR_predictions.csv", price_zone)
xgb_rmse, xgb_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK1_XGBoost_predictions.csv", price_zone)
lightgbm_rmse, lightgbm_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK1_LightGBM_predictions.csv", price_zone)
rf_rmse, rf_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK1_RF_predictions.csv", price_zone)
arima_rmse, arima_mae = modules.make_shallow_7_day_metrics(final_eval_folder, "DK1_ARIMA_predictions.csv", price_zone)
arimax_rmse, arimax_mae = modules.make_shallow_7_day_metrics(final_eval_folder, "DK1_ARIMAX_predictions.csv", price_zone)

modules.shallow_7_day_rmse(lasso_rmse, svr_rmse, xgb_rmse, lightgbm_rmse, rf_rmse, arima_rmse, arimax_rmse, price_zone)
modules.shallow_7_day_mae(lasso_mae, svr_mae, xgb_mae, lightgbm_mae, rf_mae, arima_mae, arimax_mae, price_zone)

# %%
price_zone = "DK2"

lasso_rmse, lasso_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK2_Lasso_predictions.csv", price_zone)
svr_rmse, svr_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK2_SVR_predictions.csv", price_zone)
xgb_rmse, xgb_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK2_XGBoost_predictions.csv", price_zone)
lightgbm_rmse, lightgbm_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK2_LightGBM_predictions.csv", price_zone)
rf_rmse, rf_mae  = modules.make_shallow_7_day_metrics(final_eval_folder, "DK2_RF_predictions.csv", price_zone)
arima_rmse, arima_mae = modules.make_shallow_7_day_metrics(final_eval_folder, "DK2_ARIMA_predictions.csv", price_zone)
arimax_rmse, arimax_mae = modules.make_shallow_7_day_metrics(final_eval_folder, "DK2_ARIMAX_predictions.csv", price_zone)

modules.shallow_7_day_rmse(lasso_rmse, svr_rmse, xgb_rmse, lightgbm_rmse, rf_rmse, arima_rmse, arimax_rmse, price_zone)
modules.shallow_7_day_mae(lasso_mae, svr_mae, xgb_mae, lightgbm_mae, rf_mae, arima_mae, arimax_mae, price_zone)

# %%
import matplotlib.pyplot as plt
import textwrap

xpoints = ["Day 1", "Day 2", "Day 3", "Day 4", "Day 5", "Day 6", "Day 7"]

plt.plot(xpoints, lasso_rmse, label = "Lasso Regression")
plt.plot(xpoints, svr_rmse, label = "Support Vector Regression")
plt.plot(xpoints, xgb_rmse, label = "XGBoost")
plt.plot(xpoints, lightgbm_rmse, label = "LightGBM")
plt.plot(xpoints, rf_rmse, label = "Random Forest")
plt.plot(xpoints, arima_rmse, label = "ARIMA")
plt.xlabel('Prediction Day')
plt.ylabel('RMSE (DKK/MWh)')
plt.title(f'7-Day RMSE (DKK/MWh) Development for Shallow Learners with Noise for {price_zone}')
plt.legend()
plt.savefig(f"shallow_7day_rmse_{price_zone}", bbox_inches='tight', dpi=150)
plt.show()


plt.plot(xpoints, lasso_mae, label = "Lasso Regression")
plt.plot(xpoints, svr_mae, label = "Support Vector Regression")
plt.plot(xpoints, xgb_mae, label = "XGBoost")
plt.plot(xpoints, lightgbm_mae, label = "LightGBM")
plt.plot(xpoints, rf_mae, label = "Random Forest")
plt.plot(xpoints, arima_mae, label = "ARIMA")
plt.xlabel('Prediction Day')
plt.ylabel('MAE (DKK/MWh)')
plt.title(f'7-Day MAE (DKK/MWh) Development for Shallow Learners with Noise for {price_zone}')
plt.legend()
plt.savefig(f"shallow_7day_mae_{price_zone}", bbox_inches='tight', dpi=150)
plt.show()
