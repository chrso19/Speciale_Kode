# %%
# Importing the packages

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Loading and processing the data

# Determining the path to the data
file_dir = os.path.dirname(os.path.realpath('naive_persistence.ipynb'))
python_dir = os.path.dirname(file_dir)
data_folder = os.path.join(python_dir, 'Data')
data_file = os.path.join(data_folder, 'combined_data_cleaned.csv')

# Loading the data
df = pd.read_csv(data_file, decimal = ',')
df_new = df[["TimeUTC", "DKZone", "DKPrice"]]

# Format for the datetime
date_format = '%Y-%m-%d %H:%M:%S'

# Filtering for DK1 price zone
df_DK1 = df_new[df_new['DKZone'] == 'DK1']
df_DK1 = df_DK1.drop('DKZone', axis = 1)
df_DK1.reset_index(drop=True, inplace=True)

# Saving datetime format for DK1
temp_list = []
for i in list(df_DK1["TimeUTC"]):
    n = 19
    j = i[:n]
    k = datetime.strptime(j, date_format)
    temp_list.append(k)
df_DK1.insert(0, "Time", temp_list, True)
df_DK1 = df_DK1.drop("TimeUTC", axis = 1)
df_DK1['DKPrice'] = df_DK1['DKPrice'].astype(float)

# Splitting between initial train and test set for DK1
DK1_train_set = df_DK1.loc[df_DK1['Time'] < pd.Timestamp('2025-01-01')]
DK1_train_set.reset_index(drop=True, inplace=True)
DK1_test_set = df_DK1.loc[df_DK1['Time'] >= pd.Timestamp('2025-01-01')]
DK1_test_set.reset_index(drop=True, inplace=True)

# Printing the shape for training and test date for DK1
print(f"Training data shape (DK1): {DK1_train_set.shape}")
print(f"Test data shape (DK1): {DK1_test_set.shape}")
print(f"Test set fraction (DK1): {len(DK1_test_set)/len(DK1_train_set):.2%}")

# Filtering for DK2 price zone
df_DK2 = df_new[df_new['DKZone'] == 'DK2']
df_DK2 = df_DK2.drop('DKZone', axis = 1)
df_DK2.reset_index(drop=True, inplace=True)

# Saving datetime format for DK2
temp_list = []
for i in list(df_DK2["TimeUTC"]):
    n = 19
    j = i[:n]
    k = datetime.strptime(j, date_format)
    temp_list.append(k)
df_DK2.insert(0, "Time", temp_list, True)
df_DK2 = df_DK2.drop("TimeUTC", axis = 1)
df_DK2['DKPrice'] = df_DK2['DKPrice'].astype(float)

# Splitting between initial train and test set for DK2
DK2_train_set = df_DK2.loc[df_DK1['Time'] < pd.Timestamp('2025-01-01')]
DK2_train_set.reset_index(drop=True, inplace=True)
DK2_test_set = df_DK2.loc[df_DK1['Time'] >= pd.Timestamp('2025-01-01')]
DK2_test_set.reset_index(drop=True, inplace=True)

# Printing the shape for training and test date for DK2
print(f"Training data shape (DK2): {DK2_train_set.shape}")
print(f"Test data shape (DK2): {DK2_test_set.shape}")
print(f"Test set fraction (DK2): {len(DK2_test_set)/len(DK2_train_set):.2%}")
# Out:
# Training data shape (DK1): (78912, 2)
# Test data shape (DK1): (8760, 2)
# Test set fraction (DK1): 11.10%
# Training data shape (DK2): (78912, 2)
# Test data shape (DK2): (8760, 2)
# Test set fraction (DK2): 11.10%

# %%
# Defining the moving average model
def model_MA(L: list):
    average = np.mean(L)
    return average

# %%
def perform_walk_forward_validation_MA(
        data_series, 
        model, 
        training_window = 8760, # 365 days of data - hours of data trained on
        forecast_horizon = 168, # 1 week - hours of data predicted
        average_sequence = 720, # 1 month - hours used for average
        ):
    """
    Walk-forward validation for Moving Average.
    """

    all_predictions = []
    all_actuals = []
    all_fold_rmse = []
    all_fold_mae = []

    # Calculate number of folds
    num_folds = (len(data_series) - training_window - forecast_horizon) // forecast_horizon

    print(f"Total folds: {num_folds}")
    print(f"Training winow: {training_window} hours")
    print(f"Forecast horizon: {forecast_horizon} hours")

    for fold in range(num_folds):
        start = fold * forecast_horizon

        # Check if there is enough data 
        if start + training_window + forecast_horizon > len(data_series):
            break
        
        print(f"Fold {fold + 1}/{num_folds}")

        # Split the data into training and validating data
        train_data = data_series[start: start + training_window]
        val_data = data_series[start + training_window: start + training_window + forecast_horizon]

        # Using the moving average model
        temp_list = list(train_data)
        model_input = temp_list[-average_sequence:]
        predicted_value = model(model_input)
        predictions = np.full(len(val_data), predicted_value)
        actuals = val_data.values

        # Calculate errors
        fold_mse = mean_squared_error(actuals, predictions)
        fold_rmse = np.sqrt(fold_mse)
        fold_mae = mean_absolute_error(actuals, predictions)

        all_fold_rmse.append(fold_rmse)
        all_fold_mae.append(fold_mae)
        all_predictions.extend(predictions)
        all_actuals.extend(actuals)

        print(f"Fold RMSE: {fold_rmse:.2f}, MAE: {fold_mae:.2f}\n")
    
    # Overall metrics
    overall_rmse = np.sqrt(mean_squared_error(all_actuals, all_predictions))
    overall_mae = mean_absolute_error(all_actuals, all_predictions)

    print(f"Overall RMSE: {overall_rmse:.2f}")
    print(f"Overall MAE: {overall_mae:.2f}")
    print(f"Average fold RMSE: {np.mean(all_fold_rmse):.2f} (+/- {np.std(all_fold_rmse):.2f})")
    print(f"Average fold MAE: {np.mean(all_fold_mae):.2f} (+/- {np.std(all_fold_mae):.2f})\n")

    return all_predictions, all_actuals, all_fold_rmse, all_fold_mae

# %%
def plot_walk_forward_results(
        predictions, 
        actuals, 
        title,
        training_window = 8760, # 365 days of data - hours of data trained on
        forecast_horizon = 168, # 1 week - hours of data predicted
        ):
    """
    Plot walk-forward validation results.
    """
    plt.figure(figsize=(15, 6))
    
    # Create x-axis (fold numbers repeated for each prediction in that fold)
    x = []
    fold_num = 0
    for i in range(len(predictions)):
        if i % (forecast_horizon) == 0 and i > 0:
            fold_num += 1
        x.append(fold_num)
    
    plt.plot(actuals, label='Actual', alpha=0.7, linewidth=2)
    plt.plot(predictions, label='Predicted', alpha=0.7, linewidth=2)
    
    # Add vertical lines to separate folds
    for i in range(0, len(predictions), forecast_horizon):
        plt.axvline(x=i, color='gray', linestyle='--', alpha=0.3)
    
    plt.xlabel('Time Step')
    plt.ylabel('Electricity Price (DKK)')
    plt.title(title)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
# Walk-forward validation
model = model_MA

# Walk-forward validation for DK1
data_series_DK1 = DK1_train_set['DKPrice']
predictions_DK1, actuals_DK1, rmse_DK1, mae_DK1 = perform_walk_forward_validation_MA(data_series_DK1, model)

# Walk-forward validation for DK2
data_series_DK2 = DK2_train_set['DKPrice']
predictions_DK2, actuals_DK2, rmse_DK2, mae_DK2 = perform_walk_forward_validation_MA(data_series_DK2, model)
# Out:
# Total folds: 416
# Training winow: 8760 hours
# Forecast horizon: 168 hours
# Fold 1/416
# Fold RMSE: 81.39, MAE: 49.66
#
# Fold 2/416
# Fold RMSE: 49.80, MAE: 32.54
#
# Fold 3/416
# Fold RMSE: 98.97, MAE: 52.69
#
# Fold 4/416
# Fold RMSE: 42.84, MAE: 30.94
#
# Fold 5/416
# Fold RMSE: 30.35, MAE: 19.49
#
# Fold 6/416
# Fold RMSE: 53.66, MAE: 24.13
#
# Fold 7/416
# Fold RMSE: 45.31, MAE: 20.20
#
# Fold 8/416
# Fold RMSE: 111.56, MAE: 67.50
#
# Fold 9/416
# Fold RMSE: 62.57, MAE: 34.33
#
# Fold 10/416
# Fold RMSE: 67.89, MAE: 44.87
#
# Fold 11/416
# Fold RMSE: 54.75, MAE: 29.19
#
# Fold 12/416
# Fold RMSE: 60.34, MAE: 45.99
#
# Fold 13/416
# Fold RMSE: 39.66, MAE: 26.73
#
# Fold 14/416
# Fold RMSE: 78.71, MAE: 45.22
#
# Fold 15/416
# Fold RMSE: 42.59, MAE: 20.67
#
# Fold 16/416
# Fold RMSE: 56.02, MAE: 36.30
#
# Fold 17/416
# Fold RMSE: 98.09, MAE: 75.98
#
# Fold 18/416
# Fold RMSE: 81.71, MAE: 48.81
#
# Fold 19/416
# Fold RMSE: 57.33, MAE: 44.29
#
# Fold 20/416
# Fold RMSE: 35.70, MAE: 25.68
#
# Fold 21/416
# Fold RMSE: 56.00, MAE: 45.90
#
# Fold 22/416
# Fold RMSE: 64.18, MAE: 53.88
#
# Fold 23/416
# Fold RMSE: 70.77, MAE: 55.62
#
# Fold 24/416
# Fold RMSE: 71.62, MAE: 56.78
#
# Fold 25/416
# Fold RMSE: 64.67, MAE: 51.36
#
# Fold 26/416
# Fold RMSE: 71.68, MAE: 59.08
#
# Fold 27/416
# Fold RMSE: 70.89, MAE: 54.55
#
# Fold 28/416
# Fold RMSE: 61.53, MAE: 46.77
#
# Fold 29/416
# Fold RMSE: 43.16, MAE: 36.73
#
# Fold 30/416
# Fold RMSE: 43.44, MAE: 36.41
#
# Fold 31/416
# Fold RMSE: 64.77, MAE: 52.89
#
# Fold 32/416
# Fold RMSE: 63.09, MAE: 50.31
#
# Fold 33/416
# Fold RMSE: 63.56, MAE: 53.05
#
# Fold 34/416
# Fold RMSE: 151.18, MAE: 102.35
#
# Fold 35/416
# Fold RMSE: 81.95, MAE: 53.34
#
# Fold 36/416
# Fold RMSE: 56.45, MAE: 39.05
#
# Fold 37/416
# Fold RMSE: 85.85, MAE: 59.62
#
# Fold 38/416
# Fold RMSE: 59.18, MAE: 47.66
#
# Fold 39/416
# Fold RMSE: 36.12, MAE: 27.28
#
# Fold 40/416
# Fold RMSE: 104.71, MAE: 80.65
#
# Fold 41/416
# Fold RMSE: 77.38, MAE: 56.18
#
# Fold 42/416
# Fold RMSE: 92.43, MAE: 64.17
#
# Fold 43/416
# Fold RMSE: 42.05, MAE: 28.22
#
# Fold 44/416
# Fold RMSE: 152.12, MAE: 105.18
#
# Fold 45/416
# Fold RMSE: 116.89, MAE: 60.84
#
# Fold 46/416
# Fold RMSE: 77.07, MAE: 44.76
#
# Fold 47/416
# Fold RMSE: 114.18, MAE: 82.31
#
# Fold 48/416
# Fold RMSE: 114.96, MAE: 71.93
#
# Fold 49/416
# Fold RMSE: 59.18, MAE: 42.03
#
# Fold 50/416
# Fold RMSE: 93.31, MAE: 69.32
#
# Fold 51/416
# Fold RMSE: 108.27, MAE: 62.32
#
# Fold 52/416
# Fold RMSE: 187.21, MAE: 139.50
#
# Fold 53/416
# Fold RMSE: 88.56, MAE: 62.15
#
# Fold 54/416
# Fold RMSE: 91.28, MAE: 68.99
#
# Fold 55/416
# Fold RMSE: 75.65, MAE: 50.64
#
# Fold 56/416
# Fold RMSE: 81.06, MAE: 64.32
#
# Fold 57/416
# Fold RMSE: 94.98, MAE: 55.68
#
# Fold 58/416
# Fold RMSE: 96.81, MAE: 62.70
#
# Fold 59/416
# Fold RMSE: 82.56, MAE: 48.54
#
# Fold 60/416
# Fold RMSE: 111.81, MAE: 88.15
#
# Fold 61/416
# Fold RMSE: 66.42, MAE: 46.76
#
# Fold 62/416
# Fold RMSE: 84.00, MAE: 58.89
#
# Fold 63/416
# Fold RMSE: 85.41, MAE: 62.51
#
# Fold 64/416
# Fold RMSE: 147.84, MAE: 94.94
#
# Fold 65/416
# Fold RMSE: 54.80, MAE: 34.26
#
# Fold 66/416
# Fold RMSE: 48.21, MAE: 32.86
#
# Fold 67/416
# Fold RMSE: 82.02, MAE: 56.15
#
# Fold 68/416
# Fold RMSE: 59.68, MAE: 45.64
#
# Fold 69/416
# Fold RMSE: 63.50, MAE: 47.38
#
# Fold 70/416
# Fold RMSE: 88.47, MAE: 56.13
#
# Fold 71/416
# Fold RMSE: 107.63, MAE: 85.41
#
# Fold 72/416
# Fold RMSE: 92.04, MAE: 73.08
#
# Fold 73/416
# Fold RMSE: 83.56, MAE: 64.56
#
# Fold 74/416
# Fold RMSE: 103.24, MAE: 82.73
#
# Fold 75/416
# Fold RMSE: 92.37, MAE: 79.34
#
# Fold 76/416
# Fold RMSE: 73.67, MAE: 62.42
#
# Fold 77/416
# Fold RMSE: 92.88, MAE: 57.42
#
# Fold 78/416
# Fold RMSE: 117.04, MAE: 70.09
#
# Fold 79/416
# Fold RMSE: 57.27, MAE: 44.40
#
# Fold 80/416
# Fold RMSE: 67.00, MAE: 53.53
#
# Fold 81/416
# Fold RMSE: 58.13, MAE: 51.32
#
# Fold 82/416
# Fold RMSE: 63.33, MAE: 52.39
#
# Fold 83/416
# Fold RMSE: 66.64, MAE: 51.66
#
# Fold 84/416
# Fold RMSE: 81.81, MAE: 59.96
#
# Fold 85/416
# Fold RMSE: 61.49, MAE: 54.09
#
# Fold 86/416
# Fold RMSE: 73.42, MAE: 61.73
#
# Fold 87/416
# Fold RMSE: 85.54, MAE: 66.42
#
# Fold 88/416
# Fold RMSE: 84.23, MAE: 65.06
#
# Fold 89/416
# Fold RMSE: 90.31, MAE: 69.65
#
# Fold 90/416
# Fold RMSE: 130.88, MAE: 112.69
#
# Fold 91/416
# Fold RMSE: 193.25, MAE: 168.69
#
# Fold 92/416
# Fold RMSE: 168.63, MAE: 129.13
#
# Fold 93/416
# Fold RMSE: 83.78, MAE: 52.10
#
# Fold 94/416
# Fold RMSE: 195.29, MAE: 163.16
#
# Fold 95/416
# Fold RMSE: 102.23, MAE: 66.37
#
# Fold 96/416
# Fold RMSE: 78.58, MAE: 52.25
#
# Fold 97/416
# Fold RMSE: 97.84, MAE: 78.84
#
# Fold 98/416
# Fold RMSE: 85.61, MAE: 67.23
#
# Fold 99/416
# Fold RMSE: 142.10, MAE: 81.28
#
# Fold 100/416
# Fold RMSE: 133.55, MAE: 86.10
#
# Fold 101/416
# Fold RMSE: 99.30, MAE: 75.21
#
# Fold 102/416
# Fold RMSE: 178.20, MAE: 128.64
#
# Fold 103/416
# Fold RMSE: 76.70, MAE: 52.65
#
# Fold 104/416
# Fold RMSE: 113.00, MAE: 59.11
#
# Fold 105/416
# Fold RMSE: 212.53, MAE: 129.77
#
# Fold 106/416
# Fold RMSE: 98.87, MAE: 71.28
#
# Fold 107/416
# Fold RMSE: 113.93, MAE: 73.55
#
# Fold 108/416
# Fold RMSE: 184.27, MAE: 150.34
#
# Fold 109/416
# Fold RMSE: 69.55, MAE: 53.27
#
# Fold 110/416
# Fold RMSE: 68.60, MAE: 45.91
#
# Fold 111/416
# Fold RMSE: 177.06, MAE: 128.09
#
# Fold 112/416
# Fold RMSE: 76.04, MAE: 66.61
#
# Fold 113/416
# Fold RMSE: 54.65, MAE: 47.09
#
# Fold 114/416
# Fold RMSE: 153.37, MAE: 100.84
#
# Fold 115/416
# Fold RMSE: 126.32, MAE: 82.68
#
# Fold 116/416
# Fold RMSE: 137.53, MAE: 87.37
#
# Fold 117/416
# Fold RMSE: 46.08, MAE: 37.28
#
# Fold 118/416
# Fold RMSE: 64.71, MAE: 49.24
#
# Fold 119/416
# Fold RMSE: 71.48, MAE: 60.93
#
# Fold 120/416
# Fold RMSE: 52.67, MAE: 42.78
#
# Fold 121/416
# Fold RMSE: 133.31, MAE: 82.62
#
# Fold 122/416
# Fold RMSE: 82.70, MAE: 55.46
#
# Fold 123/416
# Fold RMSE: 57.78, MAE: 47.31
#
# Fold 124/416
# Fold RMSE: 82.45, MAE: 50.51
#
# Fold 125/416
# Fold RMSE: 56.17, MAE: 41.41
#
# Fold 126/416
# Fold RMSE: 99.12, MAE: 66.81
#
# Fold 127/416
# Fold RMSE: 78.12, MAE: 62.32
#
# Fold 128/416
# Fold RMSE: 133.08, MAE: 105.13
#
# Fold 129/416
# Fold RMSE: 74.48, MAE: 56.88
#
# Fold 130/416
# Fold RMSE: 70.30, MAE: 47.39
#
# Fold 131/416
# Fold RMSE: 67.23, MAE: 48.91
#
# Fold 132/416
# Fold RMSE: 79.27, MAE: 61.74
#
# Fold 133/416
# Fold RMSE: 72.73, MAE: 57.32
#
# Fold 134/416
# Fold RMSE: 91.18, MAE: 65.28
#
# Fold 135/416
# Fold RMSE: 73.49, MAE: 51.87
#
# Fold 136/416
# Fold RMSE: 38.35, MAE: 27.41
#
# Fold 137/416
# Fold RMSE: 153.93, MAE: 107.74
#
# Fold 138/416
# Fold RMSE: 72.90, MAE: 59.64
#
# Fold 139/416
# Fold RMSE: 82.84, MAE: 60.88
#
# Fold 140/416
# Fold RMSE: 60.60, MAE: 52.22
#
# Fold 141/416
# Fold RMSE: 60.62, MAE: 46.95
#
# Fold 142/416
# Fold RMSE: 96.18, MAE: 74.31
#
# Fold 143/416
# Fold RMSE: 77.09, MAE: 63.48
#
# Fold 144/416
# Fold RMSE: 80.72, MAE: 65.29
#
# Fold 145/416
# Fold RMSE: 77.57, MAE: 59.00
#
# Fold 146/416
# Fold RMSE: 113.55, MAE: 86.61
#
# Fold 147/416
# Fold RMSE: 76.18, MAE: 61.51
#
# Fold 148/416
# Fold RMSE: 92.12, MAE: 70.37
#
# Fold 149/416
# Fold RMSE: 87.86, MAE: 68.77
#
# Fold 150/416
# Fold RMSE: 60.07, MAE: 46.04
#
# Fold 151/416
# Fold RMSE: 83.23, MAE: 59.28
#
# Fold 152/416
# Fold RMSE: 79.57, MAE: 57.67
#
# Fold 153/416
# Fold RMSE: 71.92, MAE: 52.44
#
# Fold 154/416
# Fold RMSE: 178.21, MAE: 124.31
#
# Fold 155/416
# Fold RMSE: 83.60, MAE: 58.52
#
# Fold 156/416
# Fold RMSE: 46.20, MAE: 28.86
#
# Fold 157/416
# Fold RMSE: 74.95, MAE: 51.10
#
# Fold 158/416
# Fold RMSE: 69.28, MAE: 45.54
#
# Fold 159/416
# Fold RMSE: 76.45, MAE: 66.55
#
# Fold 160/416
# Fold RMSE: 62.04, MAE: 59.78
#
# Fold 161/416
# Fold RMSE: 64.15, MAE: 55.36
#
# Fold 162/416
# Fold RMSE: 100.32, MAE: 81.83
#
# Fold 163/416
# Fold RMSE: 109.30, MAE: 99.86
#
# Fold 164/416
# Fold RMSE: 97.52, MAE: 90.02
#
# Fold 165/416
# Fold RMSE: 120.94, MAE: 106.62
#
# Fold 166/416
# Fold RMSE: 130.01, MAE: 113.03
#
# Fold 167/416
# Fold RMSE: 97.30, MAE: 84.93
#
# Fold 168/416
# Fold RMSE: 92.50, MAE: 82.55
#
# Fold 169/416
# Fold RMSE: 72.89, MAE: 61.48
#
# Fold 170/416
# Fold RMSE: 101.67, MAE: 90.12
#
# Fold 171/416
# Fold RMSE: 84.31, MAE: 70.41
#
# Fold 172/416
# Fold RMSE: 111.94, MAE: 87.22
#
# Fold 173/416
# Fold RMSE: 74.22, MAE: 60.67
#
# Fold 174/416
# Fold RMSE: 75.28, MAE: 62.68
#
# Fold 175/416
# Fold RMSE: 62.24, MAE: 53.93
#
# Fold 176/416
# Fold RMSE: 65.91, MAE: 50.81
#
# Fold 177/416
# Fold RMSE: 75.99, MAE: 55.21
#
# Fold 178/416
# Fold RMSE: 93.45, MAE: 71.15
#
# Fold 179/416
# Fold RMSE: 98.40, MAE: 77.44
#
# Fold 180/416
# Fold RMSE: 96.75, MAE: 78.81
#
# Fold 181/416
# Fold RMSE: 117.12, MAE: 95.83
#
# Fold 182/416
# Fold RMSE: 106.51, MAE: 83.25
#
# Fold 183/416
# Fold RMSE: 95.62, MAE: 78.39
#
# Fold 184/416
# Fold RMSE: 181.41, MAE: 151.45
#
# Fold 185/416
# Fold RMSE: 116.99, MAE: 105.79
#
# Fold 186/416
# Fold RMSE: 74.40, MAE: 59.99
#
# Fold 187/416
# Fold RMSE: 133.67, MAE: 112.65
#
# Fold 188/416
# Fold RMSE: 84.31, MAE: 67.94
#
# Fold 189/416
# Fold RMSE: 80.06, MAE: 63.81
#
# Fold 190/416
# Fold RMSE: 82.09, MAE: 63.00
#
# Fold 191/416
# Fold RMSE: 133.30, MAE: 104.09
#
# Fold 192/416
# Fold RMSE: 116.83, MAE: 86.59
#
# Fold 193/416
# Fold RMSE: 101.91, MAE: 79.05
#
# Fold 194/416
# Fold RMSE: 207.05, MAE: 132.37
#
# Fold 195/416
# Fold RMSE: 165.25, MAE: 112.62
#
# Fold 196/416
# Fold RMSE: 185.15, MAE: 158.00
#
# Fold 197/416
# Fold RMSE: 159.96, MAE: 132.03
#
# Fold 198/416
# Fold RMSE: 118.14, MAE: 97.80
#
# Fold 199/416
# Fold RMSE: 110.64, MAE: 99.25
#
# Fold 200/416
# Fold RMSE: 122.35, MAE: 109.93
#
# Fold 201/416
# Fold RMSE: 150.40, MAE: 143.92
#
# Fold 202/416
# Fold RMSE: 153.03, MAE: 134.86
#
# Fold 203/416
# Fold RMSE: 165.73, MAE: 160.02
#
# Fold 204/416
# Fold RMSE: 207.45, MAE: 178.86
#
# Fold 205/416
# Fold RMSE: 235.32, MAE: 190.83
#
# Fold 206/416
# Fold RMSE: 216.43, MAE: 165.57
#
# Fold 207/416
# Fold RMSE: 113.31, MAE: 99.57
#
# Fold 208/416
# Fold RMSE: 140.41, MAE: 127.87
#
# Fold 209/416
# Fold RMSE: 189.04, MAE: 147.23
#
# Fold 210/416
# Fold RMSE: 205.30, MAE: 153.85
#
# Fold 211/416
# Fold RMSE: 185.83, MAE: 137.65
#
# Fold 212/416
# Fold RMSE: 108.75, MAE: 84.70
#
# Fold 213/416
# Fold RMSE: 118.41, MAE: 95.64
#
# Fold 214/416
# Fold RMSE: 76.41, MAE: 63.81
#
# Fold 215/416
# Fold RMSE: 195.66, MAE: 147.17
#
# Fold 216/416
# Fold RMSE: 67.88, MAE: 59.57
#
# Fold 217/416
# Fold RMSE: 132.28, MAE: 118.48
#
# Fold 218/416
# Fold RMSE: 75.33, MAE: 61.77
#
# Fold 219/416
# Fold RMSE: 152.88, MAE: 117.96
#
# Fold 220/416
# Fold RMSE: 164.11, MAE: 125.87
#
# Fold 221/416
# Fold RMSE: 121.29, MAE: 95.96
#
# Fold 222/416
# Fold RMSE: 162.23, MAE: 114.25
#
# Fold 223/416
# Fold RMSE: 210.71, MAE: 152.29
#
# Fold 224/416
# Fold RMSE: 167.21, MAE: 121.18
#
# Fold 225/416
# Fold RMSE: 174.39, MAE: 132.36
#
# Fold 226/416
# Fold RMSE: 149.03, MAE: 117.02
#
# Fold 227/416
# Fold RMSE: 157.54, MAE: 116.20
#
# Fold 228/416
# Fold RMSE: 194.69, MAE: 142.96
#
# Fold 229/416
# Fold RMSE: 173.24, MAE: 136.83
#
# Fold 230/416
# Fold RMSE: 220.42, MAE: 175.51
#
# Fold 231/416
# Fold RMSE: 137.42, MAE: 102.85
#
# Fold 232/416
# Fold RMSE: 148.43, MAE: 122.75
#
# Fold 233/416
# Fold RMSE: 240.14, MAE: 185.13
#
# Fold 234/416
# Fold RMSE: 207.14, MAE: 174.22
#
# Fold 235/416
# Fold RMSE: 168.61, MAE: 142.72
#
# Fold 236/416
# Fold RMSE: 172.39, MAE: 130.55
#
# Fold 237/416
# Fold RMSE: 106.19, MAE: 89.32
#
# Fold 238/416
# Fold RMSE: 196.80, MAE: 151.52
#
# Fold 239/416
# Fold RMSE: 209.41, MAE: 158.50
#
# Fold 240/416
# Fold RMSE: 194.08, MAE: 155.24
#
# Fold 241/416
# Fold RMSE: 260.70, MAE: 197.23
#
# Fold 242/416
# Fold RMSE: 166.09, MAE: 123.59
#
# Fold 243/416
# Fold RMSE: 140.58, MAE: 107.58
#
# Fold 244/416
# Fold RMSE: 249.11, MAE: 200.39
#
# Fold 245/416
# Fold RMSE: 326.13, MAE: 276.56
#
# Fold 246/416
# Fold RMSE: 402.05, MAE: 333.40
#
# Fold 247/416
# Fold RMSE: 311.70, MAE: 250.95
#
# Fold 248/416
# Fold RMSE: 290.17, MAE: 232.89
#
# Fold 249/416
# Fold RMSE: 738.13, MAE: 596.95
#
# Fold 250/416
# Fold RMSE: 403.36, MAE: 331.66
#
# Fold 251/416
# Fold RMSE: 514.07, MAE: 439.60
#
# Fold 252/416
# Fold RMSE: 459.36, MAE: 394.19
#
# Fold 253/416
# Fold RMSE: 478.45, MAE: 411.85
#
# Fold 254/416
# Fold RMSE: 521.02, MAE: 448.89
#
# Fold 255/416
# Fold RMSE: 604.81, MAE: 452.98
#
# Fold 256/416
# Fold RMSE: 551.23, MAE: 364.12
#
# Fold 257/416
# Fold RMSE: 658.50, MAE: 481.59
#
# Fold 258/416
# Fold RMSE: 702.02, MAE: 511.17
#
# Fold 259/416
# Fold RMSE: 621.68, MAE: 480.39
#
# Fold 260/416
# Fold RMSE: 1313.80, MAE: 1018.14
#
# Fold 261/416
# Fold RMSE: 725.10, MAE: 585.25
#
# Fold 262/416
# Fold RMSE: 710.11, MAE: 620.88
#
# Fold 263/416
# Fold RMSE: 675.68, MAE: 544.67
#
# Fold 264/416
# Fold RMSE: 578.48, MAE: 459.71
#
# Fold 265/416
# Fold RMSE: 428.30, MAE: 289.11
#
# Fold 266/416
# Fold RMSE: 494.82, MAE: 387.07
#
# Fold 267/416
# Fold RMSE: 433.64, MAE: 305.19
#
# Fold 268/416
# Fold RMSE: 233.20, MAE: 147.77
#
# Fold 269/416
# Fold RMSE: 352.06, MAE: 241.38
#
# Fold 270/416
# Fold RMSE: 1307.39, MAE: 1151.60
#
# Fold 271/416
# Fold RMSE: 1789.87, MAE: 1549.27
#
# Fold 272/416
# Fold RMSE: 586.16, MAE: 456.30
#
# Fold 273/416
# Fold RMSE: 640.63, MAE: 459.92
#
# Fold 274/416
# Fold RMSE: 527.95, MAE: 410.12
#
# Fold 275/416
# Fold RMSE: 911.60, MAE: 808.11
#
# Fold 276/416
# Fold RMSE: 587.01, MAE: 442.34
#
# Fold 277/416
# Fold RMSE: 437.42, MAE: 337.58
#
# Fold 278/416
# Fold RMSE: 543.51, MAE: 470.51
#
# Fold 279/416
# Fold RMSE: 453.41, MAE: 399.13
#
# Fold 280/416
# Fold RMSE: 382.03, MAE: 272.70
#
# Fold 281/416
# Fold RMSE: 397.37, MAE: 283.10
#
# Fold 282/416
# Fold RMSE: 741.62, MAE: 583.13
#
# Fold 283/416
# Fold RMSE: 496.69, MAE: 342.53
#
# Fold 284/416
# Fold RMSE: 361.38, MAE: 248.61
#
# Fold 285/416
# Fold RMSE: 514.77, MAE: 392.33
#
# Fold 286/416
# Fold RMSE: 950.99, MAE: 793.15
#
# Fold 287/416
# Fold RMSE: 999.71, MAE: 879.34
#
# Fold 288/416
# Fold RMSE: 542.14, MAE: 404.74
#
# Fold 289/416
# Fold RMSE: 995.39, MAE: 869.99
#
# Fold 290/416
# Fold RMSE: 1020.69, MAE: 830.22
#
# Fold 291/416
# Fold RMSE: 992.53, MAE: 860.17
#
# Fold 292/416
# Fold RMSE: 888.52, MAE: 741.47
#
# Fold 293/416
# Fold RMSE: 825.52, MAE: 656.35
#
# Fold 294/416
# Fold RMSE: 1393.94, MAE: 1230.05
#
# Fold 295/416
# Fold RMSE: 1812.47, MAE: 1616.61
#
# Fold 296/416
# Fold RMSE: 1496.38, MAE: 1282.48
#
# Fold 297/416
# Fold RMSE: 1243.45, MAE: 964.31
#
# Fold 298/416
# Fold RMSE: 1188.99, MAE: 918.62
#
# Fold 299/416
# Fold RMSE: 1812.51, MAE: 1479.13
#
# Fold 300/416
# Fold RMSE: 983.53, MAE: 791.20
#
# Fold 301/416
# Fold RMSE: 1931.68, MAE: 1815.24
#
# Fold 302/416
# Fold RMSE: 961.75, MAE: 772.66
#
# Fold 303/416
# Fold RMSE: 678.53, MAE: 606.53
#
# Fold 304/416
# Fold RMSE: 746.89, MAE: 711.34
#
# Fold 305/416
# Fold RMSE: 507.26, MAE: 445.81
#
# Fold 306/416
# Fold RMSE: 672.81, MAE: 621.28
#
# Fold 307/416
# Fold RMSE: 457.47, MAE: 386.86
#
# Fold 308/416
# Fold RMSE: 994.24, MAE: 864.86
#
# Fold 309/416
# Fold RMSE: 1581.42, MAE: 1324.75
#
# Fold 310/416
# Fold RMSE: 1459.67, MAE: 1305.27
#
# Fold 311/416
# Fold RMSE: 1549.85, MAE: 1340.94
#
# Fold 312/416
# Fold RMSE: 792.68, MAE: 710.40
#
# Fold 313/416
# Fold RMSE: 1832.34, MAE: 1793.97
#
# Fold 314/416
# Fold RMSE: 1358.53, MAE: 1282.13
#
# Fold 315/416
# Fold RMSE: 890.99, MAE: 824.16
#
# Fold 316/416
# Fold RMSE: 486.37, MAE: 377.40
#
# Fold 317/416
# Fold RMSE: 593.91, MAE: 521.96
#
# Fold 318/416
# Fold RMSE: 211.39, MAE: 140.33
#
# Fold 319/416
# Fold RMSE: 323.18, MAE: 261.49
#
# Fold 320/416
# Fold RMSE: 285.97, MAE: 228.63
#
# Fold 321/416
# Fold RMSE: 332.90, MAE: 280.64
#
# Fold 322/416
# Fold RMSE: 265.14, MAE: 212.57
#
# Fold 323/416
# Fold RMSE: 189.07, MAE: 152.32
#
# Fold 324/416
# Fold RMSE: 347.09, MAE: 263.66
#
# Fold 325/416
# Fold RMSE: 283.87, MAE: 216.24
#
# Fold 326/416
# Fold RMSE: 336.55, MAE: 249.25
#
# Fold 327/416
# Fold RMSE: 293.29, MAE: 235.42
#
# Fold 328/416
# Fold RMSE: 322.08, MAE: 249.06
#
# Fold 329/416
# Fold RMSE: 234.27, MAE: 164.76
#
# Fold 330/416
# Fold RMSE: 217.02, MAE: 148.36
#
# Fold 331/416
# Fold RMSE: 244.90, MAE: 173.54
#
# Fold 332/416
# Fold RMSE: 191.06, MAE: 134.43
#
# Fold 333/416
# Fold RMSE: 295.52, MAE: 222.19
#
# Fold 334/416
# Fold RMSE: 333.51, MAE: 256.42
#
# Fold 335/416
# Fold RMSE: 399.51, MAE: 254.04
#
# Fold 336/416
# Fold RMSE: 255.72, MAE: 183.11
#
# Fold 337/416
# Fold RMSE: 342.66, MAE: 272.68
#
# Fold 338/416
# Fold RMSE: 364.46, MAE: 318.16
#
# Fold 339/416
# Fold RMSE: 279.63, MAE: 216.97
#
# Fold 340/416
# Fold RMSE: 653.99, MAE: 409.55
#
# Fold 341/416
# Fold RMSE: 249.82, MAE: 199.91
#
# Fold 342/416
# Fold RMSE: 422.96, MAE: 341.99
#
# Fold 343/416
# Fold RMSE: 256.60, MAE: 208.16
#
# Fold 344/416
# Fold RMSE: 226.97, MAE: 178.68
#
# Fold 345/416
# Fold RMSE: 389.58, MAE: 339.28
#
# Fold 346/416
# Fold RMSE: 353.35, MAE: 314.48
#
# Fold 347/416
# Fold RMSE: 502.63, MAE: 420.80
#
# Fold 348/416
# Fold RMSE: 284.13, MAE: 233.06
#
# Fold 349/416
# Fold RMSE: 255.58, MAE: 173.46
#
# Fold 350/416
# Fold RMSE: 442.21, MAE: 227.86
#
# Fold 351/416
# Fold RMSE: 602.70, MAE: 508.49
#
# Fold 352/416
# Fold RMSE: 503.28, MAE: 372.11
#
# Fold 353/416
# Fold RMSE: 534.95, MAE: 471.36
#
# Fold 354/416
# Fold RMSE: 422.55, MAE: 370.81
#
# Fold 355/416
# Fold RMSE: 404.92, MAE: 348.26
#
# Fold 356/416
# Fold RMSE: 321.06, MAE: 240.09
#
# Fold 357/416
# Fold RMSE: 258.08, MAE: 192.21
#
# Fold 358/416
# Fold RMSE: 272.46, MAE: 225.60
#
# Fold 359/416
# Fold RMSE: 324.06, MAE: 280.00
#
# Fold 360/416
# Fold RMSE: 279.73, MAE: 224.53
#
# Fold 361/416
# Fold RMSE: 501.81, MAE: 388.83
#
# Fold 362/416
# Fold RMSE: 223.85, MAE: 175.66
#
# Fold 363/416
# Fold RMSE: 228.59, MAE: 179.72
#
# Fold 364/416
# Fold RMSE: 447.75, MAE: 421.77
#
# Fold 365/416
# Fold RMSE: 520.59, MAE: 486.74
#
# Fold 366/416
# Fold RMSE: 277.48, MAE: 227.19
#
# Fold 367/416
# Fold RMSE: 358.65, MAE: 330.81
#
# Fold 368/416
# Fold RMSE: 242.78, MAE: 193.78
#
# Fold 369/416
# Fold RMSE: 176.21, MAE: 127.61
#
# Fold 370/416
# Fold RMSE: 142.09, MAE: 126.44
#
# Fold 371/416
# Fold RMSE: 279.47, MAE: 221.36
#
# Fold 372/416
# Fold RMSE: 84.76, MAE: 64.10
#
# Fold 373/416
# Fold RMSE: 137.32, MAE: 98.49
#
# Fold 374/416
# Fold RMSE: 108.12, MAE: 77.09
#
# Fold 375/416
# Fold RMSE: 132.91, MAE: 93.94
#
# Fold 376/416
# Fold RMSE: 168.34, MAE: 119.18
#
# Fold 377/416
# Fold RMSE: 181.09, MAE: 123.94
#
# Fold 378/416
# Fold RMSE: 218.43, MAE: 159.12
#
# Fold 379/416
# Fold RMSE: 160.39, MAE: 122.50
#
# Fold 380/416
# Fold RMSE: 278.43, MAE: 226.56
#
# Fold 381/416
# Fold RMSE: 339.66, MAE: 270.26
#
# Fold 382/416
# Fold RMSE: 313.80, MAE: 265.88
#
# Fold 383/416
# Fold RMSE: 277.61, MAE: 224.61
#
# Fold 384/416
# Fold RMSE: 302.56, MAE: 265.13
#
# Fold 385/416
# Fold RMSE: 335.50, MAE: 304.42
#
# Fold 386/416
# Fold RMSE: 308.79, MAE: 265.14
#
# Fold 387/416
# Fold RMSE: 303.79, MAE: 257.18
#
# Fold 388/416
# Fold RMSE: 312.00, MAE: 254.97
#
# Fold 389/416
# Fold RMSE: 297.90, MAE: 241.94
#
# Fold 390/416
# Fold RMSE: 341.01, MAE: 282.30
#
# Fold 391/416
# Fold RMSE: 329.49, MAE: 272.75
#
# Fold 392/416
# Fold RMSE: 312.95, MAE: 268.58
#
# Fold 393/416
# Fold RMSE: 344.40, MAE: 287.26
#
# Fold 394/416
# Fold RMSE: 325.35, MAE: 258.84
#
# Fold 395/416
# Fold RMSE: 284.46, MAE: 238.36
#
# Fold 396/416
# Fold RMSE: 321.87, MAE: 273.06
#
# Fold 397/416
# Fold RMSE: 360.23, MAE: 298.50
#
# Fold 398/416
# Fold RMSE: 428.62, MAE: 346.42
#
# Fold 399/416
# Fold RMSE: 345.85, MAE: 291.36
#
# Fold 400/416
# Fold RMSE: 425.18, MAE: 344.50
#
# Fold 401/416
# Fold RMSE: 440.51, MAE: 322.80
#
# Fold 402/416
# Fold RMSE: 347.11, MAE: 272.56
#
# Fold 403/416
# Fold RMSE: 285.14, MAE: 221.02
#
# Fold 404/416
# Fold RMSE: 376.58, MAE: 288.25
#
# Fold 405/416
# Fold RMSE: 328.56, MAE: 271.47
#
# Fold 406/416
# Fold RMSE: 247.84, MAE: 191.22
#
# Fold 407/416
# Fold RMSE: 367.07, MAE: 295.98
#
# Fold 408/416
# Fold RMSE: 360.83, MAE: 292.21
#
# Fold 409/416
# Fold RMSE: 411.91, MAE: 340.49
#
# Fold 410/416
# Fold RMSE: 657.60, MAE: 399.62
#
# Fold 411/416
# Fold RMSE: 405.92, MAE: 317.88
#
# Fold 412/416
# Fold RMSE: 359.15, MAE: 290.67
#
# Fold 413/416
# Fold RMSE: 453.16, MAE: 380.71
#
# Fold 414/416
# Fold RMSE: 401.87, MAE: 293.24
#
# Fold 415/416
# Fold RMSE: 1298.74, MAE: 745.19
#
# Fold 416/416
# Fold RMSE: 556.31, MAE: 523.95
#
# Overall RMSE: 431.23
# Overall MAE: 227.47
# Average fold RMSE: 282.35 (+/- 325.94)
# Average fold MAE: 227.47 (+/- 281.90)
#
# Total folds: 416
# Training winow: 8760 hours
# Forecast horizon: 168 hours
# Fold 1/416
# Fold RMSE: 91.96, MAE: 59.61
#
# Fold 2/416
# Fold RMSE: 57.13, MAE: 34.26
#
# Fold 3/416
# Fold RMSE: 117.90, MAE: 53.35
#
# Fold 4/416
# Fold RMSE: 76.19, MAE: 39.29
#
# Fold 5/416
# Fold RMSE: 60.43, MAE: 48.30
#
# Fold 6/416
# Fold RMSE: 84.46, MAE: 55.72
#
# Fold 7/416
# Fold RMSE: 55.61, MAE: 42.14
#
# Fold 8/416
# Fold RMSE: 108.24, MAE: 76.61
#
# Fold 9/416
# Fold RMSE: 75.03, MAE: 50.24
#
# Fold 10/416
# Fold RMSE: 58.91, MAE: 35.23
#
# Fold 11/416
# Fold RMSE: 56.67, MAE: 32.25
#
# Fold 12/416
# Fold RMSE: 58.45, MAE: 40.11
#
# Fold 13/416
# Fold RMSE: 41.58, MAE: 28.37
#
# Fold 14/416
# Fold RMSE: 55.06, MAE: 39.74
#
# Fold 15/416
# Fold RMSE: 43.46, MAE: 26.03
#
# Fold 16/416
# Fold RMSE: 51.46, MAE: 31.13
#
# Fold 17/416
# Fold RMSE: 89.16, MAE: 68.07
#
# Fold 18/416
# Fold RMSE: 82.13, MAE: 43.49
#
# Fold 19/416
# Fold RMSE: 53.81, MAE: 40.63
#
# Fold 20/416
# Fold RMSE: 33.02, MAE: 25.14
#
# Fold 21/416
# Fold RMSE: 54.98, MAE: 46.43
#
# Fold 22/416
# Fold RMSE: 61.39, MAE: 52.33
#
# Fold 23/416
# Fold RMSE: 66.56, MAE: 53.45
#
# Fold 24/416
# Fold RMSE: 58.19, MAE: 47.35
#
# Fold 25/416
# Fold RMSE: 65.90, MAE: 54.69
#
# Fold 26/416
# Fold RMSE: 64.47, MAE: 54.56
#
# Fold 27/416
# Fold RMSE: 59.98, MAE: 47.25
#
# Fold 28/416
# Fold RMSE: 56.61, MAE: 41.66
#
# Fold 29/416
# Fold RMSE: 42.79, MAE: 37.37
#
# Fold 30/416
# Fold RMSE: 42.30, MAE: 36.08
#
# Fold 31/416
# Fold RMSE: 54.24, MAE: 48.63
#
# Fold 32/416
# Fold RMSE: 59.61, MAE: 48.37
#
# Fold 33/416
# Fold RMSE: 62.85, MAE: 52.32
#
# Fold 34/416
# Fold RMSE: 138.38, MAE: 87.84
#
# Fold 35/416
# Fold RMSE: 85.54, MAE: 58.69
#
# Fold 36/416
# Fold RMSE: 87.33, MAE: 60.08
#
# Fold 37/416
# Fold RMSE: 54.09, MAE: 45.00
#
# Fold 38/416
# Fold RMSE: 57.82, MAE: 49.67
#
# Fold 39/416
# Fold RMSE: 55.94, MAE: 48.24
#
# Fold 40/416
# Fold RMSE: 111.44, MAE: 90.10
#
# Fold 41/416
# Fold RMSE: 81.79, MAE: 66.23
#
# Fold 42/416
# Fold RMSE: 99.24, MAE: 75.06
#
# Fold 43/416
# Fold RMSE: 66.53, MAE: 56.62
#
# Fold 44/416
# Fold RMSE: 139.18, MAE: 99.26
#
# Fold 45/416
# Fold RMSE: 120.15, MAE: 75.70
#
# Fold 46/416
# Fold RMSE: 82.51, MAE: 56.91
#
# Fold 47/416
# Fold RMSE: 112.78, MAE: 84.21
#
# Fold 48/416
# Fold RMSE: 119.13, MAE: 76.87
#
# Fold 49/416
# Fold RMSE: 67.89, MAE: 53.29
#
# Fold 50/416
# Fold RMSE: 93.68, MAE: 71.42
#
# Fold 51/416
# Fold RMSE: 118.54, MAE: 77.65
#
# Fold 52/416
# Fold RMSE: 185.06, MAE: 135.67
#
# Fold 53/416
# Fold RMSE: 75.41, MAE: 50.97
#
# Fold 54/416
# Fold RMSE: 83.55, MAE: 58.94
#
# Fold 55/416
# Fold RMSE: 71.74, MAE: 44.72
#
# Fold 56/416
# Fold RMSE: 89.59, MAE: 68.12
#
# Fold 57/416
# Fold RMSE: 98.55, MAE: 58.99
#
# Fold 58/416
# Fold RMSE: 120.58, MAE: 80.15
#
# Fold 59/416
# Fold RMSE: 70.11, MAE: 46.77
#
# Fold 60/416
# Fold RMSE: 102.26, MAE: 76.20
#
# Fold 61/416
# Fold RMSE: 266.16, MAE: 122.93
#
# Fold 62/416
# Fold RMSE: 65.45, MAE: 44.86
#
# Fold 63/416
# Fold RMSE: 81.75, MAE: 59.95
#
# Fold 64/416
# Fold RMSE: 138.96, MAE: 88.21
#
# Fold 65/416
# Fold RMSE: 55.20, MAE: 36.98
#
# Fold 66/416
# Fold RMSE: 61.37, MAE: 44.58
#
# Fold 67/416
# Fold RMSE: 88.47, MAE: 58.19
#
# Fold 68/416
# Fold RMSE: 52.06, MAE: 37.80
#
# Fold 69/416
# Fold RMSE: 63.88, MAE: 48.09
#
# Fold 70/416
# Fold RMSE: 108.78, MAE: 66.98
#
# Fold 71/416
# Fold RMSE: 106.61, MAE: 83.89
#
# Fold 72/416
# Fold RMSE: 212.04, MAE: 118.32
#
# Fold 73/416
# Fold RMSE: 137.50, MAE: 89.69
#
# Fold 74/416
# Fold RMSE: 91.44, MAE: 67.71
#
# Fold 75/416
# Fold RMSE: 74.59, MAE: 60.22
#
# Fold 76/416
# Fold RMSE: 244.02, MAE: 113.88
#
# Fold 77/416
# Fold RMSE: 73.05, MAE: 46.94
#
# Fold 78/416
# Fold RMSE: 114.69, MAE: 68.23
#
# Fold 79/416
# Fold RMSE: 43.27, MAE: 33.72
#
# Fold 80/416
# Fold RMSE: 38.09, MAE: 30.49
#
# Fold 81/416
# Fold RMSE: 47.33, MAE: 41.47
#
# Fold 82/416
# Fold RMSE: 79.56, MAE: 55.49
#
# Fold 83/416
# Fold RMSE: 89.35, MAE: 62.92
#
# Fold 84/416
# Fold RMSE: 81.54, MAE: 62.76
#
# Fold 85/416
# Fold RMSE: 58.94, MAE: 53.35
#
# Fold 86/416
# Fold RMSE: 72.64, MAE: 63.31
#
# Fold 87/416
# Fold RMSE: 82.14, MAE: 64.39
#
# Fold 88/416
# Fold RMSE: 78.01, MAE: 60.60
#
# Fold 89/416
# Fold RMSE: 72.65, MAE: 53.73
#
# Fold 90/416
# Fold RMSE: 119.80, MAE: 97.51
#
# Fold 91/416
# Fold RMSE: 188.03, MAE: 165.21
#
# Fold 92/416
# Fold RMSE: 141.54, MAE: 109.92
#
# Fold 93/416
# Fold RMSE: 129.95, MAE: 95.84
#
# Fold 94/416
# Fold RMSE: 186.21, MAE: 153.10
#
# Fold 95/416
# Fold RMSE: 115.67, MAE: 85.10
#
# Fold 96/416
# Fold RMSE: 91.10, MAE: 71.49
#
# Fold 97/416
# Fold RMSE: 91.20, MAE: 79.03
#
# Fold 98/416
# Fold RMSE: 86.58, MAE: 73.01
#
# Fold 99/416
# Fold RMSE: 147.17, MAE: 87.94
#
# Fold 100/416
# Fold RMSE: 132.16, MAE: 88.81
#
# Fold 101/416
# Fold RMSE: 94.74, MAE: 77.79
#
# Fold 102/416
# Fold RMSE: 195.37, MAE: 152.08
#
# Fold 103/416
# Fold RMSE: 80.77, MAE: 56.31
#
# Fold 104/416
# Fold RMSE: 118.67, MAE: 64.76
#
# Fold 105/416
# Fold RMSE: 218.04, MAE: 124.76
#
# Fold 106/416
# Fold RMSE: 117.37, MAE: 81.49
#
# Fold 107/416
# Fold RMSE: 109.92, MAE: 63.70
#
# Fold 108/416
# Fold RMSE: 181.99, MAE: 146.04
#
# Fold 109/416
# Fold RMSE: 75.36, MAE: 55.74
#
# Fold 110/416
# Fold RMSE: 66.41, MAE: 42.31
#
# Fold 111/416
# Fold RMSE: 172.04, MAE: 123.98
#
# Fold 112/416
# Fold RMSE: 81.98, MAE: 72.35
#
# Fold 113/416
# Fold RMSE: 61.99, MAE: 54.01
#
# Fold 114/416
# Fold RMSE: 119.84, MAE: 66.17
#
# Fold 115/416
# Fold RMSE: 130.57, MAE: 79.39
#
# Fold 116/416
# Fold RMSE: 129.78, MAE: 76.50
#
# Fold 117/416
# Fold RMSE: 43.64, MAE: 35.18
#
# Fold 118/416
# Fold RMSE: 66.46, MAE: 48.33
#
# Fold 119/416
# Fold RMSE: 64.95, MAE: 54.12
#
# Fold 120/416
# Fold RMSE: 49.58, MAE: 41.20
#
# Fold 121/416
# Fold RMSE: 121.36, MAE: 70.15
#
# Fold 122/416
# Fold RMSE: 85.01, MAE: 57.59
#
# Fold 123/416
# Fold RMSE: 68.82, MAE: 54.61
#
# Fold 124/416
# Fold RMSE: 89.96, MAE: 57.74
#
# Fold 125/416
# Fold RMSE: 53.64, MAE: 40.41
#
# Fold 126/416
# Fold RMSE: 102.52, MAE: 71.07
#
# Fold 127/416
# Fold RMSE: 80.53, MAE: 64.95
#
# Fold 128/416
# Fold RMSE: 131.95, MAE: 107.00
#
# Fold 129/416
# Fold RMSE: 73.90, MAE: 56.68
#
# Fold 130/416
# Fold RMSE: 79.99, MAE: 56.32
#
# Fold 131/416
# Fold RMSE: 62.14, MAE: 50.12
#
# Fold 132/416
# Fold RMSE: 72.69, MAE: 56.92
#
# Fold 133/416
# Fold RMSE: 69.17, MAE: 53.22
#
# Fold 134/416
# Fold RMSE: 88.45, MAE: 62.28
#
# Fold 135/416
# Fold RMSE: 71.52, MAE: 49.53
#
# Fold 136/416
# Fold RMSE: 36.50, MAE: 25.84
#
# Fold 137/416
# Fold RMSE: 80.40, MAE: 67.43
#
# Fold 138/416
# Fold RMSE: 67.67, MAE: 56.77
#
# Fold 139/416
# Fold RMSE: 78.66, MAE: 60.75
#
# Fold 140/416
# Fold RMSE: 59.42, MAE: 44.29
#
# Fold 141/416
# Fold RMSE: 57.11, MAE: 45.42
#
# Fold 142/416
# Fold RMSE: 82.94, MAE: 65.53
#
# Fold 143/416
# Fold RMSE: 71.11, MAE: 59.80
#
# Fold 144/416
# Fold RMSE: 81.89, MAE: 65.19
#
# Fold 145/416
# Fold RMSE: 113.05, MAE: 82.22
#
# Fold 146/416
# Fold RMSE: 95.33, MAE: 71.20
#
# Fold 147/416
# Fold RMSE: 72.64, MAE: 61.20
#
# Fold 148/416
# Fold RMSE: 85.09, MAE: 61.63
#
# Fold 149/416
# Fold RMSE: 73.72, MAE: 54.88
#
# Fold 150/416
# Fold RMSE: 48.83, MAE: 33.72
#
# Fold 151/416
# Fold RMSE: 69.25, MAE: 50.73
#
# Fold 152/416
# Fold RMSE: 75.82, MAE: 52.94
#
# Fold 153/416
# Fold RMSE: 73.52, MAE: 55.11
#
# Fold 154/416
# Fold RMSE: 154.39, MAE: 106.71
#
# Fold 155/416
# Fold RMSE: 73.57, MAE: 48.68
#
# Fold 156/416
# Fold RMSE: 35.73, MAE: 26.19
#
# Fold 157/416
# Fold RMSE: 82.37, MAE: 60.45
#
# Fold 158/416
# Fold RMSE: 73.93, MAE: 52.60
#
# Fold 159/416
# Fold RMSE: 80.01, MAE: 73.06
#
# Fold 160/416
# Fold RMSE: 98.19, MAE: 85.75
#
# Fold 161/416
# Fold RMSE: 69.64, MAE: 66.48
#
# Fold 162/416
# Fold RMSE: 103.37, MAE: 84.36
#
# Fold 163/416
# Fold RMSE: 112.61, MAE: 105.25
#
# Fold 164/416
# Fold RMSE: 95.51, MAE: 91.66
#
# Fold 165/416
# Fold RMSE: 119.56, MAE: 100.54
#
# Fold 166/416
# Fold RMSE: 120.18, MAE: 102.48
#
# Fold 167/416
# Fold RMSE: 100.13, MAE: 88.07
#
# Fold 168/416
# Fold RMSE: 90.76, MAE: 81.20
#
# Fold 169/416
# Fold RMSE: 62.65, MAE: 50.39
#
# Fold 170/416
# Fold RMSE: 92.86, MAE: 75.08
#
# Fold 171/416
# Fold RMSE: 75.91, MAE: 59.22
#
# Fold 172/416
# Fold RMSE: 115.21, MAE: 87.94
#
# Fold 173/416
# Fold RMSE: 78.31, MAE: 63.06
#
# Fold 174/416
# Fold RMSE: 69.68, MAE: 56.17
#
# Fold 175/416
# Fold RMSE: 69.44, MAE: 52.24
#
# Fold 176/416
# Fold RMSE: 64.81, MAE: 47.52
#
# Fold 177/416
# Fold RMSE: 88.32, MAE: 61.98
#
# Fold 178/416
# Fold RMSE: 105.80, MAE: 77.58
#
# Fold 179/416
# Fold RMSE: 101.82, MAE: 79.04
#
# Fold 180/416
# Fold RMSE: 93.43, MAE: 71.44
#
# Fold 181/416
# Fold RMSE: 111.13, MAE: 85.07
#
# Fold 182/416
# Fold RMSE: 208.46, MAE: 141.78
#
# Fold 183/416
# Fold RMSE: 92.96, MAE: 75.51
#
# Fold 184/416
# Fold RMSE: 158.08, MAE: 139.07
#
# Fold 185/416
# Fold RMSE: 108.19, MAE: 93.40
#
# Fold 186/416
# Fold RMSE: 69.19, MAE: 56.00
#
# Fold 187/416
# Fold RMSE: 134.27, MAE: 110.33
#
# Fold 188/416
# Fold RMSE: 77.53, MAE: 59.98
#
# Fold 189/416
# Fold RMSE: 117.73, MAE: 91.56
#
# Fold 190/416
# Fold RMSE: 235.86, MAE: 155.68
#
# Fold 191/416
# Fold RMSE: 140.08, MAE: 118.31
#
# Fold 192/416
# Fold RMSE: 101.82, MAE: 81.78
#
# Fold 193/416
# Fold RMSE: 115.91, MAE: 96.33
#
# Fold 194/416
# Fold RMSE: 181.22, MAE: 124.49
#
# Fold 195/416
# Fold RMSE: 166.37, MAE: 119.40
#
# Fold 196/416
# Fold RMSE: 187.39, MAE: 159.53
#
# Fold 197/416
# Fold RMSE: 155.22, MAE: 129.03
#
# Fold 198/416
# Fold RMSE: 120.30, MAE: 100.62
#
# Fold 199/416
# Fold RMSE: 112.75, MAE: 101.63
#
# Fold 200/416
# Fold RMSE: 119.33, MAE: 107.59
#
# Fold 201/416
# Fold RMSE: 157.02, MAE: 148.83
#
# Fold 202/416
# Fold RMSE: 251.67, MAE: 198.85
#
# Fold 203/416
# Fold RMSE: 229.82, MAE: 177.44
#
# Fold 204/416
# Fold RMSE: 204.57, MAE: 179.92
#
# Fold 205/416
# Fold RMSE: 315.96, MAE: 210.03
#
# Fold 206/416
# Fold RMSE: 204.52, MAE: 175.46
#
# Fold 207/416
# Fold RMSE: 219.41, MAE: 142.19
#
# Fold 208/416
# Fold RMSE: 179.77, MAE: 159.13
#
# Fold 209/416
# Fold RMSE: 158.20, MAE: 125.93
#
# Fold 210/416
# Fold RMSE: 188.47, MAE: 141.36
#
# Fold 211/416
# Fold RMSE: 174.51, MAE: 124.26
#
# Fold 212/416
# Fold RMSE: 101.81, MAE: 82.54
#
# Fold 213/416
# Fold RMSE: 120.90, MAE: 97.68
#
# Fold 214/416
# Fold RMSE: 264.69, MAE: 144.30
#
# Fold 215/416
# Fold RMSE: 277.53, MAE: 158.65
#
# Fold 216/416
# Fold RMSE: 133.33, MAE: 97.69
#
# Fold 217/416
# Fold RMSE: 161.94, MAE: 148.64
#
# Fold 218/416
# Fold RMSE: 84.66, MAE: 71.57
#
# Fold 219/416
# Fold RMSE: 166.82, MAE: 131.97
#
# Fold 220/416
# Fold RMSE: 117.90, MAE: 97.41
#
# Fold 221/416
# Fold RMSE: 127.33, MAE: 103.75
#
# Fold 222/416
# Fold RMSE: 143.43, MAE: 115.89
#
# Fold 223/416
# Fold RMSE: 193.77, MAE: 157.28
#
# Fold 224/416
# Fold RMSE: 165.06, MAE: 120.48
#
# Fold 225/416
# Fold RMSE: 175.97, MAE: 134.41
#
# Fold 226/416
# Fold RMSE: 144.41, MAE: 112.36
#
# Fold 227/416
# Fold RMSE: 116.07, MAE: 88.40
#
# Fold 228/416
# Fold RMSE: 159.17, MAE: 128.84
#
# Fold 229/416
# Fold RMSE: 172.61, MAE: 140.21
#
# Fold 230/416
# Fold RMSE: 198.36, MAE: 162.17
#
# Fold 231/416
# Fold RMSE: 126.12, MAE: 97.08
#
# Fold 232/416
# Fold RMSE: 147.21, MAE: 121.01
#
# Fold 233/416
# Fold RMSE: 229.22, MAE: 181.35
#
# Fold 234/416
# Fold RMSE: 206.13, MAE: 173.00
#
# Fold 235/416
# Fold RMSE: 169.21, MAE: 144.04
#
# Fold 236/416
# Fold RMSE: 174.86, MAE: 133.25
#
# Fold 237/416
# Fold RMSE: 110.54, MAE: 91.25
#
# Fold 238/416
# Fold RMSE: 183.87, MAE: 130.62
#
# Fold 239/416
# Fold RMSE: 215.14, MAE: 163.67
#
# Fold 240/416
# Fold RMSE: 178.28, MAE: 146.31
#
# Fold 241/416
# Fold RMSE: 237.78, MAE: 183.21
#
# Fold 242/416
# Fold RMSE: 149.98, MAE: 125.87
#
# Fold 243/416
# Fold RMSE: 153.74, MAE: 117.76
#
# Fold 244/416
# Fold RMSE: 238.09, MAE: 189.11
#
# Fold 245/416
# Fold RMSE: 317.55, MAE: 265.66
#
# Fold 246/416
# Fold RMSE: 395.76, MAE: 325.05
#
# Fold 247/416
# Fold RMSE: 332.52, MAE: 285.39
#
# Fold 248/416
# Fold RMSE: 349.19, MAE: 283.59
#
# Fold 249/416
# Fold RMSE: 771.11, MAE: 649.28
#
# Fold 250/416
# Fold RMSE: 499.15, MAE: 403.72
#
# Fold 251/416
# Fold RMSE: 638.91, MAE: 567.89
#
# Fold 252/416
# Fold RMSE: 474.86, MAE: 393.78
#
# Fold 253/416
# Fold RMSE: 537.96, MAE: 452.39
#
# Fold 254/416
# Fold RMSE: 613.23, MAE: 541.13
#
# Fold 255/416
# Fold RMSE: 707.54, MAE: 564.38
#
# Fold 256/416
# Fold RMSE: 790.98, MAE: 602.89
#
# Fold 257/416
# Fold RMSE: 724.30, MAE: 541.25
#
# Fold 258/416
# Fold RMSE: 934.66, MAE: 708.84
#
# Fold 259/416
# Fold RMSE: 747.25, MAE: 624.72
#
# Fold 260/416
# Fold RMSE: 1327.97, MAE: 1057.60
#
# Fold 261/416
# Fold RMSE: 743.44, MAE: 603.64
#
# Fold 262/416
# Fold RMSE: 751.27, MAE: 652.84
#
# Fold 263/416
# Fold RMSE: 725.96, MAE: 604.73
#
# Fold 264/416
# Fold RMSE: 699.29, MAE: 571.62
#
# Fold 265/416
# Fold RMSE: 526.65, MAE: 410.59
#
# Fold 266/416
# Fold RMSE: 556.10, MAE: 454.94
#
# Fold 267/416
# Fold RMSE: 483.00, MAE: 362.34
#
# Fold 268/416
# Fold RMSE: 396.70, MAE: 305.32
#
# Fold 269/416
# Fold RMSE: 394.95, MAE: 311.49
#
# Fold 270/416
# Fold RMSE: 1394.73, MAE: 1252.97
#
# Fold 271/416
# Fold RMSE: 1893.24, MAE: 1667.13
#
# Fold 272/416
# Fold RMSE: 683.52, MAE: 566.93
#
# Fold 273/416
# Fold RMSE: 692.98, MAE: 503.37
#
# Fold 274/416
# Fold RMSE: 683.78, MAE: 502.65
#
# Fold 275/416
# Fold RMSE: 1006.78, MAE: 906.98
#
# Fold 276/416
# Fold RMSE: 687.22, MAE: 588.11
#
# Fold 277/416
# Fold RMSE: 460.84, MAE: 389.87
#
# Fold 278/416
# Fold RMSE: 607.16, MAE: 552.85
#
# Fold 279/416
# Fold RMSE: 536.92, MAE: 487.92
#
# Fold 280/416
# Fold RMSE: 532.02, MAE: 403.84
#
# Fold 281/416
# Fold RMSE: 556.75, MAE: 401.91
#
# Fold 282/416
# Fold RMSE: 770.75, MAE: 600.67
#
# Fold 283/416
# Fold RMSE: 495.60, MAE: 359.26
#
# Fold 284/416
# Fold RMSE: 355.89, MAE: 261.07
#
# Fold 285/416
# Fold RMSE: 571.92, MAE: 448.05
#
# Fold 286/416
# Fold RMSE: 960.76, MAE: 806.59
#
# Fold 287/416
# Fold RMSE: 1019.92, MAE: 900.64
#
# Fold 288/416
# Fold RMSE: 634.48, MAE: 465.56
#
# Fold 289/416
# Fold RMSE: 1455.66, MAE: 1378.02
#
# Fold 290/416
# Fold RMSE: 1057.77, MAE: 880.18
#
# Fold 291/416
# Fold RMSE: 1223.03, MAE: 1057.57
#
# Fold 292/416
# Fold RMSE: 1043.91, MAE: 847.20
#
# Fold 293/416
# Fold RMSE: 1021.95, MAE: 877.77
#
# Fold 294/416
# Fold RMSE: 1622.74, MAE: 1472.68
#
# Fold 295/416
# Fold RMSE: 1932.95, MAE: 1736.68
#
# Fold 296/416
# Fold RMSE: 1530.99, MAE: 1321.06
#
# Fold 297/416
# Fold RMSE: 1671.34, MAE: 1331.92
#
# Fold 298/416
# Fold RMSE: 1148.11, MAE: 865.28
#
# Fold 299/416
# Fold RMSE: 1721.98, MAE: 1384.28
#
# Fold 300/416
# Fold RMSE: 916.38, MAE: 719.80
#
# Fold 301/416
# Fold RMSE: 1827.40, MAE: 1702.85
#
# Fold 302/416
# Fold RMSE: 968.67, MAE: 768.00
#
# Fold 303/416
# Fold RMSE: 731.54, MAE: 633.61
#
# Fold 304/416
# Fold RMSE: 757.90, MAE: 719.27
#
# Fold 305/416
# Fold RMSE: 519.76, MAE: 450.77
#
# Fold 306/416
# Fold RMSE: 658.82, MAE: 592.26
#
# Fold 307/416
# Fold RMSE: 494.58, MAE: 420.47
#
# Fold 308/416
# Fold RMSE: 962.84, MAE: 828.64
#
# Fold 309/416
# Fold RMSE: 1545.37, MAE: 1283.20
#
# Fold 310/416
# Fold RMSE: 1435.97, MAE: 1276.54
#
# Fold 311/416
# Fold RMSE: 1536.00, MAE: 1323.96
#
# Fold 312/416
# Fold RMSE: 850.29, MAE: 739.63
#
# Fold 313/416
# Fold RMSE: 1829.37, MAE: 1795.37
#
# Fold 314/416
# Fold RMSE: 1360.67, MAE: 1292.78
#
# Fold 315/416
# Fold RMSE: 943.65, MAE: 888.48
#
# Fold 316/416
# Fold RMSE: 493.87, MAE: 431.80
#
# Fold 317/416
# Fold RMSE: 630.51, MAE: 542.07
#
# Fold 318/416
# Fold RMSE: 364.34, MAE: 291.91
#
# Fold 319/416
# Fold RMSE: 471.01, MAE: 408.48
#
# Fold 320/416
# Fold RMSE: 395.64, MAE: 333.71
#
# Fold 321/416
# Fold RMSE: 429.66, MAE: 372.92
#
# Fold 322/416
# Fold RMSE: 410.97, MAE: 371.15
#
# Fold 323/416
# Fold RMSE: 268.12, MAE: 206.11
#
# Fold 324/416
# Fold RMSE: 327.06, MAE: 265.55
#
# Fold 325/416
# Fold RMSE: 320.61, MAE: 263.12
#
# Fold 326/416
# Fold RMSE: 323.25, MAE: 271.47
#
# Fold 327/416
# Fold RMSE: 328.67, MAE: 283.91
#
# Fold 328/416
# Fold RMSE: 319.63, MAE: 265.21
#
# Fold 329/416
# Fold RMSE: 280.18, MAE: 237.31
#
# Fold 330/416
# Fold RMSE: 262.91, MAE: 217.18
#
# Fold 331/416
# Fold RMSE: 285.95, MAE: 226.78
#
# Fold 332/416
# Fold RMSE: 339.15, MAE: 277.22
#
# Fold 333/416
# Fold RMSE: 298.41, MAE: 242.26
#
# Fold 334/416
# Fold RMSE: 290.31, MAE: 225.16
#
# Fold 335/416
# Fold RMSE: 273.84, MAE: 206.67
#
# Fold 336/416
# Fold RMSE: 266.59, MAE: 216.35
#
# Fold 337/416
# Fold RMSE: 348.66, MAE: 296.48
#
# Fold 338/416
# Fold RMSE: 363.71, MAE: 317.68
#
# Fold 339/416
# Fold RMSE: 276.42, MAE: 216.17
#
# Fold 340/416
# Fold RMSE: 412.75, MAE: 354.34
#
# Fold 341/416
# Fold RMSE: 253.46, MAE: 204.89
#
# Fold 342/416
# Fold RMSE: 442.27, MAE: 360.36
#
# Fold 343/416
# Fold RMSE: 265.92, MAE: 218.34
#
# Fold 344/416
# Fold RMSE: 229.67, MAE: 183.13
#
# Fold 345/416
# Fold RMSE: 389.90, MAE: 342.26
#
# Fold 346/416
# Fold RMSE: 358.03, MAE: 319.64
#
# Fold 347/416
# Fold RMSE: 502.27, MAE: 420.56
#
# Fold 348/416
# Fold RMSE: 282.17, MAE: 230.77
#
# Fold 349/416
# Fold RMSE: 254.78, MAE: 172.51
#
# Fold 350/416
# Fold RMSE: 440.01, MAE: 221.71
#
# Fold 351/416
# Fold RMSE: 594.61, MAE: 502.03
#
# Fold 352/416
# Fold RMSE: 501.86, MAE: 368.30
#
# Fold 353/416
# Fold RMSE: 537.53, MAE: 472.87
#
# Fold 354/416
# Fold RMSE: 431.32, MAE: 378.34
#
# Fold 355/416
# Fold RMSE: 445.94, MAE: 404.94
#
# Fold 356/416
# Fold RMSE: 345.72, MAE: 279.21
#
# Fold 357/416
# Fold RMSE: 250.27, MAE: 204.19
#
# Fold 358/416
# Fold RMSE: 263.19, MAE: 220.19
#
# Fold 359/416
# Fold RMSE: 367.07, MAE: 324.69
#
# Fold 360/416
# Fold RMSE: 320.32, MAE: 284.17
#
# Fold 361/416
# Fold RMSE: 559.26, MAE: 452.24
#
# Fold 362/416
# Fold RMSE: 435.00, MAE: 307.89
#
# Fold 363/416
# Fold RMSE: 254.19, MAE: 209.38
#
# Fold 364/416
# Fold RMSE: 615.28, MAE: 596.08
#
# Fold 365/416
# Fold RMSE: 452.14, MAE: 427.57
#
# Fold 366/416
# Fold RMSE: 525.37, MAE: 309.04
#
# Fold 367/416
# Fold RMSE: 350.03, MAE: 323.28
#
# Fold 368/416
# Fold RMSE: 341.21, MAE: 225.52
#
# Fold 369/416
# Fold RMSE: 212.69, MAE: 173.99
#
# Fold 370/416
# Fold RMSE: 315.82, MAE: 272.78
#
# Fold 371/416
# Fold RMSE: 282.54, MAE: 219.11
#
# Fold 372/416
# Fold RMSE: 112.95, MAE: 78.94
#
# Fold 373/416
# Fold RMSE: 178.77, MAE: 137.13
#
# Fold 374/416
# Fold RMSE: 141.16, MAE: 107.39
#
# Fold 375/416
# Fold RMSE: 147.28, MAE: 105.18
#
# Fold 376/416
# Fold RMSE: 167.03, MAE: 118.85
#
# Fold 377/416
# Fold RMSE: 215.79, MAE: 160.96
#
# Fold 378/416
# Fold RMSE: 209.41, MAE: 153.19
#
# Fold 379/416
# Fold RMSE: 186.09, MAE: 141.95
#
# Fold 380/416
# Fold RMSE: 290.32, MAE: 239.13
#
# Fold 381/416
# Fold RMSE: 333.37, MAE: 264.92
#
# Fold 382/416
# Fold RMSE: 305.43, MAE: 253.65
#
# Fold 383/416
# Fold RMSE: 281.95, MAE: 231.56
#
# Fold 384/416
# Fold RMSE: 299.14, MAE: 257.44
#
# Fold 385/416
# Fold RMSE: 359.53, MAE: 331.57
#
# Fold 386/416
# Fold RMSE: 321.08, MAE: 279.23
#
# Fold 387/416
# Fold RMSE: 352.26, MAE: 296.43
#
# Fold 388/416
# Fold RMSE: 372.79, MAE: 298.84
#
# Fold 389/416
# Fold RMSE: 314.79, MAE: 253.07
#
# Fold 390/416
# Fold RMSE: 343.20, MAE: 280.23
#
# Fold 391/416
# Fold RMSE: 321.88, MAE: 265.65
#
# Fold 392/416
# Fold RMSE: 321.56, MAE: 271.40
#
# Fold 393/416
# Fold RMSE: 353.35, MAE: 292.90
#
# Fold 394/416
# Fold RMSE: 331.86, MAE: 263.90
#
# Fold 395/416
# Fold RMSE: 280.22, MAE: 235.68
#
# Fold 396/416
# Fold RMSE: 324.97, MAE: 274.63
#
# Fold 397/416
# Fold RMSE: 353.76, MAE: 288.17
#
# Fold 398/416
# Fold RMSE: 437.38, MAE: 361.66
#
# Fold 399/416
# Fold RMSE: 340.37, MAE: 285.75
#
# Fold 400/416
# Fold RMSE: 433.52, MAE: 353.97
#
# Fold 401/416
# Fold RMSE: 440.72, MAE: 324.44
#
# Fold 402/416
# Fold RMSE: 349.92, MAE: 275.36
#
# Fold 403/416
# Fold RMSE: 284.18, MAE: 224.54
#
# Fold 404/416
# Fold RMSE: 392.76, MAE: 309.22
#
# Fold 405/416
# Fold RMSE: 346.69, MAE: 286.87
#
# Fold 406/416
# Fold RMSE: 270.57, MAE: 208.13
#
# Fold 407/416
# Fold RMSE: 377.05, MAE: 306.23
#
# Fold 408/416
# Fold RMSE: 367.08, MAE: 296.06
#
# Fold 409/416
# Fold RMSE: 414.85, MAE: 343.87
#
# Fold 410/416
# Fold RMSE: 663.80, MAE: 409.42
#
# Fold 411/416
# Fold RMSE: 415.66, MAE: 326.82
#
# Fold 412/416
# Fold RMSE: 372.74, MAE: 302.16
#
# Fold 413/416
# Fold RMSE: 460.53, MAE: 399.40
#
# Fold 414/416
# Fold RMSE: 409.16, MAE: 301.14
#
# Fold 415/416
# Fold RMSE: 1316.30, MAE: 762.29
#
# Fold 416/416
# Fold RMSE: 541.91, MAE: 508.89
#
# Overall RMSE: 458.54
# Overall MAE: 246.50
# Average fold RMSE: 302.49 (+/- 344.61)
# Average fold MAE: 246.50 (+/- 300.30)

# %%
title_DK1 = 'Walk-Forward Validation - Moving Average: Actual vs. Predicted for DK1'

plot_walk_forward_results(
        predictions_DK1, 
        actuals_DK1, 
        title_DK1)

title_DK2 = 'Walk-Forward Validation - Moving Average: Actual vs. Predicted for DK2'

plot_walk_forward_results(
        predictions_DK2, 
        actuals_DK2, 
        title_DK2)
