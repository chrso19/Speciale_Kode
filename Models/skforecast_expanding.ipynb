# %%
# Importing the packages

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error
from skforecast.recursive import ForecasterEquivalentDate

# %%
# Loading and processing the data

# Determining the path to the data
file_dir = os.path.dirname(os.path.realpath('naive_persistence.ipynb'))
python_dir = os.path.dirname(file_dir)
data_folder = os.path.join(python_dir, 'Data')
data_file = os.path.join(data_folder, 'combined_data_cleaned.csv')

# Loading the data
df = pd.read_csv(data_file, decimal = ',')
df_new = df[["TimeUTC", "DKZone", "DKPrice"]]

# Format for the datetime
date_format = '%Y-%m-%d %H:%M:%S'

# Filtering for DK1 price zone
df_DK1 = df_new[df_new['DKZone'] == 'DK1']
df_DK1 = df_DK1.drop('DKZone', axis = 1)
df_DK1.reset_index(drop=True, inplace=True)

# Saving datetime format for DK1
temp_list = []
for i in list(df_DK1["TimeUTC"]):
    n = 19
    j = i[:n]
    k = datetime.strptime(j, date_format)
    temp_list.append(k)
df_DK1.insert(0, "Time", temp_list, True)
df_DK1 = df_DK1.drop("TimeUTC", axis = 1)
df_DK1['DKPrice'] = df_DK1['DKPrice'].astype(float)

# Splitting between initial train and test set for DK1
DK1_train_set = df_DK1.loc[df_DK1['Time'] < pd.Timestamp('2025-01-01')]
DK1_train_set.set_index('Time', inplace=True)
DK1_train_set = DK1_train_set.asfreq('h')
DK1_train_set.index = DK1_train_set.index.tz_localize(None)
DK1_test_set = df_DK1.loc[df_DK1['Time'] >= pd.Timestamp('2025-01-01')]
DK1_test_set.set_index('Time', inplace=True)
DK1_test_set = DK1_test_set.asfreq('h')
DK1_test_set.index = DK1_test_set.index.tz_localize(None)

# Printing the shape for training and test date for DK1
print(f"Training data shape (DK1): {DK1_train_set.shape}")
print(f"Test data shape (DK1): {DK1_test_set.shape}")
print(f"Test set fraction (DK1): {len(DK1_test_set)/len(DK1_train_set):.2%}")

# Filtering for DK2 price zone
df_DK2 = df_new[df_new['DKZone'] == 'DK2']
df_DK2 = df_DK2.drop('DKZone', axis = 1)
df_DK2.reset_index(drop=True, inplace=True)

# Saving datetime format for DK2
temp_list = []
for i in list(df_DK2["TimeUTC"]):
    n = 19
    j = i[:n]
    k = datetime.strptime(j, date_format)
    temp_list.append(k)
df_DK2.insert(0, "Time", temp_list, True)
df_DK2 = df_DK2.drop("TimeUTC", axis = 1)
df_DK2['DKPrice'] = df_DK2['DKPrice'].astype(float)

# Splitting between initial train and test set for DK2
DK2_train_set = df_DK2.loc[df_DK1['Time'] < pd.Timestamp('2025-01-01')]
DK2_train_set.set_index('Time', inplace=True)
DK2_train_set = DK2_train_set.asfreq('h')
DK2_train_set.index = DK2_train_set.index.tz_localize(None)
DK2_test_set = df_DK2.loc[df_DK1['Time'] >= pd.Timestamp('2025-01-01')]
DK2_test_set.set_index('Time', inplace=True)
DK2_test_set = DK2_test_set.asfreq('h')
DK2_test_set.index = DK2_test_set.index.tz_localize(None)

# Printing the shape for training and test date for DK2
print(f"Training data shape (DK2): {DK2_train_set.shape}")
print(f"Test data shape (DK2): {DK2_test_set.shape}")
print(f"Test set fraction (DK2): {len(DK2_test_set)/len(DK2_train_set):.2%}")
# Out:
# Training data shape (DK1): (78912, 1)
# Test data shape (DK1): (8760, 1)
# Test set fraction (DK1): 11.10%
# Training data shape (DK2): (78912, 1)
# Test data shape (DK2): (8760, 1)
# Test set fraction (DK2): 11.10%

# %%
# Defining the skforecast model (Last Equivalent Date - Seasonal Naive)
forecaster = ForecasterEquivalentDate(
    offset = pd.DateOffset(days = 2),
    n_offsets = 7,
    agg_func = np.mean,
)

# %%
def perform_walk_forward_validation_forecaster(
        data_series, 
        model, 
        training_window = 8760, # 365 days of data - hours of data trained on
        forecast_horizon = 168, # 1 week - hours of data predicted
        ):
    """
    Walk-forward validation for Moving Average.
    """

    all_predictions = []
    all_actuals = []
    all_fold_rmse = []
    all_fold_mae = []

    # Calculate number of folds
    num_folds = (len(data_series) - training_window) // forecast_horizon

    print(f"Total folds: {num_folds}")
    print(f"Training winow: {training_window} hours")
    print(f"Forecast horizon: {forecast_horizon} hours")

    for fold in range(num_folds):
        start = 0

        # Check if there is enough data 
        if training_window + (fold + 1) * forecast_horizon > len(data_series):
            break
        
        print(f"Fold {fold + 1}/{num_folds}")

        # Split the data into training and validating data
        train_data = data_series.iloc[start: training_window + fold * forecast_horizon]
        val_data = data_series.iloc[training_window + fold * forecast_horizon: training_window + (fold + 1) * forecast_horizon]

        # Using the skforecast forecaster
        model.fit(train_data)
        predictions = model.predict(steps = forecast_horizon).values
        actuals = val_data.values

        # Calculate errors
        fold_mse = mean_squared_error(actuals, predictions)
        fold_rmse = np.sqrt(fold_mse)
        fold_mae = mean_absolute_error(actuals, predictions)

        all_fold_rmse.append(fold_rmse)
        all_fold_mae.append(fold_mae)
        all_predictions.extend(predictions)
        all_actuals.extend(actuals)

        print(f"Fold RMSE: {fold_rmse:.2f}, MAE: {fold_mae:.2f}\n")
    
    # Overall metrics
    overall_rmse = np.sqrt(mean_squared_error(all_actuals, all_predictions))
    overall_mae = mean_absolute_error(all_actuals, all_predictions)

    print(f"Overall RMSE: {overall_rmse:.2f}")
    print(f"Overall MAE: {overall_mae:.2f}")
    print(f"Average fold RMSE: {np.mean(all_fold_rmse):.2f} (+/- {np.std(all_fold_rmse):.2f})")
    print(f"Average fold MAE: {np.mean(all_fold_mae):.2f} (+/- {np.std(all_fold_mae):.2f})\n")

    return all_predictions, all_actuals, all_fold_rmse, all_fold_mae

# %%
def plot_walk_forward_results(
        predictions, 
        actuals, 
        title,
        training_window = 8760, # 365 days of data - hours of data trained on
        forecast_horizon = 168, # 1 week - hours of data predicted
        ):
    """
    Plot walk-forward validation results.
    """
    plt.figure(figsize=(15, 6))
    
    # Create x-axis (fold numbers repeated for each prediction in that fold)
    x = []
    fold_num = 0
    for i in range(len(predictions)):
        if i % (forecast_horizon) == 0 and i > 0:
            fold_num += 1
        x.append(fold_num)
    
    plt.plot(actuals, label='Actual', alpha=0.7, linewidth=2)
    plt.plot(predictions, label='Predicted', alpha=0.7, linewidth=2)
    
    # Add vertical lines to separate folds
    for i in range(0, len(predictions), forecast_horizon):
        plt.axvline(x=i, color='gray', linestyle='--', alpha=0.3)
    
    plt.xlabel('Time Step')
    plt.ylabel('Electricity Price (DKK)')
    plt.title(title)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
# Walk-forward validation
model = forecaster

# Walk-forward validation for DK1
data_series_DK1 = DK1_train_set['DKPrice']
predictions_DK1, actuals_DK1, rmse_DK1, mae_DK1 = perform_walk_forward_validation_forecaster(data_series_DK1, model)

# Walk-forward validation for DK2
data_series_DK2 = DK2_train_set['DKPrice']
predictions_DK2, actuals_DK2, rmse_DK2, mae_DK2 = perform_walk_forward_validation_forecaster(data_series_DK2, model)
# Out:
# Total folds: 417
# Training winow: 8760 hours
# Forecast horizon: 168 hours
# Fold 1/417
# Fold RMSE: 91.29, MAE: 69.01
#
# Fold 2/417
# Fold RMSE: 75.96, MAE: 61.19
#
# Fold 3/417
# Fold RMSE: 90.43, MAE: 44.93
#
# Fold 4/417
# Fold RMSE: 28.80, MAE: 19.93
#
# Fold 5/417
# Fold RMSE: 31.56, MAE: 20.80
#
# Fold 6/417
# Fold RMSE: 51.46, MAE: 29.23
#
# Fold 7/417
# Fold RMSE: 38.97, MAE: 21.46
#
# Fold 8/417
# Fold RMSE: 112.93, MAE: 79.06
#
# Fold 9/417
# Fold RMSE: 49.99, MAE: 36.70
#
# Fold 10/417
# Fold RMSE: 82.73, MAE: 65.78
#
# Fold 11/417
# Fold RMSE: 46.07, MAE: 29.43
#
# Fold 12/417
# Fold RMSE: 59.95, MAE: 41.40
#
# Fold 13/417
# Fold RMSE: 39.44, MAE: 32.95
#
# Fold 14/417
# Fold RMSE: 74.86, MAE: 48.05
#
# Fold 15/417
# Fold RMSE: 41.20, MAE: 28.14
#
# Fold 16/417
# Fold RMSE: 56.30, MAE: 41.71
#
# Fold 17/417
# Fold RMSE: 96.64, MAE: 79.94
#
# Fold 18/417
# Fold RMSE: 79.81, MAE: 45.33
#
# Fold 19/417
# Fold RMSE: 57.60, MAE: 43.39
#
# Fold 20/417
# Fold RMSE: 35.69, MAE: 25.95
#
# Fold 21/417
# Fold RMSE: 56.96, MAE: 46.14
#
# Fold 22/417
# Fold RMSE: 56.15, MAE: 45.98
#
# Fold 23/417
# Fold RMSE: 58.14, MAE: 46.21
#
# Fold 24/417
# Fold RMSE: 62.99, MAE: 47.43
#
# Fold 25/417
# Fold RMSE: 61.94, MAE: 50.40
#
# Fold 26/417
# Fold RMSE: 68.88, MAE: 54.53
#
# Fold 27/417
# Fold RMSE: 62.55, MAE: 52.44
#
# Fold 28/417
# Fold RMSE: 56.63, MAE: 46.93
#
# Fold 29/417
# Fold RMSE: 39.38, MAE: 31.67
#
# Fold 30/417
# Fold RMSE: 35.40, MAE: 28.88
#
# Fold 31/417
# Fold RMSE: 57.89, MAE: 42.83
#
# Fold 32/417
# Fold RMSE: 54.14, MAE: 43.02
#
# Fold 33/417
# Fold RMSE: 61.98, MAE: 50.98
#
# Fold 34/417
# Fold RMSE: 141.64, MAE: 98.69
#
# Fold 35/417
# Fold RMSE: 65.56, MAE: 47.78
#
# Fold 36/417
# Fold RMSE: 48.42, MAE: 37.17
#
# Fold 37/417
# Fold RMSE: 84.38, MAE: 65.29
#
# Fold 38/417
# Fold RMSE: 61.08, MAE: 55.11
#
# Fold 39/417
# Fold RMSE: 36.75, MAE: 29.65
#
# Fold 40/417
# Fold RMSE: 104.59, MAE: 89.57
#
# Fold 41/417
# Fold RMSE: 70.04, MAE: 53.40
#
# Fold 42/417
# Fold RMSE: 90.80, MAE: 66.09
#
# Fold 43/417
# Fold RMSE: 44.63, MAE: 36.57
#
# Fold 44/417
# Fold RMSE: 153.79, MAE: 107.46
#
# Fold 45/417
# Fold RMSE: 116.36, MAE: 76.80
#
# Fold 46/417
# Fold RMSE: 84.22, MAE: 62.71
#
# Fold 47/417
# Fold RMSE: 101.49, MAE: 79.62
#
# Fold 48/417
# Fold RMSE: 92.92, MAE: 66.98
#
# Fold 49/417
# Fold RMSE: 62.71, MAE: 52.10
#
# Fold 50/417
# Fold RMSE: 78.74, MAE: 61.78
#
# Fold 51/417
# Fold RMSE: 104.84, MAE: 69.44
#
# Fold 52/417
# Fold RMSE: 184.94, MAE: 142.58
#
# Fold 53/417
# Fold RMSE: 76.00, MAE: 61.98
#
# Fold 54/417
# Fold RMSE: 113.49, MAE: 99.48
#
# Fold 55/417
# Fold RMSE: 67.47, MAE: 47.67
#
# Fold 56/417
# Fold RMSE: 54.92, MAE: 45.40
#
# Fold 57/417
# Fold RMSE: 85.33, MAE: 55.71
#
# Fold 58/417
# Fold RMSE: 99.07, MAE: 79.81
#
# Fold 59/417
# Fold RMSE: 77.84, MAE: 52.00
#
# Fold 60/417
# Fold RMSE: 88.27, MAE: 76.12
#
# Fold 61/417
# Fold RMSE: 54.67, MAE: 40.16
#
# Fold 62/417
# Fold RMSE: 63.60, MAE: 46.37
#
# Fold 63/417
# Fold RMSE: 80.73, MAE: 60.40
#
# Fold 64/417
# Fold RMSE: 142.68, MAE: 99.89
#
# Fold 65/417
# Fold RMSE: 71.89, MAE: 58.36
#
# Fold 66/417
# Fold RMSE: 48.87, MAE: 40.49
#
# Fold 67/417
# Fold RMSE: 84.21, MAE: 53.89
#
# Fold 68/417
# Fold RMSE: 48.40, MAE: 38.21
#
# Fold 69/417
# Fold RMSE: 44.62, MAE: 34.86
#
# Fold 70/417
# Fold RMSE: 85.75, MAE: 52.95
#
# Fold 71/417
# Fold RMSE: 84.97, MAE: 67.20
#
# Fold 72/417
# Fold RMSE: 85.59, MAE: 72.66
#
# Fold 73/417
# Fold RMSE: 78.69, MAE: 67.28
#
# Fold 74/417
# Fold RMSE: 79.51, MAE: 67.12
#
# Fold 75/417
# Fold RMSE: 60.53, MAE: 52.42
#
# Fold 76/417
# Fold RMSE: 33.65, MAE: 26.15
#
# Fold 77/417
# Fold RMSE: 105.30, MAE: 69.76
#
# Fold 78/417
# Fold RMSE: 108.60, MAE: 65.81
#
# Fold 79/417
# Fold RMSE: 73.24, MAE: 63.98
#
# Fold 80/417
# Fold RMSE: 59.50, MAE: 42.25
#
# Fold 81/417
# Fold RMSE: 26.93, MAE: 23.08
#
# Fold 82/417
# Fold RMSE: 40.62, MAE: 33.92
#
# Fold 83/417
# Fold RMSE: 43.93, MAE: 35.31
#
# Fold 84/417
# Fold RMSE: 68.74, MAE: 54.53
#
# Fold 85/417
# Fold RMSE: 49.73, MAE: 35.99
#
# Fold 86/417
# Fold RMSE: 64.58, MAE: 53.92
#
# Fold 87/417
# Fold RMSE: 72.00, MAE: 60.53
#
# Fold 88/417
# Fold RMSE: 65.71, MAE: 57.02
#
# Fold 89/417
# Fold RMSE: 83.23, MAE: 65.24
#
# Fold 90/417
# Fold RMSE: 128.55, MAE: 107.57
#
# Fold 91/417
# Fold RMSE: 159.14, MAE: 139.44
#
# Fold 92/417
# Fold RMSE: 159.68, MAE: 127.81
#
# Fold 93/417
# Fold RMSE: 106.13, MAE: 83.39
#
# Fold 94/417
# Fold RMSE: 175.70, MAE: 156.11
#
# Fold 95/417
# Fold RMSE: 110.33, MAE: 88.87
#
# Fold 96/417
# Fold RMSE: 76.49, MAE: 63.30
#
# Fold 97/417
# Fold RMSE: 105.22, MAE: 89.03
#
# Fold 98/417
# Fold RMSE: 68.81, MAE: 57.06
#
# Fold 99/417
# Fold RMSE: 116.30, MAE: 79.79
#
# Fold 100/417
# Fold RMSE: 110.06, MAE: 82.13
#
# Fold 101/417
# Fold RMSE: 106.64, MAE: 86.74
#
# Fold 102/417
# Fold RMSE: 159.96, MAE: 123.22
#
# Fold 103/417
# Fold RMSE: 94.95, MAE: 76.93
#
# Fold 104/417
# Fold RMSE: 109.58, MAE: 70.97
#
# Fold 105/417
# Fold RMSE: 213.13, MAE: 127.23
#
# Fold 106/417
# Fold RMSE: 94.51, MAE: 76.85
#
# Fold 107/417
# Fold RMSE: 108.53, MAE: 82.52
#
# Fold 108/417
# Fold RMSE: 160.82, MAE: 137.83
#
# Fold 109/417
# Fold RMSE: 61.42, MAE: 48.83
#
# Fold 110/417
# Fold RMSE: 102.04, MAE: 86.12
#
# Fold 111/417
# Fold RMSE: 160.66, MAE: 108.73
#
# Fold 112/417
# Fold RMSE: 35.66, MAE: 26.95
#
# Fold 113/417
# Fold RMSE: 49.76, MAE: 41.56
#
# Fold 114/417
# Fold RMSE: 142.65, MAE: 98.54
#
# Fold 115/417
# Fold RMSE: 120.02, MAE: 85.76
#
# Fold 116/417
# Fold RMSE: 120.52, MAE: 91.58
#
# Fold 117/417
# Fold RMSE: 57.97, MAE: 49.78
#
# Fold 118/417
# Fold RMSE: 56.95, MAE: 44.69
#
# Fold 119/417
# Fold RMSE: 58.42, MAE: 49.81
#
# Fold 120/417
# Fold RMSE: 32.08, MAE: 26.49
#
# Fold 121/417
# Fold RMSE: 136.36, MAE: 84.97
#
# Fold 122/417
# Fold RMSE: 76.81, MAE: 53.72
#
# Fold 123/417
# Fold RMSE: 71.91, MAE: 62.69
#
# Fold 124/417
# Fold RMSE: 81.17, MAE: 47.22
#
# Fold 125/417
# Fold RMSE: 41.35, MAE: 29.76
#
# Fold 126/417
# Fold RMSE: 91.26, MAE: 61.58
#
# Fold 127/417
# Fold RMSE: 64.31, MAE: 50.15
#
# Fold 128/417
# Fold RMSE: 112.66, MAE: 83.12
#
# Fold 129/417
# Fold RMSE: 69.39, MAE: 57.17
#
# Fold 130/417
# Fold RMSE: 63.49, MAE: 47.89
#
# Fold 131/417
# Fold RMSE: 78.49, MAE: 56.89
#
# Fold 132/417
# Fold RMSE: 79.54, MAE: 66.67
#
# Fold 133/417
# Fold RMSE: 76.51, MAE: 68.76
#
# Fold 134/417
# Fold RMSE: 63.17, MAE: 49.31
#
# Fold 135/417
# Fold RMSE: 47.22, MAE: 35.10
#
# Fold 136/417
# Fold RMSE: 38.07, MAE: 28.55
#
# Fold 137/417
# Fold RMSE: 145.01, MAE: 94.54
#
# Fold 138/417
# Fold RMSE: 51.45, MAE: 35.38
#
# Fold 139/417
# Fold RMSE: 90.90, MAE: 75.14
#
# Fold 140/417
# Fold RMSE: 56.74, MAE: 46.51
#
# Fold 141/417
# Fold RMSE: 39.86, MAE: 29.50
#
# Fold 142/417
# Fold RMSE: 77.36, MAE: 55.88
#
# Fold 143/417
# Fold RMSE: 68.56, MAE: 54.71
#
# Fold 144/417
# Fold RMSE: 67.61, MAE: 52.11
#
# Fold 145/417
# Fold RMSE: 58.86, MAE: 43.23
#
# Fold 146/417
# Fold RMSE: 94.46, MAE: 76.21
#
# Fold 147/417
# Fold RMSE: 54.58, MAE: 44.92
#
# Fold 148/417
# Fold RMSE: 78.32, MAE: 65.06
#
# Fold 149/417
# Fold RMSE: 66.45, MAE: 53.87
#
# Fold 150/417
# Fold RMSE: 43.28, MAE: 35.34
#
# Fold 151/417
# Fold RMSE: 61.69, MAE: 46.49
#
# Fold 152/417
# Fold RMSE: 68.85, MAE: 52.97
#
# Fold 153/417
# Fold RMSE: 57.92, MAE: 45.66
#
# Fold 154/417
# Fold RMSE: 161.00, MAE: 112.36
#
# Fold 155/417
# Fold RMSE: 64.64, MAE: 47.61
#
# Fold 156/417
# Fold RMSE: 59.09, MAE: 38.25
#
# Fold 157/417
# Fold RMSE: 62.24, MAE: 49.89
#
# Fold 158/417
# Fold RMSE: 66.63, MAE: 49.82
#
# Fold 159/417
# Fold RMSE: 55.09, MAE: 47.24
#
# Fold 160/417
# Fold RMSE: 53.45, MAE: 46.95
#
# Fold 161/417
# Fold RMSE: 48.53, MAE: 36.12
#
# Fold 162/417
# Fold RMSE: 88.57, MAE: 71.39
#
# Fold 163/417
# Fold RMSE: 100.52, MAE: 89.91
#
# Fold 164/417
# Fold RMSE: 88.49, MAE: 75.61
#
# Fold 165/417
# Fold RMSE: 119.77, MAE: 104.05
#
# Fold 166/417
# Fold RMSE: 127.32, MAE: 113.37
#
# Fold 167/417
# Fold RMSE: 108.20, MAE: 95.72
#
# Fold 168/417
# Fold RMSE: 88.76, MAE: 74.33
#
# Fold 169/417
# Fold RMSE: 56.13, MAE: 47.87
#
# Fold 170/417
# Fold RMSE: 91.51, MAE: 79.14
#
# Fold 171/417
# Fold RMSE: 80.54, MAE: 69.76
#
# Fold 172/417
# Fold RMSE: 103.91, MAE: 83.11
#
# Fold 173/417
# Fold RMSE: 62.79, MAE: 49.95
#
# Fold 174/417
# Fold RMSE: 78.36, MAE: 66.23
#
# Fold 175/417
# Fold RMSE: 48.88, MAE: 41.35
#
# Fold 176/417
# Fold RMSE: 63.96, MAE: 50.49
#
# Fold 177/417
# Fold RMSE: 70.83, MAE: 51.56
#
# Fold 178/417
# Fold RMSE: 89.62, MAE: 68.14
#
# Fold 179/417
# Fold RMSE: 89.69, MAE: 74.27
#
# Fold 180/417
# Fold RMSE: 91.31, MAE: 74.33
#
# Fold 181/417
# Fold RMSE: 97.98, MAE: 82.38
#
# Fold 182/417
# Fold RMSE: 81.53, MAE: 63.66
#
# Fold 183/417
# Fold RMSE: 89.95, MAE: 68.59
#
# Fold 184/417
# Fold RMSE: 181.68, MAE: 148.96
#
# Fold 185/417
# Fold RMSE: 124.40, MAE: 114.42
#
# Fold 186/417
# Fold RMSE: 64.70, MAE: 56.98
#
# Fold 187/417
# Fold RMSE: 139.68, MAE: 114.36
#
# Fold 188/417
# Fold RMSE: 85.83, MAE: 70.92
#
# Fold 189/417
# Fold RMSE: 90.16, MAE: 77.79
#
# Fold 190/417
# Fold RMSE: 50.54, MAE: 40.89
#
# Fold 191/417
# Fold RMSE: 121.33, MAE: 94.79
#
# Fold 192/417
# Fold RMSE: 101.92, MAE: 79.83
#
# Fold 193/417
# Fold RMSE: 75.67, MAE: 62.99
#
# Fold 194/417
# Fold RMSE: 187.73, MAE: 126.17
#
# Fold 195/417
# Fold RMSE: 137.00, MAE: 98.53
#
# Fold 196/417
# Fold RMSE: 178.75, MAE: 149.31
#
# Fold 197/417
# Fold RMSE: 138.04, MAE: 101.65
#
# Fold 198/417
# Fold RMSE: 114.70, MAE: 89.91
#
# Fold 199/417
# Fold RMSE: 82.36, MAE: 67.41
#
# Fold 200/417
# Fold RMSE: 133.98, MAE: 107.20
#
# Fold 201/417
# Fold RMSE: 132.89, MAE: 121.98
#
# Fold 202/417
# Fold RMSE: 199.58, MAE: 189.60
#
# Fold 203/417
# Fold RMSE: 161.22, MAE: 151.31
#
# Fold 204/417
# Fold RMSE: 203.24, MAE: 184.07
#
# Fold 205/417
# Fold RMSE: 252.55, MAE: 212.86
#
# Fold 206/417
# Fold RMSE: 176.13, MAE: 136.72
#
# Fold 207/417
# Fold RMSE: 130.25, MAE: 102.51
#
# Fold 208/417
# Fold RMSE: 160.91, MAE: 139.30
#
# Fold 209/417
# Fold RMSE: 182.91, MAE: 147.68
#
# Fold 210/417
# Fold RMSE: 222.95, MAE: 184.43
#
# Fold 211/417
# Fold RMSE: 143.64, MAE: 107.82
#
# Fold 212/417
# Fold RMSE: 120.76, MAE: 99.32
#
# Fold 213/417
# Fold RMSE: 70.75, MAE: 60.44
#
# Fold 214/417
# Fold RMSE: 49.38, MAE: 38.98
#
# Fold 215/417
# Fold RMSE: 171.52, MAE: 134.02
#
# Fold 216/417
# Fold RMSE: 55.10, MAE: 42.62
#
# Fold 217/417
# Fold RMSE: 133.04, MAE: 115.32
#
# Fold 218/417
# Fold RMSE: 74.27, MAE: 61.61
#
# Fold 219/417
# Fold RMSE: 131.27, MAE: 110.96
#
# Fold 220/417
# Fold RMSE: 150.61, MAE: 118.37
#
# Fold 221/417
# Fold RMSE: 108.83, MAE: 92.16
#
# Fold 222/417
# Fold RMSE: 151.36, MAE: 110.91
#
# Fold 223/417
# Fold RMSE: 202.49, MAE: 147.55
#
# Fold 224/417
# Fold RMSE: 195.30, MAE: 166.11
#
# Fold 225/417
# Fold RMSE: 175.05, MAE: 149.98
#
# Fold 226/417
# Fold RMSE: 95.76, MAE: 64.00
#
# Fold 227/417
# Fold RMSE: 137.62, MAE: 106.81
#
# Fold 228/417
# Fold RMSE: 177.26, MAE: 133.51
#
# Fold 229/417
# Fold RMSE: 152.63, MAE: 128.39
#
# Fold 230/417
# Fold RMSE: 203.99, MAE: 154.10
#
# Fold 231/417
# Fold RMSE: 112.85, MAE: 93.25
#
# Fold 232/417
# Fold RMSE: 161.02, MAE: 143.89
#
# Fold 233/417
# Fold RMSE: 212.89, MAE: 156.09
#
# Fold 234/417
# Fold RMSE: 147.63, MAE: 122.49
#
# Fold 235/417
# Fold RMSE: 141.58, MAE: 120.86
#
# Fold 236/417
# Fold RMSE: 110.24, MAE: 85.14
#
# Fold 237/417
# Fold RMSE: 76.07, MAE: 63.54
#
# Fold 238/417
# Fold RMSE: 190.63, MAE: 123.60
#
# Fold 239/417
# Fold RMSE: 179.34, MAE: 125.86
#
# Fold 240/417
# Fold RMSE: 178.11, MAE: 148.94
#
# Fold 241/417
# Fold RMSE: 231.37, MAE: 195.41
#
# Fold 242/417
# Fold RMSE: 156.05, MAE: 127.75
#
# Fold 243/417
# Fold RMSE: 121.75, MAE: 101.74
#
# Fold 244/417
# Fold RMSE: 200.22, MAE: 166.95
#
# Fold 245/417
# Fold RMSE: 238.63, MAE: 213.23
#
# Fold 246/417
# Fold RMSE: 285.59, MAE: 241.39
#
# Fold 247/417
# Fold RMSE: 291.28, MAE: 226.01
#
# Fold 248/417
# Fold RMSE: 258.89, MAE: 217.51
#
# Fold 249/417
# Fold RMSE: 714.17, MAE: 556.80
#
# Fold 250/417
# Fold RMSE: 334.35, MAE: 280.91
#
# Fold 251/417
# Fold RMSE: 527.06, MAE: 445.56
#
# Fold 252/417
# Fold RMSE: 411.57, MAE: 335.93
#
# Fold 253/417
# Fold RMSE: 482.51, MAE: 381.68
#
# Fold 254/417
# Fold RMSE: 493.81, MAE: 413.39
#
# Fold 255/417
# Fold RMSE: 541.98, MAE: 422.19
#
# Fold 256/417
# Fold RMSE: 446.79, MAE: 326.76
#
# Fold 257/417
# Fold RMSE: 597.89, MAE: 461.14
#
# Fold 258/417
# Fold RMSE: 544.78, MAE: 407.00
#
# Fold 259/417
# Fold RMSE: 462.38, MAE: 376.25
#
# Fold 260/417
# Fold RMSE: 1135.67, MAE: 943.53
#
# Fold 261/417
# Fold RMSE: 888.29, MAE: 770.94
#
# Fold 262/417
# Fold RMSE: 713.58, MAE: 604.37
#
# Fold 263/417
# Fold RMSE: 516.19, MAE: 414.60
#
# Fold 264/417
# Fold RMSE: 450.97, MAE: 378.53
#
# Fold 265/417
# Fold RMSE: 383.92, MAE: 309.33
#
# Fold 266/417
# Fold RMSE: 465.60, MAE: 376.48
#
# Fold 267/417
# Fold RMSE: 422.91, MAE: 325.89
#
# Fold 268/417
# Fold RMSE: 256.01, MAE: 213.37
#
# Fold 269/417
# Fold RMSE: 306.21, MAE: 211.89
#
# Fold 270/417
# Fold RMSE: 1340.56, MAE: 1210.01
#
# Fold 271/417
# Fold RMSE: 1560.22, MAE: 1340.70
#
# Fold 272/417
# Fold RMSE: 920.31, MAE: 762.32
#
# Fold 273/417
# Fold RMSE: 794.83, MAE: 570.27
#
# Fold 274/417
# Fold RMSE: 383.53, MAE: 297.15
#
# Fold 275/417
# Fold RMSE: 644.87, MAE: 529.75
#
# Fold 276/417
# Fold RMSE: 546.36, MAE: 466.65
#
# Fold 277/417
# Fold RMSE: 398.58, MAE: 344.85
#
# Fold 278/417
# Fold RMSE: 485.74, MAE: 445.81
#
# Fold 279/417
# Fold RMSE: 334.63, MAE: 294.27
#
# Fold 280/417
# Fold RMSE: 373.03, MAE: 277.78
#
# Fold 281/417
# Fold RMSE: 314.30, MAE: 241.08
#
# Fold 282/417
# Fold RMSE: 657.25, MAE: 514.83
#
# Fold 283/417
# Fold RMSE: 483.86, MAE: 396.31
#
# Fold 284/417
# Fold RMSE: 348.89, MAE: 293.45
#
# Fold 285/417
# Fold RMSE: 425.50, MAE: 338.50
#
# Fold 286/417
# Fold RMSE: 842.37, MAE: 716.26
#
# Fold 287/417
# Fold RMSE: 740.42, MAE: 651.93
#
# Fold 288/417
# Fold RMSE: 575.64, MAE: 475.73
#
# Fold 289/417
# Fold RMSE: 933.40, MAE: 827.36
#
# Fold 290/417
# Fold RMSE: 979.70, MAE: 843.81
#
# Fold 291/417
# Fold RMSE: 909.17, MAE: 751.63
#
# Fold 292/417
# Fold RMSE: 640.67, MAE: 535.85
#
# Fold 293/417
# Fold RMSE: 589.67, MAE: 469.40
#
# Fold 294/417
# Fold RMSE: 1188.70, MAE: 1011.67
#
# Fold 295/417
# Fold RMSE: 1506.04, MAE: 1346.28
#
# Fold 296/417
# Fold RMSE: 1062.33, MAE: 853.22
#
# Fold 297/417
# Fold RMSE: 1619.06, MAE: 1459.99
#
# Fold 298/417
# Fold RMSE: 1044.40, MAE: 803.84
#
# Fold 299/417
# Fold RMSE: 1221.02, MAE: 831.84
#
# Fold 300/417
# Fold RMSE: 582.08, MAE: 477.18
#
# Fold 301/417
# Fold RMSE: 1630.15, MAE: 1478.58
#
# Fold 302/417
# Fold RMSE: 720.18, MAE: 574.32
#
# Fold 303/417
# Fold RMSE: 309.16, MAE: 233.70
#
# Fold 304/417
# Fold RMSE: 515.63, MAE: 460.30
#
# Fold 305/417
# Fold RMSE: 352.65, MAE: 297.95
#
# Fold 306/417
# Fold RMSE: 503.82, MAE: 447.97
#
# Fold 307/417
# Fold RMSE: 458.39, MAE: 398.46
#
# Fold 308/417
# Fold RMSE: 1084.31, MAE: 1001.94
#
# Fold 309/417
# Fold RMSE: 1297.27, MAE: 1073.11
#
# Fold 310/417
# Fold RMSE: 786.47, MAE: 654.93
#
# Fold 311/417
# Fold RMSE: 812.66, MAE: 680.53
#
# Fold 312/417
# Fold RMSE: 1307.14, MAE: 1242.23
#
# Fold 313/417
# Fold RMSE: 1852.04, MAE: 1788.52
#
# Fold 314/417
# Fold RMSE: 571.61, MAE: 468.24
#
# Fold 315/417
# Fold RMSE: 287.08, MAE: 228.52
#
# Fold 316/417
# Fold RMSE: 495.03, MAE: 439.56
#
# Fold 317/417
# Fold RMSE: 535.66, MAE: 480.98
#
# Fold 318/417
# Fold RMSE: 336.70, MAE: 292.63
#
# Fold 319/417
# Fold RMSE: 286.91, MAE: 243.21
#
# Fold 320/417
# Fold RMSE: 257.39, MAE: 205.72
#
# Fold 321/417
# Fold RMSE: 331.17, MAE: 266.10
#
# Fold 322/417
# Fold RMSE: 246.55, MAE: 220.77
#
# Fold 323/417
# Fold RMSE: 184.74, MAE: 138.53
#
# Fold 324/417
# Fold RMSE: 370.70, MAE: 304.70
#
# Fold 325/417
# Fold RMSE: 260.73, MAE: 213.11
#
# Fold 326/417
# Fold RMSE: 261.40, MAE: 199.21
#
# Fold 327/417
# Fold RMSE: 284.67, MAE: 255.13
#
# Fold 328/417
# Fold RMSE: 275.35, MAE: 207.01
#
# Fold 329/417
# Fold RMSE: 168.88, MAE: 127.26
#
# Fold 330/417
# Fold RMSE: 156.18, MAE: 119.93
#
# Fold 331/417
# Fold RMSE: 184.48, MAE: 130.30
#
# Fold 332/417
# Fold RMSE: 161.44, MAE: 122.87
#
# Fold 333/417
# Fold RMSE: 227.67, MAE: 167.94
#
# Fold 334/417
# Fold RMSE: 266.64, MAE: 216.35
#
# Fold 335/417
# Fold RMSE: 273.35, MAE: 183.79
#
# Fold 336/417
# Fold RMSE: 249.12, MAE: 201.46
#
# Fold 337/417
# Fold RMSE: 313.11, MAE: 266.77
#
# Fold 338/417
# Fold RMSE: 246.18, MAE: 217.54
#
# Fold 339/417
# Fold RMSE: 201.83, MAE: 152.95
#
# Fold 340/417
# Fold RMSE: 651.00, MAE: 435.08
#
# Fold 341/417
# Fold RMSE: 223.64, MAE: 182.34
#
# Fold 342/417
# Fold RMSE: 312.12, MAE: 267.41
#
# Fold 343/417
# Fold RMSE: 232.73, MAE: 181.23
#
# Fold 344/417
# Fold RMSE: 183.77, MAE: 149.68
#
# Fold 345/417
# Fold RMSE: 348.18, MAE: 299.67
#
# Fold 346/417
# Fold RMSE: 350.68, MAE: 321.12
#
# Fold 347/417
# Fold RMSE: 441.99, MAE: 384.03
#
# Fold 348/417
# Fold RMSE: 154.95, MAE: 124.45
#
# Fold 349/417
# Fold RMSE: 169.81, MAE: 129.62
#
# Fold 350/417
# Fold RMSE: 343.06, MAE: 159.88
#
# Fold 351/417
# Fold RMSE: 574.69, MAE: 454.50
#
# Fold 352/417
# Fold RMSE: 402.39, MAE: 323.65
#
# Fold 353/417
# Fold RMSE: 426.83, MAE: 373.39
#
# Fold 354/417
# Fold RMSE: 417.92, MAE: 357.46
#
# Fold 355/417
# Fold RMSE: 391.25, MAE: 329.47
#
# Fold 356/417
# Fold RMSE: 354.89, MAE: 278.01
#
# Fold 357/417
# Fold RMSE: 244.74, MAE: 194.89
#
# Fold 358/417
# Fold RMSE: 239.87, MAE: 199.13
#
# Fold 359/417
# Fold RMSE: 291.80, MAE: 258.58
#
# Fold 360/417
# Fold RMSE: 284.45, MAE: 238.77
#
# Fold 361/417
# Fold RMSE: 409.73, MAE: 316.66
#
# Fold 362/417
# Fold RMSE: 128.74, MAE: 105.46
#
# Fold 363/417
# Fold RMSE: 304.03, MAE: 255.35
#
# Fold 364/417
# Fold RMSE: 430.99, MAE: 405.37
#
# Fold 365/417
# Fold RMSE: 353.54, MAE: 308.84
#
# Fold 366/417
# Fold RMSE: 252.96, MAE: 206.18
#
# Fold 367/417
# Fold RMSE: 466.59, MAE: 456.06
#
# Fold 368/417
# Fold RMSE: 133.75, MAE: 109.22
#
# Fold 369/417
# Fold RMSE: 327.05, MAE: 296.43
#
# Fold 370/417
# Fold RMSE: 154.06, MAE: 127.04
#
# Fold 371/417
# Fold RMSE: 204.70, MAE: 161.90
#
# Fold 372/417
# Fold RMSE: 105.09, MAE: 90.70
#
# Fold 373/417
# Fold RMSE: 114.50, MAE: 86.13
#
# Fold 374/417
# Fold RMSE: 83.68, MAE: 67.24
#
# Fold 375/417
# Fold RMSE: 123.80, MAE: 99.07
#
# Fold 376/417
# Fold RMSE: 161.34, MAE: 125.97
#
# Fold 377/417
# Fold RMSE: 155.57, MAE: 120.65
#
# Fold 378/417
# Fold RMSE: 191.57, MAE: 151.52
#
# Fold 379/417
# Fold RMSE: 136.93, MAE: 108.59
#
# Fold 380/417
# Fold RMSE: 229.37, MAE: 187.56
#
# Fold 381/417
# Fold RMSE: 305.59, MAE: 257.02
#
# Fold 382/417
# Fold RMSE: 298.72, MAE: 269.54
#
# Fold 383/417
# Fold RMSE: 297.20, MAE: 241.36
#
# Fold 384/417
# Fold RMSE: 196.03, MAE: 178.82
#
# Fold 385/417
# Fold RMSE: 301.38, MAE: 265.86
#
# Fold 386/417
# Fold RMSE: 245.09, MAE: 210.44
#
# Fold 387/417
# Fold RMSE: 298.50, MAE: 269.52
#
# Fold 388/417
# Fold RMSE: 239.24, MAE: 185.40
#
# Fold 389/417
# Fold RMSE: 267.33, MAE: 202.93
#
# Fold 390/417
# Fold RMSE: 299.87, MAE: 263.43
#
# Fold 391/417
# Fold RMSE: 218.04, MAE: 175.76
#
# Fold 392/417
# Fold RMSE: 285.11, MAE: 224.68
#
# Fold 393/417
# Fold RMSE: 306.12, MAE: 253.55
#
# Fold 394/417
# Fold RMSE: 213.58, MAE: 171.61
#
# Fold 395/417
# Fold RMSE: 178.84, MAE: 150.01
#
# Fold 396/417
# Fold RMSE: 195.06, MAE: 161.07
#
# Fold 397/417
# Fold RMSE: 259.38, MAE: 202.43
#
# Fold 398/417
# Fold RMSE: 306.18, MAE: 243.77
#
# Fold 399/417
# Fold RMSE: 319.87, MAE: 258.53
#
# Fold 400/417
# Fold RMSE: 321.84, MAE: 269.59
#
# Fold 401/417
# Fold RMSE: 367.19, MAE: 290.45
#
# Fold 402/417
# Fold RMSE: 319.23, MAE: 246.31
#
# Fold 403/417
# Fold RMSE: 187.55, MAE: 149.52
#
# Fold 404/417
# Fold RMSE: 317.16, MAE: 247.58
#
# Fold 405/417
# Fold RMSE: 292.74, MAE: 231.98
#
# Fold 406/417
# Fold RMSE: 178.80, MAE: 150.69
#
# Fold 407/417
# Fold RMSE: 334.96, MAE: 288.27
#
# Fold 408/417
# Fold RMSE: 289.05, MAE: 259.59
#
# Fold 409/417
# Fold RMSE: 378.98, MAE: 319.71
#
# Fold 410/417
# Fold RMSE: 558.83, MAE: 349.78
#
# Fold 411/417
# Fold RMSE: 345.11, MAE: 282.37
#
# Fold 412/417
# Fold RMSE: 446.45, MAE: 322.73
#
# Fold 413/417
# Fold RMSE: 438.17, MAE: 364.39
#
# Fold 414/417
# Fold RMSE: 410.41, MAE: 295.85
#
# Fold 415/417
# Fold RMSE: 1294.62, MAE: 774.89
#
# Fold 416/417
# Fold RMSE: 849.54, MAE: 766.50
#
# Fold 417/417
# Fold RMSE: 416.63, MAE: 339.16
#
# Overall RMSE: 376.09
# Overall MAE: 202.71
# Average fold RMSE: 247.78 (+/- 282.93)
# Average fold MAE: 202.71 (+/- 243.84)
#
# Total folds: 417
# Training winow: 8760 hours
# Forecast horizon: 168 hours
# Fold 1/417
# Fold RMSE: 91.13, MAE: 70.27
#
# Fold 2/417
# Fold RMSE: 82.16, MAE: 64.38
#
# Fold 3/417
# Fold RMSE: 104.39, MAE: 63.82
#
# Fold 4/417
# Fold RMSE: 58.31, MAE: 41.26
#
# Fold 5/417
# Fold RMSE: 42.72, MAE: 30.97
#
# Fold 6/417
# Fold RMSE: 69.73, MAE: 51.45
#
# Fold 7/417
# Fold RMSE: 51.72, MAE: 37.00
#
# Fold 8/417
# Fold RMSE: 109.46, MAE: 90.19
#
# Fold 9/417
# Fold RMSE: 51.70, MAE: 39.17
#
# Fold 10/417
# Fold RMSE: 71.76, MAE: 54.97
#
# Fold 11/417
# Fold RMSE: 46.83, MAE: 32.13
#
# Fold 12/417
# Fold RMSE: 55.34, MAE: 37.49
#
# Fold 13/417
# Fold RMSE: 38.40, MAE: 31.57
#
# Fold 14/417
# Fold RMSE: 43.23, MAE: 32.18
#
# Fold 15/417
# Fold RMSE: 50.00, MAE: 37.78
#
# Fold 16/417
# Fold RMSE: 48.67, MAE: 36.21
#
# Fold 17/417
# Fold RMSE: 86.65, MAE: 73.95
#
# Fold 18/417
# Fold RMSE: 81.03, MAE: 44.42
#
# Fold 19/417
# Fold RMSE: 52.90, MAE: 41.35
#
# Fold 20/417
# Fold RMSE: 33.08, MAE: 25.75
#
# Fold 21/417
# Fold RMSE: 55.91, MAE: 45.44
#
# Fold 22/417
# Fold RMSE: 51.85, MAE: 43.02
#
# Fold 23/417
# Fold RMSE: 53.55, MAE: 43.56
#
# Fold 24/417
# Fold RMSE: 47.16, MAE: 38.10
#
# Fold 25/417
# Fold RMSE: 60.63, MAE: 50.73
#
# Fold 26/417
# Fold RMSE: 60.98, MAE: 49.11
#
# Fold 27/417
# Fold RMSE: 51.77, MAE: 45.50
#
# Fold 28/417
# Fold RMSE: 51.49, MAE: 42.44
#
# Fold 29/417
# Fold RMSE: 40.00, MAE: 31.74
#
# Fold 30/417
# Fold RMSE: 34.54, MAE: 28.29
#
# Fold 31/417
# Fold RMSE: 44.79, MAE: 37.57
#
# Fold 32/417
# Fold RMSE: 50.30, MAE: 40.55
#
# Fold 33/417
# Fold RMSE: 60.15, MAE: 49.08
#
# Fold 34/417
# Fold RMSE: 127.55, MAE: 84.06
#
# Fold 35/417
# Fold RMSE: 61.69, MAE: 42.93
#
# Fold 36/417
# Fold RMSE: 56.58, MAE: 37.90
#
# Fold 37/417
# Fold RMSE: 48.24, MAE: 38.91
#
# Fold 38/417
# Fold RMSE: 39.60, MAE: 31.21
#
# Fold 39/417
# Fold RMSE: 37.91, MAE: 30.54
#
# Fold 40/417
# Fold RMSE: 103.67, MAE: 89.68
#
# Fold 41/417
# Fold RMSE: 60.90, MAE: 48.13
#
# Fold 42/417
# Fold RMSE: 92.98, MAE: 70.87
#
# Fold 43/417
# Fold RMSE: 63.51, MAE: 51.22
#
# Fold 44/417
# Fold RMSE: 126.20, MAE: 93.86
#
# Fold 45/417
# Fold RMSE: 112.51, MAE: 77.25
#
# Fold 46/417
# Fold RMSE: 77.75, MAE: 66.17
#
# Fold 47/417
# Fold RMSE: 100.55, MAE: 79.19
#
# Fold 48/417
# Fold RMSE: 98.82, MAE: 71.72
#
# Fold 49/417
# Fold RMSE: 70.11, MAE: 58.56
#
# Fold 50/417
# Fold RMSE: 78.52, MAE: 62.23
#
# Fold 51/417
# Fold RMSE: 113.74, MAE: 80.43
#
# Fold 52/417
# Fold RMSE: 180.87, MAE: 138.77
#
# Fold 53/417
# Fold RMSE: 69.27, MAE: 57.17
#
# Fold 54/417
# Fold RMSE: 104.42, MAE: 90.08
#
# Fold 55/417
# Fold RMSE: 63.65, MAE: 42.91
#
# Fold 56/417
# Fold RMSE: 58.56, MAE: 48.44
#
# Fold 57/417
# Fold RMSE: 88.44, MAE: 61.43
#
# Fold 58/417
# Fold RMSE: 115.77, MAE: 93.42
#
# Fold 59/417
# Fold RMSE: 61.96, MAE: 45.50
#
# Fold 60/417
# Fold RMSE: 70.05, MAE: 62.13
#
# Fold 61/417
# Fold RMSE: 242.87, MAE: 112.40
#
# Fold 62/417
# Fold RMSE: 78.44, MAE: 51.29
#
# Fold 63/417
# Fold RMSE: 98.11, MAE: 68.35
#
# Fold 64/417
# Fold RMSE: 120.92, MAE: 77.51
#
# Fold 65/417
# Fold RMSE: 65.79, MAE: 51.48
#
# Fold 66/417
# Fold RMSE: 50.05, MAE: 40.33
#
# Fold 67/417
# Fold RMSE: 88.91, MAE: 57.24
#
# Fold 68/417
# Fold RMSE: 48.65, MAE: 38.91
#
# Fold 69/417
# Fold RMSE: 43.79, MAE: 33.90
#
# Fold 70/417
# Fold RMSE: 102.25, MAE: 61.11
#
# Fold 71/417
# Fold RMSE: 87.04, MAE: 68.27
#
# Fold 72/417
# Fold RMSE: 206.61, MAE: 114.14
#
# Fold 73/417
# Fold RMSE: 120.03, MAE: 95.53
#
# Fold 74/417
# Fold RMSE: 85.88, MAE: 73.63
#
# Fold 75/417
# Fold RMSE: 59.57, MAE: 51.47
#
# Fold 76/417
# Fold RMSE: 227.33, MAE: 91.61
#
# Fold 77/417
# Fold RMSE: 105.38, MAE: 82.70
#
# Fold 78/417
# Fold RMSE: 97.90, MAE: 62.53
#
# Fold 79/417
# Fold RMSE: 60.38, MAE: 53.12
#
# Fold 80/417
# Fold RMSE: 38.06, MAE: 31.57
#
# Fold 81/417
# Fold RMSE: 21.44, MAE: 18.39
#
# Fold 82/417
# Fold RMSE: 62.12, MAE: 39.75
#
# Fold 83/417
# Fold RMSE: 71.21, MAE: 48.07
#
# Fold 84/417
# Fold RMSE: 70.97, MAE: 55.74
#
# Fold 85/417
# Fold RMSE: 49.04, MAE: 36.39
#
# Fold 86/417
# Fold RMSE: 64.30, MAE: 53.86
#
# Fold 87/417
# Fold RMSE: 72.05, MAE: 58.92
#
# Fold 88/417
# Fold RMSE: 59.08, MAE: 50.97
#
# Fold 89/417
# Fold RMSE: 57.90, MAE: 48.81
#
# Fold 90/417
# Fold RMSE: 115.28, MAE: 94.94
#
# Fold 91/417
# Fold RMSE: 157.20, MAE: 140.71
#
# Fold 92/417
# Fold RMSE: 124.43, MAE: 103.35
#
# Fold 93/417
# Fold RMSE: 136.61, MAE: 115.37
#
# Fold 94/417
# Fold RMSE: 154.53, MAE: 135.14
#
# Fold 95/417
# Fold RMSE: 123.52, MAE: 97.48
#
# Fold 96/417
# Fold RMSE: 82.05, MAE: 66.39
#
# Fold 97/417
# Fold RMSE: 95.14, MAE: 80.49
#
# Fold 98/417
# Fold RMSE: 68.10, MAE: 56.20
#
# Fold 99/417
# Fold RMSE: 120.73, MAE: 83.51
#
# Fold 100/417
# Fold RMSE: 105.92, MAE: 80.21
#
# Fold 101/417
# Fold RMSE: 96.76, MAE: 78.50
#
# Fold 102/417
# Fold RMSE: 170.35, MAE: 141.82
#
# Fold 103/417
# Fold RMSE: 88.40, MAE: 71.91
#
# Fold 104/417
# Fold RMSE: 120.38, MAE: 86.28
#
# Fold 105/417
# Fold RMSE: 214.62, MAE: 127.79
#
# Fold 106/417
# Fold RMSE: 113.66, MAE: 92.62
#
# Fold 107/417
# Fold RMSE: 101.44, MAE: 75.31
#
# Fold 108/417
# Fold RMSE: 153.45, MAE: 129.66
#
# Fold 109/417
# Fold RMSE: 56.29, MAE: 42.36
#
# Fold 110/417
# Fold RMSE: 97.68, MAE: 83.17
#
# Fold 111/417
# Fold RMSE: 154.31, MAE: 104.88
#
# Fold 112/417
# Fold RMSE: 39.12, MAE: 28.87
#
# Fold 113/417
# Fold RMSE: 46.22, MAE: 36.05
#
# Fold 114/417
# Fold RMSE: 101.85, MAE: 60.97
#
# Fold 115/417
# Fold RMSE: 122.78, MAE: 78.04
#
# Fold 116/417
# Fold RMSE: 114.73, MAE: 78.71
#
# Fold 117/417
# Fold RMSE: 58.00, MAE: 49.57
#
# Fold 118/417
# Fold RMSE: 62.45, MAE: 48.29
#
# Fold 119/417
# Fold RMSE: 52.96, MAE: 44.60
#
# Fold 120/417
# Fold RMSE: 33.86, MAE: 28.56
#
# Fold 121/417
# Fold RMSE: 123.20, MAE: 71.98
#
# Fold 122/417
# Fold RMSE: 77.71, MAE: 54.04
#
# Fold 123/417
# Fold RMSE: 78.38, MAE: 65.72
#
# Fold 124/417
# Fold RMSE: 85.75, MAE: 53.83
#
# Fold 125/417
# Fold RMSE: 40.92, MAE: 29.45
#
# Fold 126/417
# Fold RMSE: 95.44, MAE: 65.73
#
# Fold 127/417
# Fold RMSE: 64.15, MAE: 49.72
#
# Fold 128/417
# Fold RMSE: 113.31, MAE: 86.08
#
# Fold 129/417
# Fold RMSE: 68.21, MAE: 56.31
#
# Fold 130/417
# Fold RMSE: 60.97, MAE: 44.70
#
# Fold 131/417
# Fold RMSE: 78.74, MAE: 58.93
#
# Fold 132/417
# Fold RMSE: 72.32, MAE: 60.22
#
# Fold 133/417
# Fold RMSE: 73.71, MAE: 65.63
#
# Fold 134/417
# Fold RMSE: 62.03, MAE: 48.41
#
# Fold 135/417
# Fold RMSE: 46.30, MAE: 34.34
#
# Fold 136/417
# Fold RMSE: 37.02, MAE: 27.56
#
# Fold 137/417
# Fold RMSE: 65.96, MAE: 54.72
#
# Fold 138/417
# Fold RMSE: 45.75, MAE: 32.57
#
# Fold 139/417
# Fold RMSE: 70.35, MAE: 53.81
#
# Fold 140/417
# Fold RMSE: 52.79, MAE: 38.62
#
# Fold 141/417
# Fold RMSE: 39.53, MAE: 30.48
#
# Fold 142/417
# Fold RMSE: 62.44, MAE: 45.79
#
# Fold 143/417
# Fold RMSE: 59.57, MAE: 47.40
#
# Fold 144/417
# Fold RMSE: 68.68, MAE: 51.95
#
# Fold 145/417
# Fold RMSE: 91.07, MAE: 69.29
#
# Fold 146/417
# Fold RMSE: 73.57, MAE: 55.89
#
# Fold 147/417
# Fold RMSE: 54.12, MAE: 43.64
#
# Fold 148/417
# Fold RMSE: 71.83, MAE: 58.65
#
# Fold 149/417
# Fold RMSE: 62.66, MAE: 51.17
#
# Fold 150/417
# Fold RMSE: 39.38, MAE: 32.33
#
# Fold 151/417
# Fold RMSE: 50.77, MAE: 38.38
#
# Fold 152/417
# Fold RMSE: 63.57, MAE: 46.61
#
# Fold 153/417
# Fold RMSE: 56.55, MAE: 43.93
#
# Fold 154/417
# Fold RMSE: 134.71, MAE: 93.86
#
# Fold 155/417
# Fold RMSE: 58.84, MAE: 44.63
#
# Fold 156/417
# Fold RMSE: 58.33, MAE: 38.55
#
# Fold 157/417
# Fold RMSE: 67.54, MAE: 51.96
#
# Fold 158/417
# Fold RMSE: 70.91, MAE: 53.14
#
# Fold 159/417
# Fold RMSE: 58.46, MAE: 51.02
#
# Fold 160/417
# Fold RMSE: 89.30, MAE: 69.18
#
# Fold 161/417
# Fold RMSE: 63.52, MAE: 52.31
#
# Fold 162/417
# Fold RMSE: 89.54, MAE: 70.55
#
# Fold 163/417
# Fold RMSE: 97.68, MAE: 87.12
#
# Fold 164/417
# Fold RMSE: 79.28, MAE: 67.42
#
# Fold 165/417
# Fold RMSE: 121.10, MAE: 96.67
#
# Fold 166/417
# Fold RMSE: 114.07, MAE: 99.42
#
# Fold 167/417
# Fold RMSE: 108.34, MAE: 93.42
#
# Fold 168/417
# Fold RMSE: 87.00, MAE: 72.94
#
# Fold 169/417
# Fold RMSE: 52.30, MAE: 43.26
#
# Fold 170/417
# Fold RMSE: 70.44, MAE: 60.19
#
# Fold 171/417
# Fold RMSE: 65.32, MAE: 55.12
#
# Fold 172/417
# Fold RMSE: 96.26, MAE: 73.36
#
# Fold 173/417
# Fold RMSE: 69.13, MAE: 56.72
#
# Fold 174/417
# Fold RMSE: 67.02, MAE: 53.41
#
# Fold 175/417
# Fold RMSE: 55.54, MAE: 45.21
#
# Fold 176/417
# Fold RMSE: 58.05, MAE: 44.00
#
# Fold 177/417
# Fold RMSE: 77.13, MAE: 51.03
#
# Fold 178/417
# Fold RMSE: 99.94, MAE: 74.20
#
# Fold 179/417
# Fold RMSE: 94.72, MAE: 78.27
#
# Fold 180/417
# Fold RMSE: 89.30, MAE: 70.47
#
# Fold 181/417
# Fold RMSE: 97.32, MAE: 77.78
#
# Fold 182/417
# Fold RMSE: 178.84, MAE: 124.75
#
# Fold 183/417
# Fold RMSE: 100.86, MAE: 76.00
#
# Fold 184/417
# Fold RMSE: 175.87, MAE: 141.56
#
# Fold 185/417
# Fold RMSE: 111.75, MAE: 102.91
#
# Fold 186/417
# Fold RMSE: 60.97, MAE: 52.56
#
# Fold 187/417
# Fold RMSE: 131.22, MAE: 106.98
#
# Fold 188/417
# Fold RMSE: 78.09, MAE: 65.08
#
# Fold 189/417
# Fold RMSE: 130.19, MAE: 102.13
#
# Fold 190/417
# Fold RMSE: 202.86, MAE: 128.20
#
# Fold 191/417
# Fold RMSE: 121.21, MAE: 86.46
#
# Fold 192/417
# Fold RMSE: 88.31, MAE: 71.01
#
# Fold 193/417
# Fold RMSE: 85.93, MAE: 72.68
#
# Fold 194/417
# Fold RMSE: 164.37, MAE: 112.74
#
# Fold 195/417
# Fold RMSE: 132.14, MAE: 98.74
#
# Fold 196/417
# Fold RMSE: 175.50, MAE: 146.12
#
# Fold 197/417
# Fold RMSE: 123.66, MAE: 92.23
#
# Fold 198/417
# Fold RMSE: 114.38, MAE: 90.24
#
# Fold 199/417
# Fold RMSE: 76.77, MAE: 62.17
#
# Fold 200/417
# Fold RMSE: 121.70, MAE: 99.26
#
# Fold 201/417
# Fold RMSE: 140.62, MAE: 127.22
#
# Fold 202/417
# Fold RMSE: 276.78, MAE: 245.78
#
# Fold 203/417
# Fold RMSE: 179.70, MAE: 122.06
#
# Fold 204/417
# Fold RMSE: 188.08, MAE: 151.08
#
# Fold 205/417
# Fold RMSE: 274.04, MAE: 178.99
#
# Fold 206/417
# Fold RMSE: 157.28, MAE: 125.06
#
# Fold 207/417
# Fold RMSE: 174.30, MAE: 114.94
#
# Fold 208/417
# Fold RMSE: 205.90, MAE: 161.24
#
# Fold 209/417
# Fold RMSE: 137.32, MAE: 110.33
#
# Fold 210/417
# Fold RMSE: 206.95, MAE: 166.22
#
# Fold 211/417
# Fold RMSE: 143.05, MAE: 107.75
#
# Fold 212/417
# Fold RMSE: 118.69, MAE: 98.74
#
# Fold 213/417
# Fold RMSE: 72.95, MAE: 64.47
#
# Fold 214/417
# Fold RMSE: 241.83, MAE: 115.15
#
# Fold 215/417
# Fold RMSE: 226.77, MAE: 128.40
#
# Fold 216/417
# Fold RMSE: 165.78, MAE: 110.18
#
# Fold 217/417
# Fold RMSE: 189.12, MAE: 158.57
#
# Fold 218/417
# Fold RMSE: 66.46, MAE: 54.51
#
# Fold 219/417
# Fold RMSE: 140.58, MAE: 114.04
#
# Fold 220/417
# Fold RMSE: 105.65, MAE: 89.00
#
# Fold 221/417
# Fold RMSE: 106.31, MAE: 86.42
#
# Fold 222/417
# Fold RMSE: 140.35, MAE: 113.94
#
# Fold 223/417
# Fold RMSE: 180.54, MAE: 144.93
#
# Fold 224/417
# Fold RMSE: 189.11, MAE: 161.28
#
# Fold 225/417
# Fold RMSE: 170.66, MAE: 145.09
#
# Fold 226/417
# Fold RMSE: 98.71, MAE: 70.60
#
# Fold 227/417
# Fold RMSE: 99.08, MAE: 83.21
#
# Fold 228/417
# Fold RMSE: 144.00, MAE: 119.46
#
# Fold 229/417
# Fold RMSE: 151.75, MAE: 129.30
#
# Fold 230/417
# Fold RMSE: 183.43, MAE: 140.51
#
# Fold 231/417
# Fold RMSE: 105.62, MAE: 88.47
#
# Fold 232/417
# Fold RMSE: 150.87, MAE: 134.93
#
# Fold 233/417
# Fold RMSE: 203.88, MAE: 152.71
#
# Fold 234/417
# Fold RMSE: 149.11, MAE: 126.25
#
# Fold 235/417
# Fold RMSE: 143.94, MAE: 125.55
#
# Fold 236/417
# Fold RMSE: 111.74, MAE: 86.48
#
# Fold 237/417
# Fold RMSE: 79.42, MAE: 65.09
#
# Fold 238/417
# Fold RMSE: 171.68, MAE: 101.37
#
# Fold 239/417
# Fold RMSE: 185.97, MAE: 130.19
#
# Fold 240/417
# Fold RMSE: 158.83, MAE: 136.08
#
# Fold 241/417
# Fold RMSE: 213.09, MAE: 182.06
#
# Fold 242/417
# Fold RMSE: 141.00, MAE: 122.90
#
# Fold 243/417
# Fold RMSE: 128.28, MAE: 104.86
#
# Fold 244/417
# Fold RMSE: 183.63, MAE: 152.71
#
# Fold 245/417
# Fold RMSE: 233.99, MAE: 208.01
#
# Fold 246/417
# Fold RMSE: 285.65, MAE: 240.57
#
# Fold 247/417
# Fold RMSE: 313.06, MAE: 253.82
#
# Fold 248/417
# Fold RMSE: 310.58, MAE: 260.76
#
# Fold 249/417
# Fold RMSE: 742.28, MAE: 605.78
#
# Fold 250/417
# Fold RMSE: 417.74, MAE: 352.48
#
# Fold 251/417
# Fold RMSE: 651.36, MAE: 570.07
#
# Fold 252/417
# Fold RMSE: 409.77, MAE: 331.06
#
# Fold 253/417
# Fold RMSE: 525.11, MAE: 425.33
#
# Fold 254/417
# Fold RMSE: 569.19, MAE: 499.54
#
# Fold 255/417
# Fold RMSE: 631.54, MAE: 535.45
#
# Fold 256/417
# Fold RMSE: 636.86, MAE: 508.23
#
# Fold 257/417
# Fold RMSE: 604.45, MAE: 466.15
#
# Fold 258/417
# Fold RMSE: 668.98, MAE: 502.36
#
# Fold 259/417
# Fold RMSE: 549.31, MAE: 461.33
#
# Fold 260/417
# Fold RMSE: 1137.40, MAE: 977.84
#
# Fold 261/417
# Fold RMSE: 841.37, MAE: 711.67
#
# Fold 262/417
# Fold RMSE: 708.96, MAE: 607.29
#
# Fold 263/417
# Fold RMSE: 650.87, MAE: 550.94
#
# Fold 264/417
# Fold RMSE: 547.69, MAE: 453.26
#
# Fold 265/417
# Fold RMSE: 438.44, MAE: 376.21
#
# Fold 266/417
# Fold RMSE: 536.31, MAE: 454.55
#
# Fold 267/417
# Fold RMSE: 460.03, MAE: 370.62
#
# Fold 268/417
# Fold RMSE: 393.62, MAE: 332.61
#
# Fold 269/417
# Fold RMSE: 302.53, MAE: 250.32
#
# Fold 270/417
# Fold RMSE: 1478.18, MAE: 1342.72
#
# Fold 271/417
# Fold RMSE: 1643.73, MAE: 1442.37
#
# Fold 272/417
# Fold RMSE: 1025.51, MAE: 826.20
#
# Fold 273/417
# Fold RMSE: 842.27, MAE: 584.92
#
# Fold 274/417
# Fold RMSE: 532.13, MAE: 418.33
#
# Fold 275/417
# Fold RMSE: 703.23, MAE: 609.58
#
# Fold 276/417
# Fold RMSE: 646.92, MAE: 577.61
#
# Fold 277/417
# Fold RMSE: 499.64, MAE: 440.75
#
# Fold 278/417
# Fold RMSE: 552.25, MAE: 523.67
#
# Fold 279/417
# Fold RMSE: 355.71, MAE: 321.06
#
# Fold 280/417
# Fold RMSE: 578.34, MAE: 405.15
#
# Fold 281/417
# Fold RMSE: 493.94, MAE: 350.87
#
# Fold 282/417
# Fold RMSE: 673.41, MAE: 515.72
#
# Fold 283/417
# Fold RMSE: 511.04, MAE: 437.55
#
# Fold 284/417
# Fold RMSE: 356.07, MAE: 309.35
#
# Fold 285/417
# Fold RMSE: 468.34, MAE: 375.43
#
# Fold 286/417
# Fold RMSE: 834.13, MAE: 704.76
#
# Fold 287/417
# Fold RMSE: 765.78, MAE: 675.42
#
# Fold 288/417
# Fold RMSE: 671.93, MAE: 519.01
#
# Fold 289/417
# Fold RMSE: 1502.15, MAE: 1379.09
#
# Fold 290/417
# Fold RMSE: 1158.52, MAE: 999.23
#
# Fold 291/417
# Fold RMSE: 1234.35, MAE: 1022.30
#
# Fold 292/417
# Fold RMSE: 829.27, MAE: 696.86
#
# Fold 293/417
# Fold RMSE: 734.68, MAE: 610.33
#
# Fold 294/417
# Fold RMSE: 1277.80, MAE: 1118.95
#
# Fold 295/417
# Fold RMSE: 1539.29, MAE: 1382.39
#
# Fold 296/417
# Fold RMSE: 1073.38, MAE: 861.32
#
# Fold 297/417
# Fold RMSE: 2078.73, MAE: 1879.88
#
# Fold 298/417
# Fold RMSE: 915.44, MAE: 680.65
#
# Fold 299/417
# Fold RMSE: 1154.01, MAE: 851.56
#
# Fold 300/417
# Fold RMSE: 592.94, MAE: 489.71
#
# Fold 301/417
# Fold RMSE: 1617.68, MAE: 1457.94
#
# Fold 302/417
# Fold RMSE: 754.52, MAE: 594.09
#
# Fold 303/417
# Fold RMSE: 380.56, MAE: 276.89
#
# Fold 304/417
# Fold RMSE: 515.16, MAE: 455.30
#
# Fold 305/417
# Fold RMSE: 364.84, MAE: 307.31
#
# Fold 306/417
# Fold RMSE: 511.84, MAE: 446.37
#
# Fold 307/417
# Fold RMSE: 500.37, MAE: 431.31
#
# Fold 308/417
# Fold RMSE: 1020.05, MAE: 941.11
#
# Fold 309/417
# Fold RMSE: 1264.29, MAE: 1056.16
#
# Fold 310/417
# Fold RMSE: 794.99, MAE: 670.21
#
# Fold 311/417
# Fold RMSE: 814.43, MAE: 688.17
#
# Fold 312/417
# Fold RMSE: 1333.62, MAE: 1271.09
#
# Fold 313/417
# Fold RMSE: 1846.17, MAE: 1783.72
#
# Fold 314/417
# Fold RMSE: 567.77, MAE: 449.65
#
# Fold 315/417
# Fold RMSE: 276.00, MAE: 217.00
#
# Fold 316/417
# Fold RMSE: 438.61, MAE: 359.44
#
# Fold 317/417
# Fold RMSE: 598.58, MAE: 529.51
#
# Fold 318/417
# Fold RMSE: 500.03, MAE: 423.25
#
# Fold 319/417
# Fold RMSE: 448.04, MAE: 383.17
#
# Fold 320/417
# Fold RMSE: 361.79, MAE: 311.52
#
# Fold 321/417
# Fold RMSE: 411.01, MAE: 343.09
#
# Fold 322/417
# Fold RMSE: 444.05, MAE: 409.30
#
# Fold 323/417
# Fold RMSE: 264.07, MAE: 226.08
#
# Fold 324/417
# Fold RMSE: 396.71, MAE: 346.92
#
# Fold 325/417
# Fold RMSE: 323.86, MAE: 278.29
#
# Fold 326/417
# Fold RMSE: 260.91, MAE: 224.89
#
# Fold 327/417
# Fold RMSE: 343.44, MAE: 307.48
#
# Fold 328/417
# Fold RMSE: 277.35, MAE: 225.35
#
# Fold 329/417
# Fold RMSE: 287.04, MAE: 237.47
#
# Fold 330/417
# Fold RMSE: 225.20, MAE: 192.34
#
# Fold 331/417
# Fold RMSE: 241.30, MAE: 198.14
#
# Fold 332/417
# Fold RMSE: 299.10, MAE: 237.15
#
# Fold 333/417
# Fold RMSE: 271.45, MAE: 230.83
#
# Fold 334/417
# Fold RMSE: 228.46, MAE: 180.65
#
# Fold 335/417
# Fold RMSE: 188.58, MAE: 150.90
#
# Fold 336/417
# Fold RMSE: 232.26, MAE: 194.70
#
# Fold 337/417
# Fold RMSE: 321.97, MAE: 286.80
#
# Fold 338/417
# Fold RMSE: 270.77, MAE: 242.58
#
# Fold 339/417
# Fold RMSE: 194.90, MAE: 148.39
#
# Fold 340/417
# Fold RMSE: 466.98, MAE: 391.72
#
# Fold 341/417
# Fold RMSE: 195.48, MAE: 167.29
#
# Fold 342/417
# Fold RMSE: 323.11, MAE: 279.17
#
# Fold 343/417
# Fold RMSE: 238.04, MAE: 191.89
#
# Fold 344/417
# Fold RMSE: 177.33, MAE: 148.54
#
# Fold 345/417
# Fold RMSE: 353.16, MAE: 305.40
#
# Fold 346/417
# Fold RMSE: 349.57, MAE: 321.01
#
# Fold 347/417
# Fold RMSE: 441.73, MAE: 384.68
#
# Fold 348/417
# Fold RMSE: 154.02, MAE: 123.61
#
# Fold 349/417
# Fold RMSE: 169.98, MAE: 129.76
#
# Fold 350/417
# Fold RMSE: 344.23, MAE: 163.78
#
# Fold 351/417
# Fold RMSE: 564.90, MAE: 450.10
#
# Fold 352/417
# Fold RMSE: 401.20, MAE: 324.64
#
# Fold 353/417
# Fold RMSE: 431.92, MAE: 376.20
#
# Fold 354/417
# Fold RMSE: 423.32, MAE: 364.76
#
# Fold 355/417
# Fold RMSE: 420.19, MAE: 369.70
#
# Fold 356/417
# Fold RMSE: 382.17, MAE: 306.86
#
# Fold 357/417
# Fold RMSE: 230.18, MAE: 191.74
#
# Fold 358/417
# Fold RMSE: 241.48, MAE: 189.79
#
# Fold 359/417
# Fold RMSE: 348.90, MAE: 312.48
#
# Fold 360/417
# Fold RMSE: 325.72, MAE: 293.41
#
# Fold 361/417
# Fold RMSE: 457.10, MAE: 361.93
#
# Fold 362/417
# Fold RMSE: 320.37, MAE: 221.54
#
# Fold 363/417
# Fold RMSE: 325.58, MAE: 262.24
#
# Fold 364/417
# Fold RMSE: 662.03, MAE: 632.84
#
# Fold 365/417
# Fold RMSE: 246.51, MAE: 215.47
#
# Fold 366/417
# Fold RMSE: 605.26, MAE: 340.37
#
# Fold 367/417
# Fold RMSE: 405.07, MAE: 387.44
#
# Fold 368/417
# Fold RMSE: 253.13, MAE: 149.83
#
# Fold 369/417
# Fold RMSE: 366.86, MAE: 333.99
#
# Fold 370/417
# Fold RMSE: 280.11, MAE: 243.44
#
# Fold 371/417
# Fold RMSE: 220.85, MAE: 187.76
#
# Fold 372/417
# Fold RMSE: 155.66, MAE: 141.84
#
# Fold 373/417
# Fold RMSE: 169.12, MAE: 127.96
#
# Fold 374/417
# Fold RMSE: 118.57, MAE: 98.50
#
# Fold 375/417
# Fold RMSE: 151.41, MAE: 126.32
#
# Fold 376/417
# Fold RMSE: 161.01, MAE: 128.79
#
# Fold 377/417
# Fold RMSE: 183.59, MAE: 150.43
#
# Fold 378/417
# Fold RMSE: 186.02, MAE: 148.58
#
# Fold 379/417
# Fold RMSE: 160.26, MAE: 126.54
#
# Fold 380/417
# Fold RMSE: 249.48, MAE: 203.14
#
# Fold 381/417
# Fold RMSE: 301.46, MAE: 253.15
#
# Fold 382/417
# Fold RMSE: 287.51, MAE: 259.89
#
# Fold 383/417
# Fold RMSE: 303.77, MAE: 251.14
#
# Fold 384/417
# Fold RMSE: 198.36, MAE: 178.81
#
# Fold 385/417
# Fold RMSE: 322.83, MAE: 285.32
#
# Fold 386/417
# Fold RMSE: 264.79, MAE: 230.43
#
# Fold 387/417
# Fold RMSE: 367.58, MAE: 333.79
#
# Fold 388/417
# Fold RMSE: 263.84, MAE: 205.43
#
# Fold 389/417
# Fold RMSE: 301.23, MAE: 223.89
#
# Fold 390/417
# Fold RMSE: 293.01, MAE: 253.08
#
# Fold 391/417
# Fold RMSE: 213.86, MAE: 171.38
#
# Fold 392/417
# Fold RMSE: 281.23, MAE: 226.64
#
# Fold 393/417
# Fold RMSE: 307.66, MAE: 257.12
#
# Fold 394/417
# Fold RMSE: 221.29, MAE: 174.96
#
# Fold 395/417
# Fold RMSE: 179.44, MAE: 152.97
#
# Fold 396/417
# Fold RMSE: 205.74, MAE: 169.46
#
# Fold 397/417
# Fold RMSE: 239.08, MAE: 188.58
#
# Fold 398/417
# Fold RMSE: 316.44, MAE: 247.92
#
# Fold 399/417
# Fold RMSE: 319.08, MAE: 254.21
#
# Fold 400/417
# Fold RMSE: 348.43, MAE: 293.77
#
# Fold 401/417
# Fold RMSE: 372.84, MAE: 295.53
#
# Fold 402/417
# Fold RMSE: 312.54, MAE: 244.49
#
# Fold 403/417
# Fold RMSE: 191.95, MAE: 154.92
#
# Fold 404/417
# Fold RMSE: 340.95, MAE: 266.80
#
# Fold 405/417
# Fold RMSE: 309.23, MAE: 245.59
#
# Fold 406/417
# Fold RMSE: 199.10, MAE: 166.18
#
# Fold 407/417
# Fold RMSE: 343.98, MAE: 297.88
#
# Fold 408/417
# Fold RMSE: 296.84, MAE: 268.32
#
# Fold 409/417
# Fold RMSE: 380.60, MAE: 320.41
#
# Fold 410/417
# Fold RMSE: 561.77, MAE: 359.04
#
# Fold 411/417
# Fold RMSE: 352.37, MAE: 287.53
#
# Fold 412/417
# Fold RMSE: 451.17, MAE: 330.84
#
# Fold 413/417
# Fold RMSE: 441.31, MAE: 373.01
#
# Fold 414/417
# Fold RMSE: 411.84, MAE: 313.41
#
# Fold 415/417
# Fold RMSE: 1300.17, MAE: 781.74
#
# Fold 416/417
# Fold RMSE: 849.14, MAE: 762.21
#
# Fold 417/417
# Fold RMSE: 425.99, MAE: 347.81
#
# Overall RMSE: 406.10
# Overall MAE: 219.32
# Average fold RMSE: 267.03 (+/- 305.95)
# Average fold MAE: 219.32 (+/- 266.86)

# %%
title_DK1 = 'Walk-Forward Validation - Seasonal Naive: Actual vs. Predicted for DK1'

plot_walk_forward_results(
        predictions_DK1, 
        actuals_DK1, 
        title_DK1)

title_DK2 = 'Walk-Forward Validation - Seasonal Naive: Actual vs. Predicted for DK2'

plot_walk_forward_results(
        predictions_DK2, 
        actuals_DK2, 
        title_DK2)
