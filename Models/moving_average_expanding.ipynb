# %%
# Importing the packages

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Loading and processing the data

# Determining the path to the data
file_dir = os.path.dirname(os.path.realpath('naive_persistence.ipynb'))
python_dir = os.path.dirname(file_dir)
data_folder = os.path.join(python_dir, 'Data')
data_file = os.path.join(data_folder, 'combined_data_cleaned.csv')

# Loading the data
df = pd.read_csv(data_file, decimal = ',')
df_new = df[["TimeUTC", "DKZone", "DKPrice"]]

# Format for the datetime
date_format = '%Y-%m-%d %H:%M:%S'

# Filtering for DK1 price zone
df_DK1 = df_new[df_new['DKZone'] == 'DK1']
df_DK1 = df_DK1.drop('DKZone', axis = 1)
df_DK1.reset_index(drop=True, inplace=True)

# Saving datetime format for DK1
temp_list = []
for i in list(df_DK1["TimeUTC"]):
    n = 19
    j = i[:n]
    k = datetime.strptime(j, date_format)
    temp_list.append(k)
df_DK1.insert(0, "Time", temp_list, True)
df_DK1 = df_DK1.drop("TimeUTC", axis = 1)
df_DK1['DKPrice'] = df_DK1['DKPrice'].astype(float)

# Splitting between initial train and test set for DK1
DK1_train_set = df_DK1.loc[df_DK1['Time'] < pd.Timestamp('2025-01-01')]
DK1_train_set.reset_index(drop=True, inplace=True)
DK1_test_set = df_DK1.loc[df_DK1['Time'] >= pd.Timestamp('2025-01-01')]
DK1_test_set.reset_index(drop=True, inplace=True)

# Printing the shape for training and test date for DK1
print(f"Training data shape (DK1): {DK1_train_set.shape}")
print(f"Test data shape (DK1): {DK1_test_set.shape}")
print(f"Test set fraction (DK1): {len(DK1_test_set)/len(DK1_train_set):.2%}")

# Filtering for DK2 price zone
df_DK2 = df_new[df_new['DKZone'] == 'DK2']
df_DK2 = df_DK2.drop('DKZone', axis = 1)
df_DK2.reset_index(drop=True, inplace=True)

# Saving datetime format for DK2
temp_list = []
for i in list(df_DK2["TimeUTC"]):
    n = 19
    j = i[:n]
    k = datetime.strptime(j, date_format)
    temp_list.append(k)
df_DK2.insert(0, "Time", temp_list, True)
df_DK2 = df_DK2.drop("TimeUTC", axis = 1)
df_DK2['DKPrice'] = df_DK2['DKPrice'].astype(float)

# Splitting between initial train and test set for DK2
DK2_train_set = df_DK2.loc[df_DK1['Time'] < pd.Timestamp('2025-01-01')]
DK2_train_set.reset_index(drop=True, inplace=True)
DK2_test_set = df_DK2.loc[df_DK1['Time'] >= pd.Timestamp('2025-01-01')]
DK2_test_set.reset_index(drop=True, inplace=True)

# Printing the shape for training and test date for DK2
print(f"Training data shape (DK2): {DK2_train_set.shape}")
print(f"Test data shape (DK2): {DK2_test_set.shape}")
print(f"Test set fraction (DK2): {len(DK2_test_set)/len(DK2_train_set):.2%}")
# Out:
# Training data shape (DK1): (78912, 2)
# Test data shape (DK1): (8760, 2)
# Test set fraction (DK1): 11.10%
# Training data shape (DK2): (78912, 2)
# Test data shape (DK2): (8760, 2)
# Test set fraction (DK2): 11.10%

# %%
# Defining the moving average model
def model_MA(L: list):
    average = np.mean(L)
    return average

# %%
def perform_walk_forward_validation_MA(
        data_series, 
        model, 
        training_window = 8760, # 365 days of data - hours of data trained on
        forecast_horizon = 168, # 1 week - hours of data predicted
        average_sequence = 48, # 1 month - hours used for average
        ):
    """
    Walk-forward validation for Moving Average.
    """

    all_predictions = []
    all_actuals = []
    all_fold_rmse = []
    all_fold_mae = []

    # Calculate number of folds
    num_folds = (len(data_series) - training_window) // forecast_horizon

    print(f"Total folds: {num_folds}")
    print(f"Training winow: {training_window} hours")
    print(f"Forecast horizon: {forecast_horizon} hours")

    for fold in range(num_folds):
        start = 0

        # Check if there is enough data 
        if training_window + (fold + 1) * forecast_horizon > len(data_series):
            break
        
        print(f"Fold {fold + 1}/{num_folds}")

        # Split the data into training and validating data
        train_data = data_series.iloc[start: training_window + fold * forecast_horizon]
        val_data = data_series.iloc[training_window + fold * forecast_horizon: training_window + (fold + 1) * forecast_horizon]

        # Using the moving average model
        temp_list = list(train_data)
        predictions = []

        for step in range(forecast_horizon):
            model_input = temp_list[-average_sequence:]
            predicted_value = model(model_input)
            predictions.append(predicted_value)
            temp_list.append(predicted_value)  # feed prediction back in

        predictions = np.array(predictions)
        actuals = val_data.values

        # Calculate errors
        fold_mse = mean_squared_error(actuals, predictions)
        fold_rmse = np.sqrt(fold_mse)
        fold_mae = mean_absolute_error(actuals, predictions)

        all_fold_rmse.append(fold_rmse)
        all_fold_mae.append(fold_mae)
        all_predictions.extend(predictions)
        all_actuals.extend(actuals)

        print(f"Fold RMSE: {fold_rmse:.2f}, MAE: {fold_mae:.2f}\n")
    
    # Overall metrics
    overall_rmse = np.sqrt(mean_squared_error(all_actuals, all_predictions))
    overall_mae = mean_absolute_error(all_actuals, all_predictions)

    print(f"Overall RMSE: {overall_rmse:.2f}")
    print(f"Overall MAE: {overall_mae:.2f}")
    print(f"Average fold RMSE: {np.mean(all_fold_rmse):.2f} (+/- {np.std(all_fold_rmse):.2f})")
    print(f"Average fold MAE: {np.mean(all_fold_mae):.2f} (+/- {np.std(all_fold_mae):.2f})\n")

    return all_predictions, all_actuals, all_fold_rmse, all_fold_mae

# %%
def plot_walk_forward_results(
        predictions, 
        actuals, 
        title,
        training_window = 8760, # 365 days of data - hours of data trained on
        forecast_horizon = 168, # 1 week - hours of data predicted
        ):
    """
    Plot walk-forward validation results.
    """
    plt.figure(figsize=(15, 6))
    
    # Create x-axis (fold numbers repeated for each prediction in that fold)
    x = []
    fold_num = 0
    for i in range(len(predictions)):
        if i % (forecast_horizon) == 0 and i > 0:
            fold_num += 1
        x.append(fold_num)
    
    plt.plot(actuals, label='Actual', alpha=0.7, linewidth=2)
    plt.plot(predictions, label='Predicted', alpha=0.7, linewidth=2)
    
    # Add vertical lines to separate folds
    for i in range(0, len(predictions), forecast_horizon):
        plt.axvline(x=i, color='gray', linestyle='--', alpha=0.3)
    
    plt.xlabel('Time Step')
    plt.ylabel('Electricity Price (DKK)')
    plt.title(title)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
# Walk-forward validation
model = model_MA

# Walk-forward validation for DK1
data_series_DK1 = DK1_train_set['DKPrice']
predictions_DK1, actuals_DK1, rmse_DK1, mae_DK1 = perform_walk_forward_validation_MA(data_series_DK1, model)

# Walk-forward validation for DK2
data_series_DK2 = DK2_train_set['DKPrice']
predictions_DK2, actuals_DK2, rmse_DK2, mae_DK2 = perform_walk_forward_validation_MA(data_series_DK2, model)
# Out:
# Total folds: 417
# Training winow: 8760 hours
# Forecast horizon: 168 hours
# Fold 1/417
# Fold RMSE: 81.39, MAE: 48.69
#
# Fold 2/417
# Fold RMSE: 67.55, MAE: 50.61
#
# Fold 3/417
# Fold RMSE: 83.89, MAE: 39.77
#
# Fold 4/417
# Fold RMSE: 32.24, MAE: 15.93
#
# Fold 5/417
# Fold RMSE: 30.61, MAE: 19.52
#
# Fold 6/417
# Fold RMSE: 52.35, MAE: 22.37
#
# Fold 7/417
# Fold RMSE: 49.97, MAE: 40.08
#
# Fold 8/417
# Fold RMSE: 107.47, MAE: 61.80
#
# Fold 9/417
# Fold RMSE: 57.32, MAE: 41.80
#
# Fold 10/417
# Fold RMSE: 67.65, MAE: 41.49
#
# Fold 11/417
# Fold RMSE: 57.37, MAE: 31.19
#
# Fold 12/417
# Fold RMSE: 60.71, MAE: 52.30
#
# Fold 13/417
# Fold RMSE: 37.21, MAE: 30.15
#
# Fold 14/417
# Fold RMSE: 81.05, MAE: 48.27
#
# Fold 15/417
# Fold RMSE: 40.53, MAE: 29.94
#
# Fold 16/417
# Fold RMSE: 55.10, MAE: 32.43
#
# Fold 17/417
# Fold RMSE: 123.32, MAE: 113.31
#
# Fold 18/417
# Fold RMSE: 102.83, MAE: 65.27
#
# Fold 19/417
# Fold RMSE: 38.40, MAE: 26.84
#
# Fold 20/417
# Fold RMSE: 35.77, MAE: 25.83
#
# Fold 21/417
# Fold RMSE: 60.66, MAE: 50.99
#
# Fold 22/417
# Fold RMSE: 64.10, MAE: 54.11
#
# Fold 23/417
# Fold RMSE: 97.65, MAE: 80.91
#
# Fold 24/417
# Fold RMSE: 86.18, MAE: 68.97
#
# Fold 25/417
# Fold RMSE: 91.96, MAE: 71.83
#
# Fold 26/417
# Fold RMSE: 72.37, MAE: 60.51
#
# Fold 27/417
# Fold RMSE: 68.53, MAE: 53.29
#
# Fold 28/417
# Fold RMSE: 52.22, MAE: 45.00
#
# Fold 29/417
# Fold RMSE: 55.30, MAE: 47.72
#
# Fold 30/417
# Fold RMSE: 48.84, MAE: 41.52
#
# Fold 31/417
# Fold RMSE: 57.99, MAE: 45.64
#
# Fold 32/417
# Fold RMSE: 76.22, MAE: 59.22
#
# Fold 33/417
# Fold RMSE: 76.86, MAE: 62.37
#
# Fold 34/417
# Fold RMSE: 146.40, MAE: 102.73
#
# Fold 35/417
# Fold RMSE: 67.40, MAE: 49.17
#
# Fold 36/417
# Fold RMSE: 61.94, MAE: 49.52
#
# Fold 37/417
# Fold RMSE: 77.02, MAE: 50.86
#
# Fold 38/417
# Fold RMSE: 58.55, MAE: 47.62
#
# Fold 39/417
# Fold RMSE: 54.80, MAE: 48.86
#
# Fold 40/417
# Fold RMSE: 88.76, MAE: 64.59
#
# Fold 41/417
# Fold RMSE: 83.45, MAE: 59.62
#
# Fold 42/417
# Fold RMSE: 94.44, MAE: 61.13
#
# Fold 43/417
# Fold RMSE: 57.07, MAE: 46.97
#
# Fold 44/417
# Fold RMSE: 146.48, MAE: 108.93
#
# Fold 45/417
# Fold RMSE: 110.96, MAE: 80.85
#
# Fold 46/417
# Fold RMSE: 83.61, MAE: 56.51
#
# Fold 47/417
# Fold RMSE: 114.55, MAE: 82.63
#
# Fold 48/417
# Fold RMSE: 103.79, MAE: 68.10
#
# Fold 49/417
# Fold RMSE: 115.13, MAE: 105.65
#
# Fold 50/417
# Fold RMSE: 95.96, MAE: 75.49
#
# Fold 51/417
# Fold RMSE: 99.80, MAE: 68.75
#
# Fold 52/417
# Fold RMSE: 168.12, MAE: 121.87
#
# Fold 53/417
# Fold RMSE: 88.86, MAE: 63.36
#
# Fold 54/417
# Fold RMSE: 75.18, MAE: 63.40
#
# Fold 55/417
# Fold RMSE: 88.75, MAE: 65.85
#
# Fold 56/417
# Fold RMSE: 87.31, MAE: 68.31
#
# Fold 57/417
# Fold RMSE: 102.23, MAE: 61.77
#
# Fold 58/417
# Fold RMSE: 83.94, MAE: 54.34
#
# Fold 59/417
# Fold RMSE: 84.74, MAE: 51.24
#
# Fold 60/417
# Fold RMSE: 95.57, MAE: 69.44
#
# Fold 61/417
# Fold RMSE: 82.16, MAE: 69.95
#
# Fold 62/417
# Fold RMSE: 80.00, MAE: 56.72
#
# Fold 63/417
# Fold RMSE: 90.05, MAE: 67.08
#
# Fold 64/417
# Fold RMSE: 152.70, MAE: 135.54
#
# Fold 65/417
# Fold RMSE: 70.58, MAE: 60.94
#
# Fold 66/417
# Fold RMSE: 50.15, MAE: 30.51
#
# Fold 67/417
# Fold RMSE: 80.62, MAE: 56.94
#
# Fold 68/417
# Fold RMSE: 61.72, MAE: 47.60
#
# Fold 69/417
# Fold RMSE: 58.83, MAE: 42.67
#
# Fold 70/417
# Fold RMSE: 89.60, MAE: 57.23
#
# Fold 71/417
# Fold RMSE: 126.92, MAE: 103.79
#
# Fold 72/417
# Fold RMSE: 94.07, MAE: 72.18
#
# Fold 73/417
# Fold RMSE: 76.99, MAE: 56.31
#
# Fold 74/417
# Fold RMSE: 67.69, MAE: 49.70
#
# Fold 75/417
# Fold RMSE: 60.54, MAE: 52.01
#
# Fold 76/417
# Fold RMSE: 46.98, MAE: 38.63
#
# Fold 77/417
# Fold RMSE: 116.86, MAE: 83.27
#
# Fold 78/417
# Fold RMSE: 188.33, MAE: 158.12
#
# Fold 79/417
# Fold RMSE: 50.73, MAE: 38.62
#
# Fold 80/417
# Fold RMSE: 60.91, MAE: 39.81
#
# Fold 81/417
# Fold RMSE: 37.95, MAE: 29.03
#
# Fold 82/417
# Fold RMSE: 39.52, MAE: 32.23
#
# Fold 83/417
# Fold RMSE: 59.05, MAE: 49.41
#
# Fold 84/417
# Fold RMSE: 104.95, MAE: 88.63
#
# Fold 85/417
# Fold RMSE: 77.69, MAE: 62.46
#
# Fold 86/417
# Fold RMSE: 74.60, MAE: 67.25
#
# Fold 87/417
# Fold RMSE: 85.54, MAE: 67.50
#
# Fold 88/417
# Fold RMSE: 63.74, MAE: 58.91
#
# Fold 89/417
# Fold RMSE: 100.38, MAE: 88.01
#
# Fold 90/417
# Fold RMSE: 160.34, MAE: 142.57
#
# Fold 91/417
# Fold RMSE: 115.97, MAE: 83.60
#
# Fold 92/417
# Fold RMSE: 170.14, MAE: 135.33
#
# Fold 93/417
# Fold RMSE: 119.02, MAE: 109.13
#
# Fold 94/417
# Fold RMSE: 200.89, MAE: 168.54
#
# Fold 95/417
# Fold RMSE: 199.90, MAE: 178.39
#
# Fold 96/417
# Fold RMSE: 93.28, MAE: 74.19
#
# Fold 97/417
# Fold RMSE: 106.56, MAE: 81.14
#
# Fold 98/417
# Fold RMSE: 97.43, MAE: 89.25
#
# Fold 99/417
# Fold RMSE: 134.01, MAE: 99.33
#
# Fold 100/417
# Fold RMSE: 199.54, MAE: 184.05
#
# Fold 101/417
# Fold RMSE: 75.72, MAE: 53.82
#
# Fold 102/417
# Fold RMSE: 166.51, MAE: 132.34
#
# Fold 103/417
# Fold RMSE: 82.62, MAE: 69.79
#
# Fold 104/417
# Fold RMSE: 115.86, MAE: 60.89
#
# Fold 105/417
# Fold RMSE: 233.91, MAE: 138.24
#
# Fold 106/417
# Fold RMSE: 104.04, MAE: 63.63
#
# Fold 107/417
# Fold RMSE: 119.65, MAE: 68.32
#
# Fold 108/417
# Fold RMSE: 113.83, MAE: 80.30
#
# Fold 109/417
# Fold RMSE: 122.41, MAE: 108.68
#
# Fold 110/417
# Fold RMSE: 74.16, MAE: 51.83
#
# Fold 111/417
# Fold RMSE: 132.08, MAE: 93.65
#
# Fold 112/417
# Fold RMSE: 47.81, MAE: 40.09
#
# Fold 113/417
# Fold RMSE: 50.18, MAE: 43.11
#
# Fold 114/417
# Fold RMSE: 167.05, MAE: 114.10
#
# Fold 115/417
# Fold RMSE: 121.47, MAE: 94.13
#
# Fold 116/417
# Fold RMSE: 136.36, MAE: 88.90
#
# Fold 117/417
# Fold RMSE: 50.32, MAE: 39.43
#
# Fold 118/417
# Fold RMSE: 65.36, MAE: 47.85
#
# Fold 119/417
# Fold RMSE: 40.06, MAE: 30.74
#
# Fold 120/417
# Fold RMSE: 50.76, MAE: 42.58
#
# Fold 121/417
# Fold RMSE: 142.41, MAE: 88.87
#
# Fold 122/417
# Fold RMSE: 96.31, MAE: 67.64
#
# Fold 123/417
# Fold RMSE: 56.14, MAE: 45.13
#
# Fold 124/417
# Fold RMSE: 95.49, MAE: 60.57
#
# Fold 125/417
# Fold RMSE: 50.33, MAE: 42.22
#
# Fold 126/417
# Fold RMSE: 101.10, MAE: 69.05
#
# Fold 127/417
# Fold RMSE: 70.90, MAE: 52.29
#
# Fold 128/417
# Fold RMSE: 128.85, MAE: 99.38
#
# Fold 129/417
# Fold RMSE: 82.91, MAE: 71.64
#
# Fold 130/417
# Fold RMSE: 76.87, MAE: 63.00
#
# Fold 131/417
# Fold RMSE: 105.68, MAE: 93.73
#
# Fold 132/417
# Fold RMSE: 83.82, MAE: 64.61
#
# Fold 133/417
# Fold RMSE: 55.56, MAE: 50.15
#
# Fold 134/417
# Fold RMSE: 68.28, MAE: 58.48
#
# Fold 135/417
# Fold RMSE: 67.82, MAE: 57.19
#
# Fold 136/417
# Fold RMSE: 46.97, MAE: 40.76
#
# Fold 137/417
# Fold RMSE: 142.00, MAE: 91.43
#
# Fold 138/417
# Fold RMSE: 65.41, MAE: 47.92
#
# Fold 139/417
# Fold RMSE: 83.83, MAE: 60.61
#
# Fold 140/417
# Fold RMSE: 83.87, MAE: 75.14
#
# Fold 141/417
# Fold RMSE: 72.29, MAE: 51.10
#
# Fold 142/417
# Fold RMSE: 94.43, MAE: 71.91
#
# Fold 143/417
# Fold RMSE: 76.99, MAE: 68.20
#
# Fold 144/417
# Fold RMSE: 82.71, MAE: 67.84
#
# Fold 145/417
# Fold RMSE: 97.53, MAE: 79.56
#
# Fold 146/417
# Fold RMSE: 145.08, MAE: 120.47
#
# Fold 147/417
# Fold RMSE: 76.80, MAE: 64.80
#
# Fold 148/417
# Fold RMSE: 94.73, MAE: 71.99
#
# Fold 149/417
# Fold RMSE: 94.87, MAE: 75.60
#
# Fold 150/417
# Fold RMSE: 65.67, MAE: 55.68
#
# Fold 151/417
# Fold RMSE: 84.07, MAE: 59.45
#
# Fold 152/417
# Fold RMSE: 86.08, MAE: 65.60
#
# Fold 153/417
# Fold RMSE: 74.90, MAE: 53.19
#
# Fold 154/417
# Fold RMSE: 153.54, MAE: 112.74
#
# Fold 155/417
# Fold RMSE: 77.91, MAE: 54.08
#
# Fold 156/417
# Fold RMSE: 42.67, MAE: 28.63
#
# Fold 157/417
# Fold RMSE: 92.60, MAE: 73.90
#
# Fold 158/417
# Fold RMSE: 72.91, MAE: 54.28
#
# Fold 159/417
# Fold RMSE: 81.89, MAE: 72.58
#
# Fold 160/417
# Fold RMSE: 43.32, MAE: 39.08
#
# Fold 161/417
# Fold RMSE: 46.49, MAE: 22.70
#
# Fold 162/417
# Fold RMSE: 103.20, MAE: 76.37
#
# Fold 163/417
# Fold RMSE: 142.76, MAE: 132.88
#
# Fold 164/417
# Fold RMSE: 164.46, MAE: 152.57
#
# Fold 165/417
# Fold RMSE: 139.92, MAE: 115.94
#
# Fold 166/417
# Fold RMSE: 121.38, MAE: 95.63
#
# Fold 167/417
# Fold RMSE: 136.48, MAE: 122.45
#
# Fold 168/417
# Fold RMSE: 103.54, MAE: 81.05
#
# Fold 169/417
# Fold RMSE: 70.78, MAE: 59.84
#
# Fold 170/417
# Fold RMSE: 116.26, MAE: 103.77
#
# Fold 171/417
# Fold RMSE: 118.15, MAE: 97.29
#
# Fold 172/417
# Fold RMSE: 137.27, MAE: 109.11
#
# Fold 173/417
# Fold RMSE: 112.80, MAE: 97.41
#
# Fold 174/417
# Fold RMSE: 66.33, MAE: 54.10
#
# Fold 175/417
# Fold RMSE: 68.18, MAE: 57.77
#
# Fold 176/417
# Fold RMSE: 68.79, MAE: 56.96
#
# Fold 177/417
# Fold RMSE: 79.85, MAE: 57.03
#
# Fold 178/417
# Fold RMSE: 94.18, MAE: 76.74
#
# Fold 179/417
# Fold RMSE: 97.91, MAE: 77.22
#
# Fold 180/417
# Fold RMSE: 85.82, MAE: 66.82
#
# Fold 181/417
# Fold RMSE: 106.97, MAE: 85.99
#
# Fold 182/417
# Fold RMSE: 80.14, MAE: 58.45
#
# Fold 183/417
# Fold RMSE: 122.43, MAE: 93.88
#
# Fold 184/417
# Fold RMSE: 203.67, MAE: 164.25
#
# Fold 185/417
# Fold RMSE: 115.30, MAE: 93.63
#
# Fold 186/417
# Fold RMSE: 111.64, MAE: 88.44
#
# Fold 187/417
# Fold RMSE: 146.10, MAE: 122.34
#
# Fold 188/417
# Fold RMSE: 61.21, MAE: 51.82
#
# Fold 189/417
# Fold RMSE: 55.88, MAE: 46.53
#
# Fold 190/417
# Fold RMSE: 78.41, MAE: 64.13
#
# Fold 191/417
# Fold RMSE: 133.50, MAE: 102.19
#
# Fold 192/417
# Fold RMSE: 92.19, MAE: 77.06
#
# Fold 193/417
# Fold RMSE: 103.35, MAE: 82.98
#
# Fold 194/417
# Fold RMSE: 205.88, MAE: 137.83
#
# Fold 195/417
# Fold RMSE: 170.79, MAE: 123.00
#
# Fold 196/417
# Fold RMSE: 178.23, MAE: 144.43
#
# Fold 197/417
# Fold RMSE: 126.84, MAE: 108.40
#
# Fold 198/417
# Fold RMSE: 129.09, MAE: 98.31
#
# Fold 199/417
# Fold RMSE: 141.96, MAE: 123.82
#
# Fold 200/417
# Fold RMSE: 130.80, MAE: 115.04
#
# Fold 201/417
# Fold RMSE: 157.60, MAE: 149.52
#
# Fold 202/417
# Fold RMSE: 136.61, MAE: 117.25
#
# Fold 203/417
# Fold RMSE: 240.41, MAE: 218.67
#
# Fold 204/417
# Fold RMSE: 208.15, MAE: 189.00
#
# Fold 205/417
# Fold RMSE: 216.99, MAE: 182.44
#
# Fold 206/417
# Fold RMSE: 225.46, MAE: 172.13
#
# Fold 207/417
# Fold RMSE: 132.69, MAE: 110.80
#
# Fold 208/417
# Fold RMSE: 109.63, MAE: 92.28
#
# Fold 209/417
# Fold RMSE: 182.80, MAE: 151.08
#
# Fold 210/417
# Fold RMSE: 159.61, MAE: 124.76
#
# Fold 211/417
# Fold RMSE: 217.83, MAE: 195.39
#
# Fold 212/417
# Fold RMSE: 255.67, MAE: 233.70
#
# Fold 213/417
# Fold RMSE: 192.55, MAE: 174.39
#
# Fold 214/417
# Fold RMSE: 77.01, MAE: 64.67
#
# Fold 215/417
# Fold RMSE: 195.66, MAE: 147.48
#
# Fold 216/417
# Fold RMSE: 148.27, MAE: 134.89
#
# Fold 217/417
# Fold RMSE: 113.21, MAE: 99.43
#
# Fold 218/417
# Fold RMSE: 150.30, MAE: 131.52
#
# Fold 219/417
# Fold RMSE: 173.53, MAE: 137.64
#
# Fold 220/417
# Fold RMSE: 224.13, MAE: 201.21
#
# Fold 221/417
# Fold RMSE: 137.60, MAE: 112.25
#
# Fold 222/417
# Fold RMSE: 163.74, MAE: 115.68
#
# Fold 223/417
# Fold RMSE: 184.49, MAE: 129.05
#
# Fold 224/417
# Fold RMSE: 223.47, MAE: 190.08
#
# Fold 225/417
# Fold RMSE: 145.87, MAE: 106.75
#
# Fold 226/417
# Fold RMSE: 147.05, MAE: 114.62
#
# Fold 227/417
# Fold RMSE: 179.02, MAE: 131.09
#
# Fold 228/417
# Fold RMSE: 216.80, MAE: 140.36
#
# Fold 229/417
# Fold RMSE: 189.49, MAE: 142.47
#
# Fold 230/417
# Fold RMSE: 234.61, MAE: 210.22
#
# Fold 231/417
# Fold RMSE: 164.68, MAE: 124.34
#
# Fold 232/417
# Fold RMSE: 94.78, MAE: 78.68
#
# Fold 233/417
# Fold RMSE: 259.03, MAE: 174.64
#
# Fold 234/417
# Fold RMSE: 141.22, MAE: 107.60
#
# Fold 235/417
# Fold RMSE: 128.84, MAE: 95.52
#
# Fold 236/417
# Fold RMSE: 134.33, MAE: 110.99
#
# Fold 237/417
# Fold RMSE: 125.95, MAE: 102.04
#
# Fold 238/417
# Fold RMSE: 194.83, MAE: 150.40
#
# Fold 239/417
# Fold RMSE: 227.02, MAE: 174.24
#
# Fold 240/417
# Fold RMSE: 244.76, MAE: 195.43
#
# Fold 241/417
# Fold RMSE: 261.56, MAE: 203.73
#
# Fold 242/417
# Fold RMSE: 235.36, MAE: 195.58
#
# Fold 243/417
# Fold RMSE: 147.38, MAE: 127.86
#
# Fold 244/417
# Fold RMSE: 179.49, MAE: 138.27
#
# Fold 245/417
# Fold RMSE: 192.63, MAE: 152.41
#
# Fold 246/417
# Fold RMSE: 236.40, MAE: 201.67
#
# Fold 247/417
# Fold RMSE: 392.59, MAE: 331.16
#
# Fold 248/417
# Fold RMSE: 369.17, MAE: 275.10
#
# Fold 249/417
# Fold RMSE: 898.23, MAE: 716.76
#
# Fold 250/417
# Fold RMSE: 792.20, MAE: 708.08
#
# Fold 251/417
# Fold RMSE: 491.72, MAE: 374.45
#
# Fold 252/417
# Fold RMSE: 468.45, MAE: 355.39
#
# Fold 253/417
# Fold RMSE: 566.97, MAE: 390.59
#
# Fold 254/417
# Fold RMSE: 535.38, MAE: 446.04
#
# Fold 255/417
# Fold RMSE: 565.80, MAE: 490.81
#
# Fold 256/417
# Fold RMSE: 752.68, MAE: 555.50
#
# Fold 257/417
# Fold RMSE: 587.42, MAE: 456.19
#
# Fold 258/417
# Fold RMSE: 627.76, MAE: 481.86
#
# Fold 259/417
# Fold RMSE: 690.00, MAE: 597.04
#
# Fold 260/417
# Fold RMSE: 1184.39, MAE: 941.20
#
# Fold 261/417
# Fold RMSE: 771.21, MAE: 633.30
#
# Fold 262/417
# Fold RMSE: 643.54, MAE: 522.94
#
# Fold 263/417
# Fold RMSE: 644.38, MAE: 503.07
#
# Fold 264/417
# Fold RMSE: 491.79, MAE: 407.19
#
# Fold 265/417
# Fold RMSE: 428.90, MAE: 300.22
#
# Fold 266/417
# Fold RMSE: 515.42, MAE: 414.90
#
# Fold 267/417
# Fold RMSE: 458.54, MAE: 333.37
#
# Fold 268/417
# Fold RMSE: 577.15, MAE: 539.88
#
# Fold 269/417
# Fold RMSE: 317.27, MAE: 220.59
#
# Fold 270/417
# Fold RMSE: 1214.61, MAE: 1047.54
#
# Fold 271/417
# Fold RMSE: 1124.10, MAE: 860.49
#
# Fold 272/417
# Fold RMSE: 859.97, MAE: 735.20
#
# Fold 273/417
# Fold RMSE: 641.36, MAE: 456.34
#
# Fold 274/417
# Fold RMSE: 475.32, MAE: 350.18
#
# Fold 275/417
# Fold RMSE: 578.62, MAE: 463.92
#
# Fold 276/417
# Fold RMSE: 713.87, MAE: 645.00
#
# Fold 277/417
# Fold RMSE: 495.63, MAE: 353.58
#
# Fold 278/417
# Fold RMSE: 522.11, MAE: 433.97
#
# Fold 279/417
# Fold RMSE: 241.17, MAE: 206.94
#
# Fold 280/417
# Fold RMSE: 554.00, MAE: 429.15
#
# Fold 281/417
# Fold RMSE: 527.48, MAE: 460.26
#
# Fold 282/417
# Fold RMSE: 794.93, MAE: 639.71
#
# Fold 283/417
# Fold RMSE: 1077.22, MAE: 1016.94
#
# Fold 284/417
# Fold RMSE: 366.83, MAE: 250.27
#
# Fold 285/417
# Fold RMSE: 502.18, MAE: 379.11
#
# Fold 286/417
# Fold RMSE: 674.82, MAE: 522.53
#
# Fold 287/417
# Fold RMSE: 623.69, MAE: 486.17
#
# Fold 288/417
# Fold RMSE: 852.99, MAE: 759.26
#
# Fold 289/417
# Fold RMSE: 1057.65, MAE: 907.65
#
# Fold 290/417
# Fold RMSE: 1094.00, MAE: 908.93
#
# Fold 291/417
# Fold RMSE: 987.03, MAE: 831.66
#
# Fold 292/417
# Fold RMSE: 1022.20, MAE: 825.80
#
# Fold 293/417
# Fold RMSE: 794.33, MAE: 640.07
#
# Fold 294/417
# Fold RMSE: 873.80, MAE: 686.16
#
# Fold 295/417
# Fold RMSE: 1069.25, MAE: 820.12
#
# Fold 296/417
# Fold RMSE: 1520.47, MAE: 1160.41
#
# Fold 297/417
# Fold RMSE: 1146.99, MAE: 886.96
#
# Fold 298/417
# Fold RMSE: 795.23, MAE: 585.99
#
# Fold 299/417
# Fold RMSE: 1214.94, MAE: 1095.91
#
# Fold 300/417
# Fold RMSE: 866.30, MAE: 668.53
#
# Fold 301/417
# Fold RMSE: 1739.69, MAE: 1618.59
#
# Fold 302/417
# Fold RMSE: 1447.85, MAE: 1230.84
#
# Fold 303/417
# Fold RMSE: 873.72, MAE: 810.49
#
# Fold 304/417
# Fold RMSE: 441.92, MAE: 388.51
#
# Fold 305/417
# Fold RMSE: 317.17, MAE: 250.47
#
# Fold 306/417
# Fold RMSE: 527.10, MAE: 490.10
#
# Fold 307/417
# Fold RMSE: 790.28, MAE: 654.05
#
# Fold 308/417
# Fold RMSE: 968.22, MAE: 838.06
#
# Fold 309/417
# Fold RMSE: 901.28, MAE: 732.43
#
# Fold 310/417
# Fold RMSE: 674.57, MAE: 599.17
#
# Fold 311/417
# Fold RMSE: 781.78, MAE: 705.01
#
# Fold 312/417
# Fold RMSE: 1621.00, MAE: 1582.05
#
# Fold 313/417
# Fold RMSE: 997.81, MAE: 925.67
#
# Fold 314/417
# Fold RMSE: 681.19, MAE: 559.85
#
# Fold 315/417
# Fold RMSE: 421.81, MAE: 330.28
#
# Fold 316/417
# Fold RMSE: 535.48, MAE: 483.36
#
# Fold 317/417
# Fold RMSE: 295.51, MAE: 258.06
#
# Fold 318/417
# Fold RMSE: 501.02, MAE: 461.69
#
# Fold 319/417
# Fold RMSE: 326.11, MAE: 258.26
#
# Fold 320/417
# Fold RMSE: 374.85, MAE: 295.65
#
# Fold 321/417
# Fold RMSE: 298.26, MAE: 231.05
#
# Fold 322/417
# Fold RMSE: 331.42, MAE: 271.51
#
# Fold 323/417
# Fold RMSE: 193.79, MAE: 155.70
#
# Fold 324/417
# Fold RMSE: 349.61, MAE: 267.03
#
# Fold 325/417
# Fold RMSE: 254.12, MAE: 190.59
#
# Fold 326/417
# Fold RMSE: 362.73, MAE: 317.22
#
# Fold 327/417
# Fold RMSE: 301.90, MAE: 249.74
#
# Fold 328/417
# Fold RMSE: 353.46, MAE: 247.13
#
# Fold 329/417
# Fold RMSE: 281.92, MAE: 208.94
#
# Fold 330/417
# Fold RMSE: 215.46, MAE: 153.35
#
# Fold 331/417
# Fold RMSE: 278.36, MAE: 198.79
#
# Fold 332/417
# Fold RMSE: 237.57, MAE: 188.20
#
# Fold 333/417
# Fold RMSE: 332.28, MAE: 250.86
#
# Fold 334/417
# Fold RMSE: 334.18, MAE: 257.21
#
# Fold 335/417
# Fold RMSE: 358.58, MAE: 250.51
#
# Fold 336/417
# Fold RMSE: 243.91, MAE: 162.12
#
# Fold 337/417
# Fold RMSE: 315.61, MAE: 236.31
#
# Fold 338/417
# Fold RMSE: 243.69, MAE: 194.59
#
# Fold 339/417
# Fold RMSE: 301.68, MAE: 220.06
#
# Fold 340/417
# Fold RMSE: 717.34, MAE: 492.02
#
# Fold 341/417
# Fold RMSE: 251.91, MAE: 197.90
#
# Fold 342/417
# Fold RMSE: 434.92, MAE: 350.95
#
# Fold 343/417
# Fold RMSE: 296.06, MAE: 231.24
#
# Fold 344/417
# Fold RMSE: 355.69, MAE: 288.48
#
# Fold 345/417
# Fold RMSE: 359.34, MAE: 317.78
#
# Fold 346/417
# Fold RMSE: 245.63, MAE: 176.30
#
# Fold 347/417
# Fold RMSE: 388.58, MAE: 273.79
#
# Fold 348/417
# Fold RMSE: 217.30, MAE: 188.65
#
# Fold 349/417
# Fold RMSE: 254.81, MAE: 194.46
#
# Fold 350/417
# Fold RMSE: 435.13, MAE: 237.26
#
# Fold 351/417
# Fold RMSE: 624.45, MAE: 530.81
#
# Fold 352/417
# Fold RMSE: 511.22, MAE: 379.77
#
# Fold 353/417
# Fold RMSE: 446.85, MAE: 410.95
#
# Fold 354/417
# Fold RMSE: 492.45, MAE: 371.33
#
# Fold 355/417
# Fold RMSE: 403.20, MAE: 314.20
#
# Fold 356/417
# Fold RMSE: 526.47, MAE: 452.15
#
# Fold 357/417
# Fold RMSE: 443.09, MAE: 383.91
#
# Fold 358/417
# Fold RMSE: 303.09, MAE: 254.15
#
# Fold 359/417
# Fold RMSE: 202.07, MAE: 152.82
#
# Fold 360/417
# Fold RMSE: 443.56, MAE: 369.40
#
# Fold 361/417
# Fold RMSE: 631.83, MAE: 543.82
#
# Fold 362/417
# Fold RMSE: 394.25, MAE: 366.13
#
# Fold 363/417
# Fold RMSE: 242.68, MAE: 193.75
#
# Fold 364/417
# Fold RMSE: 378.10, MAE: 347.70
#
# Fold 365/417
# Fold RMSE: 185.79, MAE: 159.58
#
# Fold 366/417
# Fold RMSE: 357.93, MAE: 295.67
#
# Fold 367/417
# Fold RMSE: 150.63, MAE: 117.45
#
# Fold 368/417
# Fold RMSE: 213.13, MAE: 189.36
#
# Fold 369/417
# Fold RMSE: 253.76, MAE: 215.00
#
# Fold 370/417
# Fold RMSE: 113.47, MAE: 89.29
#
# Fold 371/417
# Fold RMSE: 222.96, MAE: 177.94
#
# Fold 372/417
# Fold RMSE: 88.77, MAE: 74.16
#
# Fold 373/417
# Fold RMSE: 135.31, MAE: 96.38
#
# Fold 374/417
# Fold RMSE: 180.38, MAE: 149.57
#
# Fold 375/417
# Fold RMSE: 119.74, MAE: 85.35
#
# Fold 376/417
# Fold RMSE: 182.81, MAE: 138.89
#
# Fold 377/417
# Fold RMSE: 209.80, MAE: 147.62
#
# Fold 378/417
# Fold RMSE: 214.16, MAE: 157.05
#
# Fold 379/417
# Fold RMSE: 181.87, MAE: 141.01
#
# Fold 380/417
# Fold RMSE: 252.57, MAE: 195.25
#
# Fold 381/417
# Fold RMSE: 366.75, MAE: 302.22
#
# Fold 382/417
# Fold RMSE: 253.37, MAE: 192.68
#
# Fold 383/417
# Fold RMSE: 415.94, MAE: 358.63
#
# Fold 384/417
# Fold RMSE: 330.92, MAE: 296.48
#
# Fold 385/417
# Fold RMSE: 375.03, MAE: 343.44
#
# Fold 386/417
# Fold RMSE: 441.72, MAE: 372.45
#
# Fold 387/417
# Fold RMSE: 305.58, MAE: 228.74
#
# Fold 388/417
# Fold RMSE: 331.90, MAE: 271.47
#
# Fold 389/417
# Fold RMSE: 346.29, MAE: 289.33
#
# Fold 390/417
# Fold RMSE: 342.35, MAE: 273.96
#
# Fold 391/417
# Fold RMSE: 391.86, MAE: 310.07
#
# Fold 392/417
# Fold RMSE: 313.92, MAE: 268.22
#
# Fold 393/417
# Fold RMSE: 438.39, MAE: 361.95
#
# Fold 394/417
# Fold RMSE: 379.27, MAE: 304.29
#
# Fold 395/417
# Fold RMSE: 304.42, MAE: 230.49
#
# Fold 396/417
# Fold RMSE: 325.23, MAE: 232.87
#
# Fold 397/417
# Fold RMSE: 392.65, MAE: 302.42
#
# Fold 398/417
# Fold RMSE: 527.08, MAE: 441.03
#
# Fold 399/417
# Fold RMSE: 460.61, MAE: 374.86
#
# Fold 400/417
# Fold RMSE: 572.53, MAE: 472.42
#
# Fold 401/417
# Fold RMSE: 468.00, MAE: 339.22
#
# Fold 402/417
# Fold RMSE: 414.14, MAE: 343.43
#
# Fold 403/417
# Fold RMSE: 299.80, MAE: 216.17
#
# Fold 404/417
# Fold RMSE: 376.56, MAE: 286.28
#
# Fold 405/417
# Fold RMSE: 359.66, MAE: 291.45
#
# Fold 406/417
# Fold RMSE: 306.46, MAE: 258.34
#
# Fold 407/417
# Fold RMSE: 365.37, MAE: 291.48
#
# Fold 408/417
# Fold RMSE: 352.26, MAE: 261.13
#
# Fold 409/417
# Fold RMSE: 442.63, MAE: 331.18
#
# Fold 410/417
# Fold RMSE: 980.52, MAE: 805.72
#
# Fold 411/417
# Fold RMSE: 336.74, MAE: 230.93
#
# Fold 412/417
# Fold RMSE: 357.33, MAE: 297.56
#
# Fold 413/417
# Fold RMSE: 503.72, MAE: 423.52
#
# Fold 414/417
# Fold RMSE: 419.47, MAE: 333.12
#
# Fold 415/417
# Fold RMSE: 1327.69, MAE: 752.92
#
# Fold 416/417
# Fold RMSE: 1565.97, MAE: 1554.34
#
# Fold 417/417
# Fold RMSE: 471.70, MAE: 400.79
#
# Overall RMSE: 404.23
# Overall MAE: 226.66
# Average fold RMSE: 280.35 (+/- 291.22)
# Average fold MAE: 226.66 (+/- 248.77)
#
# Total folds: 417
# Training winow: 8760 hours
# Forecast horizon: 168 hours
# Fold 1/417
# Fold RMSE: 94.46, MAE: 63.90
#
# Fold 2/417
# Fold RMSE: 101.98, MAE: 88.25
#
# Fold 3/417
# Fold RMSE: 107.59, MAE: 67.49
#
# Fold 4/417
# Fold RMSE: 75.56, MAE: 38.71
#
# Fold 5/417
# Fold RMSE: 62.18, MAE: 59.57
#
# Fold 6/417
# Fold RMSE: 78.62, MAE: 60.00
#
# Fold 7/417
# Fold RMSE: 68.60, MAE: 63.54
#
# Fold 8/417
# Fold RMSE: 89.63, MAE: 48.28
#
# Fold 9/417
# Fold RMSE: 56.89, MAE: 41.41
#
# Fold 10/417
# Fold RMSE: 58.97, MAE: 35.04
#
# Fold 11/417
# Fold RMSE: 57.14, MAE: 33.12
#
# Fold 12/417
# Fold RMSE: 58.25, MAE: 47.25
#
# Fold 13/417
# Fold RMSE: 40.08, MAE: 32.07
#
# Fold 14/417
# Fold RMSE: 54.39, MAE: 42.01
#
# Fold 15/417
# Fold RMSE: 47.89, MAE: 32.44
#
# Fold 16/417
# Fold RMSE: 51.51, MAE: 31.11
#
# Fold 17/417
# Fold RMSE: 113.56, MAE: 103.83
#
# Fold 18/417
# Fold RMSE: 102.04, MAE: 65.49
#
# Fold 19/417
# Fold RMSE: 39.01, MAE: 27.76
#
# Fold 20/417
# Fold RMSE: 33.87, MAE: 27.58
#
# Fold 21/417
# Fold RMSE: 58.78, MAE: 50.23
#
# Fold 22/417
# Fold RMSE: 60.86, MAE: 52.22
#
# Fold 23/417
# Fold RMSE: 92.43, MAE: 77.44
#
# Fold 24/417
# Fold RMSE: 70.35, MAE: 58.69
#
# Fold 25/417
# Fold RMSE: 77.05, MAE: 60.49
#
# Fold 26/417
# Fold RMSE: 65.18, MAE: 54.36
#
# Fold 27/417
# Fold RMSE: 58.97, MAE: 47.26
#
# Fold 28/417
# Fold RMSE: 50.99, MAE: 44.16
#
# Fold 29/417
# Fold RMSE: 55.42, MAE: 47.84
#
# Fold 30/417
# Fold RMSE: 47.58, MAE: 40.81
#
# Fold 31/417
# Fold RMSE: 46.70, MAE: 40.54
#
# Fold 32/417
# Fold RMSE: 68.32, MAE: 50.47
#
# Fold 33/417
# Fold RMSE: 72.76, MAE: 58.24
#
# Fold 34/417
# Fold RMSE: 124.37, MAE: 85.56
#
# Fold 35/417
# Fold RMSE: 69.03, MAE: 52.25
#
# Fold 36/417
# Fold RMSE: 77.99, MAE: 62.61
#
# Fold 37/417
# Fold RMSE: 57.97, MAE: 48.15
#
# Fold 38/417
# Fold RMSE: 57.07, MAE: 49.30
#
# Fold 39/417
# Fold RMSE: 57.96, MAE: 51.31
#
# Fold 40/417
# Fold RMSE: 115.12, MAE: 94.23
#
# Fold 41/417
# Fold RMSE: 83.67, MAE: 60.93
#
# Fold 42/417
# Fold RMSE: 97.37, MAE: 75.14
#
# Fold 43/417
# Fold RMSE: 70.07, MAE: 60.74
#
# Fold 44/417
# Fold RMSE: 137.37, MAE: 96.72
#
# Fold 45/417
# Fold RMSE: 138.66, MAE: 123.70
#
# Fold 46/417
# Fold RMSE: 89.02, MAE: 55.06
#
# Fold 47/417
# Fold RMSE: 112.70, MAE: 79.68
#
# Fold 48/417
# Fold RMSE: 113.11, MAE: 76.45
#
# Fold 49/417
# Fold RMSE: 126.08, MAE: 116.86
#
# Fold 50/417
# Fold RMSE: 98.09, MAE: 75.96
#
# Fold 51/417
# Fold RMSE: 105.72, MAE: 82.76
#
# Fold 52/417
# Fold RMSE: 167.10, MAE: 116.73
#
# Fold 53/417
# Fold RMSE: 75.28, MAE: 50.85
#
# Fold 54/417
# Fold RMSE: 73.86, MAE: 63.86
#
# Fold 55/417
# Fold RMSE: 87.81, MAE: 65.34
#
# Fold 56/417
# Fold RMSE: 88.62, MAE: 70.17
#
# Fold 57/417
# Fold RMSE: 125.90, MAE: 92.83
#
# Fold 58/417
# Fold RMSE: 102.83, MAE: 71.48
#
# Fold 59/417
# Fold RMSE: 91.64, MAE: 72.54
#
# Fold 60/417
# Fold RMSE: 92.64, MAE: 66.69
#
# Fold 61/417
# Fold RMSE: 244.37, MAE: 116.14
#
# Fold 62/417
# Fold RMSE: 168.53, MAE: 157.83
#
# Fold 63/417
# Fold RMSE: 77.20, MAE: 54.92
#
# Fold 64/417
# Fold RMSE: 128.26, MAE: 84.00
#
# Fold 65/417
# Fold RMSE: 66.67, MAE: 54.71
#
# Fold 66/417
# Fold RMSE: 52.27, MAE: 33.36
#
# Fold 67/417
# Fold RMSE: 80.97, MAE: 57.56
#
# Fold 68/417
# Fold RMSE: 59.92, MAE: 46.00
#
# Fold 69/417
# Fold RMSE: 58.55, MAE: 42.92
#
# Fold 70/417
# Fold RMSE: 109.00, MAE: 67.30
#
# Fold 71/417
# Fold RMSE: 150.28, MAE: 125.96
#
# Fold 72/417
# Fold RMSE: 211.19, MAE: 117.97
#
# Fold 73/417
# Fold RMSE: 131.72, MAE: 87.83
#
# Fold 74/417
# Fold RMSE: 68.75, MAE: 49.87
#
# Fold 75/417
# Fold RMSE: 67.44, MAE: 59.97
#
# Fold 76/417
# Fold RMSE: 222.56, MAE: 98.93
#
# Fold 77/417
# Fold RMSE: 85.81, MAE: 63.28
#
# Fold 78/417
# Fold RMSE: 166.59, MAE: 129.37
#
# Fold 79/417
# Fold RMSE: 51.75, MAE: 39.14
#
# Fold 80/417
# Fold RMSE: 36.63, MAE: 29.29
#
# Fold 81/417
# Fold RMSE: 34.62, MAE: 26.13
#
# Fold 82/417
# Fold RMSE: 63.05, MAE: 41.16
#
# Fold 83/417
# Fold RMSE: 78.95, MAE: 62.11
#
# Fold 84/417
# Fold RMSE: 134.23, MAE: 114.29
#
# Fold 85/417
# Fold RMSE: 78.08, MAE: 63.15
#
# Fold 86/417
# Fold RMSE: 74.86, MAE: 67.53
#
# Fold 87/417
# Fold RMSE: 83.69, MAE: 65.59
#
# Fold 88/417
# Fold RMSE: 62.38, MAE: 56.79
#
# Fold 89/417
# Fold RMSE: 76.53, MAE: 70.45
#
# Fold 90/417
# Fold RMSE: 141.41, MAE: 120.52
#
# Fold 91/417
# Fold RMSE: 108.22, MAE: 79.40
#
# Fold 92/417
# Fold RMSE: 152.45, MAE: 118.65
#
# Fold 93/417
# Fold RMSE: 119.48, MAE: 102.08
#
# Fold 94/417
# Fold RMSE: 182.89, MAE: 147.08
#
# Fold 95/417
# Fold RMSE: 191.84, MAE: 162.27
#
# Fold 96/417
# Fold RMSE: 100.82, MAE: 83.76
#
# Fold 97/417
# Fold RMSE: 105.24, MAE: 83.06
#
# Fold 98/417
# Fold RMSE: 103.87, MAE: 93.29
#
# Fold 99/417
# Fold RMSE: 138.63, MAE: 102.73
#
# Fold 100/417
# Fold RMSE: 202.73, MAE: 186.46
#
# Fold 101/417
# Fold RMSE: 80.07, MAE: 52.94
#
# Fold 102/417
# Fold RMSE: 196.09, MAE: 154.90
#
# Fold 103/417
# Fold RMSE: 122.98, MAE: 110.26
#
# Fold 104/417
# Fold RMSE: 117.75, MAE: 63.77
#
# Fold 105/417
# Fold RMSE: 231.68, MAE: 133.83
#
# Fold 106/417
# Fold RMSE: 118.44, MAE: 78.08
#
# Fold 107/417
# Fold RMSE: 124.08, MAE: 73.50
#
# Fold 108/417
# Fold RMSE: 116.05, MAE: 83.52
#
# Fold 109/417
# Fold RMSE: 121.72, MAE: 104.50
#
# Fold 110/417
# Fold RMSE: 75.19, MAE: 53.93
#
# Fold 111/417
# Fold RMSE: 130.08, MAE: 87.42
#
# Fold 112/417
# Fold RMSE: 50.28, MAE: 42.63
#
# Fold 113/417
# Fold RMSE: 50.27, MAE: 43.13
#
# Fold 114/417
# Fold RMSE: 126.60, MAE: 74.48
#
# Fold 115/417
# Fold RMSE: 123.56, MAE: 90.50
#
# Fold 116/417
# Fold RMSE: 125.81, MAE: 80.80
#
# Fold 117/417
# Fold RMSE: 47.79, MAE: 36.91
#
# Fold 118/417
# Fold RMSE: 68.17, MAE: 49.87
#
# Fold 119/417
# Fold RMSE: 37.98, MAE: 28.32
#
# Fold 120/417
# Fold RMSE: 46.67, MAE: 38.52
#
# Fold 121/417
# Fold RMSE: 127.90, MAE: 74.80
#
# Fold 122/417
# Fold RMSE: 96.93, MAE: 68.73
#
# Fold 123/417
# Fold RMSE: 67.36, MAE: 52.90
#
# Fold 124/417
# Fold RMSE: 102.15, MAE: 68.96
#
# Fold 125/417
# Fold RMSE: 51.21, MAE: 43.23
#
# Fold 126/417
# Fold RMSE: 105.10, MAE: 74.16
#
# Fold 127/417
# Fold RMSE: 71.18, MAE: 52.55
#
# Fold 128/417
# Fold RMSE: 127.74, MAE: 102.35
#
# Fold 129/417
# Fold RMSE: 82.47, MAE: 70.99
#
# Fold 130/417
# Fold RMSE: 82.25, MAE: 65.87
#
# Fold 131/417
# Fold RMSE: 108.57, MAE: 100.89
#
# Fold 132/417
# Fold RMSE: 80.60, MAE: 61.02
#
# Fold 133/417
# Fold RMSE: 55.17, MAE: 49.90
#
# Fold 134/417
# Fold RMSE: 67.21, MAE: 57.52
#
# Fold 135/417
# Fold RMSE: 66.71, MAE: 56.42
#
# Fold 136/417
# Fold RMSE: 44.51, MAE: 39.07
#
# Fold 137/417
# Fold RMSE: 71.15, MAE: 53.48
#
# Fold 138/417
# Fold RMSE: 58.95, MAE: 40.51
#
# Fold 139/417
# Fold RMSE: 80.78, MAE: 60.15
#
# Fold 140/417
# Fold RMSE: 71.07, MAE: 60.45
#
# Fold 141/417
# Fold RMSE: 62.81, MAE: 44.58
#
# Fold 142/417
# Fold RMSE: 82.53, MAE: 64.53
#
# Fold 143/417
# Fold RMSE: 70.59, MAE: 62.49
#
# Fold 144/417
# Fold RMSE: 83.06, MAE: 67.32
#
# Fold 145/417
# Fold RMSE: 104.96, MAE: 94.80
#
# Fold 146/417
# Fold RMSE: 111.02, MAE: 79.16
#
# Fold 147/417
# Fold RMSE: 75.16, MAE: 63.97
#
# Fold 148/417
# Fold RMSE: 90.79, MAE: 63.44
#
# Fold 149/417
# Fold RMSE: 82.81, MAE: 61.61
#
# Fold 150/417
# Fold RMSE: 57.92, MAE: 51.40
#
# Fold 151/417
# Fold RMSE: 68.86, MAE: 51.83
#
# Fold 152/417
# Fold RMSE: 79.95, MAE: 59.62
#
# Fold 153/417
# Fold RMSE: 77.05, MAE: 54.87
#
# Fold 154/417
# Fold RMSE: 133.13, MAE: 97.17
#
# Fold 155/417
# Fold RMSE: 67.64, MAE: 42.66
#
# Fold 156/417
# Fold RMSE: 30.29, MAE: 19.65
#
# Fold 157/417
# Fold RMSE: 91.85, MAE: 71.31
#
# Fold 158/417
# Fold RMSE: 70.62, MAE: 46.64
#
# Fold 159/417
# Fold RMSE: 79.37, MAE: 72.29
#
# Fold 160/417
# Fold RMSE: 100.42, MAE: 78.92
#
# Fold 161/417
# Fold RMSE: 42.07, MAE: 32.44
#
# Fold 162/417
# Fold RMSE: 97.72, MAE: 73.16
#
# Fold 163/417
# Fold RMSE: 137.80, MAE: 129.20
#
# Fold 164/417
# Fold RMSE: 152.34, MAE: 143.87
#
# Fold 165/417
# Fold RMSE: 148.02, MAE: 109.62
#
# Fold 166/417
# Fold RMSE: 113.66, MAE: 90.97
#
# Fold 167/417
# Fold RMSE: 133.03, MAE: 117.58
#
# Fold 168/417
# Fold RMSE: 99.06, MAE: 77.97
#
# Fold 169/417
# Fold RMSE: 60.21, MAE: 47.81
#
# Fold 170/417
# Fold RMSE: 96.55, MAE: 78.28
#
# Fold 171/417
# Fold RMSE: 85.05, MAE: 68.80
#
# Fold 172/417
# Fold RMSE: 130.40, MAE: 96.85
#
# Fold 173/417
# Fold RMSE: 115.19, MAE: 101.72
#
# Fold 174/417
# Fold RMSE: 67.64, MAE: 53.72
#
# Fold 175/417
# Fold RMSE: 82.93, MAE: 66.92
#
# Fold 176/417
# Fold RMSE: 67.01, MAE: 52.42
#
# Fold 177/417
# Fold RMSE: 88.97, MAE: 64.07
#
# Fold 178/417
# Fold RMSE: 105.90, MAE: 78.14
#
# Fold 179/417
# Fold RMSE: 103.46, MAE: 81.88
#
# Fold 180/417
# Fold RMSE: 89.93, MAE: 67.76
#
# Fold 181/417
# Fold RMSE: 109.19, MAE: 83.59
#
# Fold 182/417
# Fold RMSE: 176.35, MAE: 120.20
#
# Fold 183/417
# Fold RMSE: 189.23, MAE: 164.99
#
# Fold 184/417
# Fold RMSE: 170.45, MAE: 146.43
#
# Fold 185/417
# Fold RMSE: 111.87, MAE: 91.04
#
# Fold 186/417
# Fold RMSE: 102.97, MAE: 81.01
#
# Fold 187/417
# Fold RMSE: 135.88, MAE: 111.65
#
# Fold 188/417
# Fold RMSE: 55.55, MAE: 48.43
#
# Fold 189/417
# Fold RMSE: 85.57, MAE: 74.17
#
# Fold 190/417
# Fold RMSE: 194.68, MAE: 143.65
#
# Fold 191/417
# Fold RMSE: 149.79, MAE: 125.36
#
# Fold 192/417
# Fold RMSE: 100.62, MAE: 86.58
#
# Fold 193/417
# Fold RMSE: 109.82, MAE: 91.34
#
# Fold 194/417
# Fold RMSE: 182.59, MAE: 130.75
#
# Fold 195/417
# Fold RMSE: 167.10, MAE: 120.68
#
# Fold 196/417
# Fold RMSE: 177.90, MAE: 144.91
#
# Fold 197/417
# Fold RMSE: 123.60, MAE: 105.77
#
# Fold 198/417
# Fold RMSE: 128.92, MAE: 99.11
#
# Fold 199/417
# Fold RMSE: 140.72, MAE: 122.14
#
# Fold 200/417
# Fold RMSE: 123.75, MAE: 109.60
#
# Fold 201/417
# Fold RMSE: 163.06, MAE: 153.82
#
# Fold 202/417
# Fold RMSE: 239.44, MAE: 187.22
#
# Fold 203/417
# Fold RMSE: 268.64, MAE: 188.68
#
# Fold 204/417
# Fold RMSE: 242.20, MAE: 194.89
#
# Fold 205/417
# Fold RMSE: 276.75, MAE: 204.97
#
# Fold 206/417
# Fold RMSE: 221.06, MAE: 180.65
#
# Fold 207/417
# Fold RMSE: 230.73, MAE: 162.36
#
# Fold 208/417
# Fold RMSE: 125.38, MAE: 117.26
#
# Fold 209/417
# Fold RMSE: 141.76, MAE: 128.94
#
# Fold 210/417
# Fold RMSE: 158.99, MAE: 123.36
#
# Fold 211/417
# Fold RMSE: 218.43, MAE: 197.14
#
# Fold 212/417
# Fold RMSE: 258.82, MAE: 239.03
#
# Fold 213/417
# Fold RMSE: 204.29, MAE: 185.48
#
# Fold 214/417
# Fold RMSE: 254.21, MAE: 145.66
#
# Fold 215/417
# Fold RMSE: 270.90, MAE: 191.79
#
# Fold 216/417
# Fold RMSE: 267.41, MAE: 249.31
#
# Fold 217/417
# Fold RMSE: 100.47, MAE: 90.85
#
# Fold 218/417
# Fold RMSE: 150.76, MAE: 131.87
#
# Fold 219/417
# Fold RMSE: 171.35, MAE: 136.55
#
# Fold 220/417
# Fold RMSE: 182.53, MAE: 149.34
#
# Fold 221/417
# Fold RMSE: 146.82, MAE: 114.97
#
# Fold 222/417
# Fold RMSE: 155.44, MAE: 125.05
#
# Fold 223/417
# Fold RMSE: 166.21, MAE: 127.73
#
# Fold 224/417
# Fold RMSE: 225.41, MAE: 190.83
#
# Fold 225/417
# Fold RMSE: 153.68, MAE: 112.41
#
# Fold 226/417
# Fold RMSE: 156.62, MAE: 128.98
#
# Fold 227/417
# Fold RMSE: 125.57, MAE: 102.99
#
# Fold 228/417
# Fold RMSE: 172.57, MAE: 126.20
#
# Fold 229/417
# Fold RMSE: 191.38, MAE: 147.79
#
# Fold 230/417
# Fold RMSE: 218.32, MAE: 194.54
#
# Fold 231/417
# Fold RMSE: 153.89, MAE: 121.36
#
# Fold 232/417
# Fold RMSE: 98.52, MAE: 81.28
#
# Fold 233/417
# Fold RMSE: 251.26, MAE: 177.45
#
# Fold 234/417
# Fold RMSE: 144.61, MAE: 112.47
#
# Fold 235/417
# Fold RMSE: 126.74, MAE: 95.04
#
# Fold 236/417
# Fold RMSE: 131.86, MAE: 107.98
#
# Fold 237/417
# Fold RMSE: 126.25, MAE: 103.31
#
# Fold 238/417
# Fold RMSE: 185.88, MAE: 132.55
#
# Fold 239/417
# Fold RMSE: 227.31, MAE: 174.51
#
# Fold 240/417
# Fold RMSE: 239.69, MAE: 192.44
#
# Fold 241/417
# Fold RMSE: 239.33, MAE: 189.40
#
# Fold 242/417
# Fold RMSE: 213.77, MAE: 180.64
#
# Fold 243/417
# Fold RMSE: 144.14, MAE: 122.95
#
# Fold 244/417
# Fold RMSE: 169.50, MAE: 132.42
#
# Fold 245/417
# Fold RMSE: 196.05, MAE: 155.08
#
# Fold 246/417
# Fold RMSE: 250.05, MAE: 212.66
#
# Fold 247/417
# Fold RMSE: 396.02, MAE: 336.39
#
# Fold 248/417
# Fold RMSE: 448.51, MAE: 363.76
#
# Fold 249/417
# Fold RMSE: 1015.75, MAE: 839.40
#
# Fold 250/417
# Fold RMSE: 910.54, MAE: 793.26
#
# Fold 251/417
# Fold RMSE: 608.30, MAE: 476.74
#
# Fold 252/417
# Fold RMSE: 524.55, MAE: 405.43
#
# Fold 253/417
# Fold RMSE: 602.25, MAE: 446.57
#
# Fold 254/417
# Fold RMSE: 661.11, MAE: 554.40
#
# Fold 255/417
# Fold RMSE: 688.38, MAE: 582.92
#
# Fold 256/417
# Fold RMSE: 1115.43, MAE: 849.54
#
# Fold 257/417
# Fold RMSE: 576.51, MAE: 445.07
#
# Fold 258/417
# Fold RMSE: 789.25, MAE: 630.11
#
# Fold 259/417
# Fold RMSE: 907.52, MAE: 737.29
#
# Fold 260/417
# Fold RMSE: 1266.89, MAE: 1018.56
#
# Fold 261/417
# Fold RMSE: 753.68, MAE: 617.92
#
# Fold 262/417
# Fold RMSE: 642.69, MAE: 507.27
#
# Fold 263/417
# Fold RMSE: 720.43, MAE: 599.14
#
# Fold 264/417
# Fold RMSE: 540.26, MAE: 458.27
#
# Fold 265/417
# Fold RMSE: 513.78, MAE: 429.16
#
# Fold 266/417
# Fold RMSE: 569.88, MAE: 474.05
#
# Fold 267/417
# Fold RMSE: 525.91, MAE: 394.18
#
# Fold 268/417
# Fold RMSE: 810.94, MAE: 745.38
#
# Fold 269/417
# Fold RMSE: 355.71, MAE: 307.01
#
# Fold 270/417
# Fold RMSE: 1321.70, MAE: 1175.17
#
# Fold 271/417
# Fold RMSE: 1173.74, MAE: 879.59
#
# Fold 272/417
# Fold RMSE: 953.84, MAE: 806.96
#
# Fold 273/417
# Fold RMSE: 702.43, MAE: 506.31
#
# Fold 274/417
# Fold RMSE: 614.81, MAE: 431.45
#
# Fold 275/417
# Fold RMSE: 658.22, MAE: 567.56
#
# Fold 276/417
# Fold RMSE: 881.06, MAE: 765.38
#
# Fold 277/417
# Fold RMSE: 485.12, MAE: 344.43
#
# Fold 278/417
# Fold RMSE: 577.14, MAE: 513.11
#
# Fold 279/417
# Fold RMSE: 329.60, MAE: 252.85
#
# Fold 280/417
# Fold RMSE: 742.69, MAE: 553.82
#
# Fold 281/417
# Fold RMSE: 790.77, MAE: 734.11
#
# Fold 282/417
# Fold RMSE: 808.43, MAE: 636.92
#
# Fold 283/417
# Fold RMSE: 1242.10, MAE: 1165.65
#
# Fold 284/417
# Fold RMSE: 374.88, MAE: 258.83
#
# Fold 285/417
# Fold RMSE: 556.84, MAE: 418.94
#
# Fold 286/417
# Fold RMSE: 691.16, MAE: 535.56
#
# Fold 287/417
# Fold RMSE: 728.66, MAE: 609.20
#
# Fold 288/417
# Fold RMSE: 977.98, MAE: 836.13
#
# Fold 289/417
# Fold RMSE: 1347.17, MAE: 1299.86
#
# Fold 290/417
# Fold RMSE: 1730.21, MAE: 1495.88
#
# Fold 291/417
# Fold RMSE: 1231.98, MAE: 1072.64
#
# Fold 292/417
# Fold RMSE: 1189.07, MAE: 972.88
#
# Fold 293/417
# Fold RMSE: 830.48, MAE: 669.44
#
# Fold 294/417
# Fold RMSE: 898.98, MAE: 705.18
#
# Fold 295/417
# Fold RMSE: 1069.25, MAE: 820.12
#
# Fold 296/417
# Fold RMSE: 1549.52, MAE: 1183.09
#
# Fold 297/417
# Fold RMSE: 1560.73, MAE: 1246.01
#
# Fold 298/417
# Fold RMSE: 835.90, MAE: 671.30
#
# Fold 299/417
# Fold RMSE: 1211.90, MAE: 1093.79
#
# Fold 300/417
# Fold RMSE: 867.42, MAE: 669.19
#
# Fold 301/417
# Fold RMSE: 1757.37, MAE: 1630.67
#
# Fold 302/417
# Fold RMSE: 1437.87, MAE: 1214.24
#
# Fold 303/417
# Fold RMSE: 912.89, MAE: 823.21
#
# Fold 304/417
# Fold RMSE: 450.83, MAE: 392.37
#
# Fold 305/417
# Fold RMSE: 383.26, MAE: 297.98
#
# Fold 306/417
# Fold RMSE: 768.42, MAE: 688.56
#
# Fold 307/417
# Fold RMSE: 849.34, MAE: 696.08
#
# Fold 308/417
# Fold RMSE: 962.00, MAE: 830.46
#
# Fold 309/417
# Fold RMSE: 906.32, MAE: 734.55
#
# Fold 310/417
# Fold RMSE: 677.15, MAE: 604.18
#
# Fold 311/417
# Fold RMSE: 782.65, MAE: 705.75
#
# Fold 312/417
# Fold RMSE: 1672.51, MAE: 1615.35
#
# Fold 313/417
# Fold RMSE: 920.09, MAE: 849.55
#
# Fold 314/417
# Fold RMSE: 638.67, MAE: 520.20
#
# Fold 315/417
# Fold RMSE: 407.66, MAE: 353.98
#
# Fold 316/417
# Fold RMSE: 469.39, MAE: 378.17
#
# Fold 317/417
# Fold RMSE: 381.68, MAE: 310.95
#
# Fold 318/417
# Fold RMSE: 679.30, MAE: 602.90
#
# Fold 319/417
# Fold RMSE: 462.56, MAE: 386.64
#
# Fold 320/417
# Fold RMSE: 586.85, MAE: 483.08
#
# Fold 321/417
# Fold RMSE: 364.09, MAE: 303.67
#
# Fold 322/417
# Fold RMSE: 466.36, MAE: 431.44
#
# Fold 323/417
# Fold RMSE: 291.22, MAE: 227.91
#
# Fold 324/417
# Fold RMSE: 430.32, MAE: 370.63
#
# Fold 325/417
# Fold RMSE: 357.27, MAE: 298.21
#
# Fold 326/417
# Fold RMSE: 386.30, MAE: 297.11
#
# Fold 327/417
# Fold RMSE: 353.12, MAE: 309.41
#
# Fold 328/417
# Fold RMSE: 343.52, MAE: 271.95
#
# Fold 329/417
# Fold RMSE: 422.04, MAE: 360.65
#
# Fold 330/417
# Fold RMSE: 256.77, MAE: 223.11
#
# Fold 331/417
# Fold RMSE: 354.74, MAE: 279.68
#
# Fold 332/417
# Fold RMSE: 295.67, MAE: 236.13
#
# Fold 333/417
# Fold RMSE: 309.04, MAE: 233.86
#
# Fold 334/417
# Fold RMSE: 336.13, MAE: 258.97
#
# Fold 335/417
# Fold RMSE: 269.11, MAE: 220.03
#
# Fold 336/417
# Fold RMSE: 247.52, MAE: 177.61
#
# Fold 337/417
# Fold RMSE: 383.57, MAE: 333.98
#
# Fold 338/417
# Fold RMSE: 243.10, MAE: 194.10
#
# Fold 339/417
# Fold RMSE: 287.01, MAE: 210.60
#
# Fold 340/417
# Fold RMSE: 520.64, MAE: 461.52
#
# Fold 341/417
# Fold RMSE: 259.09, MAE: 206.41
#
# Fold 342/417
# Fold RMSE: 447.50, MAE: 364.22
#
# Fold 343/417
# Fold RMSE: 304.96, MAE: 241.23
#
# Fold 344/417
# Fold RMSE: 349.31, MAE: 281.26
#
# Fold 345/417
# Fold RMSE: 376.41, MAE: 334.30
#
# Fold 346/417
# Fold RMSE: 244.60, MAE: 174.51
#
# Fold 347/417
# Fold RMSE: 388.57, MAE: 273.57
#
# Fold 348/417
# Fold RMSE: 217.05, MAE: 188.31
#
# Fold 349/417
# Fold RMSE: 254.86, MAE: 194.60
#
# Fold 350/417
# Fold RMSE: 432.01, MAE: 231.11
#
# Fold 351/417
# Fold RMSE: 614.76, MAE: 522.80
#
# Fold 352/417
# Fold RMSE: 508.77, MAE: 374.64
#
# Fold 353/417
# Fold RMSE: 453.70, MAE: 416.11
#
# Fold 354/417
# Fold RMSE: 494.67, MAE: 378.07
#
# Fold 355/417
# Fold RMSE: 426.42, MAE: 358.64
#
# Fold 356/417
# Fold RMSE: 547.18, MAE: 449.82
#
# Fold 357/417
# Fold RMSE: 439.20, MAE: 383.97
#
# Fold 358/417
# Fold RMSE: 307.59, MAE: 234.42
#
# Fold 359/417
# Fold RMSE: 273.30, MAE: 223.04
#
# Fold 360/417
# Fold RMSE: 503.04, MAE: 418.64
#
# Fold 361/417
# Fold RMSE: 848.25, MAE: 768.22
#
# Fold 362/417
# Fold RMSE: 445.01, MAE: 404.41
#
# Fold 363/417
# Fold RMSE: 257.96, MAE: 214.84
#
# Fold 364/417
# Fold RMSE: 552.17, MAE: 530.04
#
# Fold 365/417
# Fold RMSE: 149.85, MAE: 118.05
#
# Fold 366/417
# Fold RMSE: 639.74, MAE: 374.61
#
# Fold 367/417
# Fold RMSE: 529.84, MAE: 510.88
#
# Fold 368/417
# Fold RMSE: 285.64, MAE: 226.27
#
# Fold 369/417
# Fold RMSE: 281.22, MAE: 245.61
#
# Fold 370/417
# Fold RMSE: 221.51, MAE: 181.03
#
# Fold 371/417
# Fold RMSE: 275.77, MAE: 239.38
#
# Fold 372/417
# Fold RMSE: 133.34, MAE: 105.69
#
# Fold 373/417
# Fold RMSE: 169.73, MAE: 135.44
#
# Fold 374/417
# Fold RMSE: 284.38, MAE: 255.73
#
# Fold 375/417
# Fold RMSE: 139.38, MAE: 99.56
#
# Fold 376/417
# Fold RMSE: 190.01, MAE: 147.96
#
# Fold 377/417
# Fold RMSE: 240.58, MAE: 181.63
#
# Fold 378/417
# Fold RMSE: 207.77, MAE: 152.51
#
# Fold 379/417
# Fold RMSE: 202.02, MAE: 161.05
#
# Fold 380/417
# Fold RMSE: 275.14, MAE: 224.32
#
# Fold 381/417
# Fold RMSE: 362.99, MAE: 296.92
#
# Fold 382/417
# Fold RMSE: 243.86, MAE: 185.68
#
# Fold 383/417
# Fold RMSE: 417.66, MAE: 361.29
#
# Fold 384/417
# Fold RMSE: 332.25, MAE: 295.22
#
# Fold 385/417
# Fold RMSE: 415.14, MAE: 386.47
#
# Fold 386/417
# Fold RMSE: 474.55, MAE: 387.43
#
# Fold 387/417
# Fold RMSE: 302.29, MAE: 221.02
#
# Fold 388/417
# Fold RMSE: 378.25, MAE: 304.68
#
# Fold 389/417
# Fold RMSE: 365.33, MAE: 302.76
#
# Fold 390/417
# Fold RMSE: 352.98, MAE: 274.68
#
# Fold 391/417
# Fold RMSE: 381.19, MAE: 303.90
#
# Fold 392/417
# Fold RMSE: 318.85, MAE: 267.77
#
# Fold 393/417
# Fold RMSE: 441.64, MAE: 359.85
#
# Fold 394/417
# Fold RMSE: 370.52, MAE: 295.23
#
# Fold 395/417
# Fold RMSE: 301.11, MAE: 230.39
#
# Fold 396/417
# Fold RMSE: 332.82, MAE: 240.65
#
# Fold 397/417
# Fold RMSE: 377.58, MAE: 288.46
#
# Fold 398/417
# Fold RMSE: 496.61, MAE: 413.23
#
# Fold 399/417
# Fold RMSE: 454.57, MAE: 368.23
#
# Fold 400/417
# Fold RMSE: 561.54, MAE: 458.93
#
# Fold 401/417
# Fold RMSE: 471.32, MAE: 345.55
#
# Fold 402/417
# Fold RMSE: 417.92, MAE: 350.41
#
# Fold 403/417
# Fold RMSE: 297.16, MAE: 217.58
#
# Fold 404/417
# Fold RMSE: 395.50, MAE: 307.26
#
# Fold 405/417
# Fold RMSE: 378.55, MAE: 305.32
#
# Fold 406/417
# Fold RMSE: 329.93, MAE: 273.37
#
# Fold 407/417
# Fold RMSE: 379.72, MAE: 302.13
#
# Fold 408/417
# Fold RMSE: 345.95, MAE: 253.94
#
# Fold 409/417
# Fold RMSE: 443.46, MAE: 332.20
#
# Fold 410/417
# Fold RMSE: 979.55, MAE: 796.15
#
# Fold 411/417
# Fold RMSE: 343.32, MAE: 234.52
#
# Fold 412/417
# Fold RMSE: 371.35, MAE: 312.29
#
# Fold 413/417
# Fold RMSE: 524.46, MAE: 453.82
#
# Fold 414/417
# Fold RMSE: 429.00, MAE: 344.48
#
# Fold 415/417
# Fold RMSE: 1346.52, MAE: 769.01
#
# Fold 416/417
# Fold RMSE: 1548.21, MAE: 1537.20
#
# Fold 417/417
# Fold RMSE: 441.43, MAE: 381.41
#
# Overall RMSE: 443.46
# Overall MAE: 249.21
# Average fold RMSE: 305.49 (+/- 321.46)
# Average fold MAE: 249.21 (+/- 276.66)

# %%
title_DK1 = 'Walk-Forward Validation - Moving Average: Actual vs. Predicted for DK1'

plot_walk_forward_results(
        predictions_DK1, 
        actuals_DK1, 
        title_DK1)

title_DK2 = 'Walk-Forward Validation - Moving Average: Actual vs. Predicted for DK2'

plot_walk_forward_results(
        predictions_DK2, 
        actuals_DK2, 
        title_DK2)
