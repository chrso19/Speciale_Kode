# %%
# Importing the packages

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# Loading and processing the data

# Determining the path to the data
file_dir = os.path.dirname(os.path.realpath('naive_persistence.ipynb'))
python_dir = os.path.dirname(file_dir)
data_folder = os.path.join(python_dir, 'Data')
data_file = os.path.join(data_folder, 'combined_data_cleaned.csv')

# Loading the data
df = pd.read_csv(data_file, decimal = ',')
df_new = df[["TimeUTC", "DKZone", "DKPrice"]]

# Format for the datetime
date_format = '%Y-%m-%d %H:%M:%S'

# Filtering for DK1 price zone
df_DK1 = df_new[df_new['DKZone'] == 'DK1']
df_DK1 = df_DK1.drop('DKZone', axis = 1)
df_DK1.reset_index(drop=True, inplace=True)

# Saving datetime format for DK1
temp_list = []
for i in list(df_DK1["TimeUTC"]):
    n = 19
    j = i[:n]
    k = datetime.strptime(j, date_format)
    temp_list.append(k)
df_DK1.insert(0, "Time", temp_list, True)
df_DK1 = df_DK1.drop("TimeUTC", axis = 1)
df_DK1['DKPrice'] = df_DK1['DKPrice'].astype(float)

# Splitting between initial train and test set for DK1
DK1_train_set = df_DK1.loc[df_DK1['Time'] < pd.Timestamp('2025-01-01')]
DK1_train_set.reset_index(drop=True, inplace=True)
DK1_test_set = df_DK1.loc[df_DK1['Time'] >= pd.Timestamp('2025-01-01')]
DK1_test_set.reset_index(drop=True, inplace=True)

# Printing the shape for training and test date for DK1
print(f"Training data shape (DK1): {DK1_train_set.shape}")
print(f"Test data shape (DK1): {DK1_test_set.shape}")
print(f"Test set fraction (DK1): {len(DK1_test_set)/len(DK1_train_set):.2%}")

# Filtering for DK2 price zone
df_DK2 = df_new[df_new['DKZone'] == 'DK2']
df_DK2 = df_DK2.drop('DKZone', axis = 1)
df_DK2.reset_index(drop=True, inplace=True)

# Saving datetime format for DK2
temp_list = []
for i in list(df_DK2["TimeUTC"]):
    n = 19
    j = i[:n]
    k = datetime.strptime(j, date_format)
    temp_list.append(k)
df_DK2.insert(0, "Time", temp_list, True)
df_DK2 = df_DK2.drop("TimeUTC", axis = 1)
df_DK2['DKPrice'] = df_DK2['DKPrice'].astype(float)

# Splitting between initial train and test set for DK2
DK2_train_set = df_DK2.loc[df_DK1['Time'] < pd.Timestamp('2025-01-01')]
DK2_train_set.reset_index(drop=True, inplace=True)
DK2_test_set = df_DK2.loc[df_DK1['Time'] >= pd.Timestamp('2025-01-01')]
DK2_test_set.reset_index(drop=True, inplace=True)

# Printing the shape for training and test date for DK2
print(f"Training data shape (DK2): {DK2_train_set.shape}")
print(f"Test data shape (DK2): {DK2_test_set.shape}")
print(f"Test set fraction (DK2): {len(DK2_test_set)/len(DK2_train_set):.2%}")
# Out:
# Training data shape (DK1): (78911, 3)
# Test data shape (DK1): (8760, 3)
# Test set fraction (DK1): 11.10%
# Training data shape (DK2): (78911, 3)
# Test data shape (DK2): (8760, 3)
# Test set fraction (DK2): 11.10%

# %%
# Defining the persistence model
def model_persistence(x):
    return x

# %%
def perform_walk_forward_validation_naive(
        data_series, 
        model, 
        training_window = 8760, # 365 days of data - hours of data trained on
        forecast_horizon = 168, # 1 week - hours of data predicted
        ):
    """
    Walk-forward validation for Naive Persistence.
    """

    all_predictions = []
    all_actuals = []
    all_fold_rmse = []
    all_fold_mae = []

    # Calculate number of folds
    num_folds = (len(data_series) - training_window - forecast_horizon) // forecast_horizon

    print(f"Total folds: {num_folds}")
    print(f"Training winow: {training_window} hours")
    print(f"Forecast horizon: {forecast_horizon} hours")

    for fold in range(num_folds):
        start = fold * forecast_horizon

        # Check if there is enough data 
        if start + training_window + forecast_horizon > len(data_series):
            break
        
        print(f"Fold {fold + 1}/{num_folds}")

        # Split the data into training and validating data
        train_data = data_series[start: start + training_window]
        val_data = data_series[start + training_window: start + training_window + forecast_horizon]

        # Using the naive persistence model
        predicted_value = model(train_data.iloc[-1])
        predictions = np.full(len(val_data), predicted_value)
        actuals = val_data.values

        # Calculate errors
        fold_mse = mean_squared_error(actuals, predictions)
        fold_rmse = np.sqrt(fold_mse)
        fold_mae = mean_absolute_error(actuals, predictions)

        all_fold_rmse.append(fold_rmse)
        all_fold_mae.append(fold_mae)
        all_predictions.extend(predictions)
        all_actuals.extend(actuals)

        print(f"Fold RMSE: {fold_rmse:.2f}, MAE: {fold_mae:.2f}\n")
    
    # Overall metrics
    overall_rmse = np.sqrt(mean_squared_error(all_actuals, all_predictions))
    overall_mae = mean_absolute_error(all_actuals, all_predictions)

    print(f"Overall RMSE: {overall_rmse:.2f}")
    print(f"Overall MAE: {overall_mae:.2f}")
    print(f"Average fold RMSE: {np.mean(all_fold_rmse):.2f} (+/- {np.std(all_fold_rmse):.2f})")
    print(f"Average fold MAE: {np.mean(all_fold_mae):.2f} (+/- {np.std(all_fold_mae):.2f})\n")

    return all_predictions, all_actuals, all_fold_rmse, all_fold_mae

# %%
def plot_walk_forward_results(
        predictions, 
        actuals, 
        title,
        training_window = 8760, # 365 days of data - hours of data trained on
        forecast_horizon = 168, # 1 week - hours of data predicted
        ):
    """
    Plot walk-forward validation results.
    """
    plt.figure(figsize=(15, 6))
    
    # Create x-axis (fold numbers repeated for each prediction in that fold)
    x = []
    fold_num = 0
    for i in range(len(predictions)):
        if i % (forecast_horizon) == 0 and i > 0:
            fold_num += 1
        x.append(fold_num)
    
    plt.plot(actuals, label='Actual', alpha=0.7, linewidth=2)
    plt.plot(predictions, label='Predicted', alpha=0.7, linewidth=2)
    
    # Add vertical lines to separate folds
    for i in range(0, len(predictions), forecast_horizon):
        plt.axvline(x=i, color='gray', linestyle='--', alpha=0.3)
    
    plt.xlabel('Time Step')
    plt.ylabel('Electricity Price (DKK)')
    plt.title(title)
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
# Walk-forward validation
model = model_persistence

# Walk-forward validation for DK1
data_series_DK1 = DK1_train_set['DKPrice']
predictions_DK1, actuals_DK1, rmse_DK1, mae_DK1 = perform_walk_forward_validation_naive(data_series_DK1, model)

# Walk-forward validation for DK2
data_series_DK2 = DK2_train_set['DKPrice']
predictions_DK2, actuals_DK2, rmse_DK2, mae_DK2 = perform_walk_forward_validation_naive(data_series_DK2, model)
# Out:
# Total folds: 416
# Training winow: 8760 hours
# Forecast horizon: 168 hours
# Fold 1/416
# Fold RMSE: 140.97, MAE: 127.20
#
# Fold 2/416
# Fold RMSE: 49.73, MAE: 32.39
#
# Fold 3/416
# Fold RMSE: 90.30, MAE: 36.76
#
# Fold 4/416
# Fold RMSE: 39.03, MAE: 25.50
#
# Fold 5/416
# Fold RMSE: 36.95, MAE: 25.07
#
# Fold 6/416
# Fold RMSE: 57.82, MAE: 30.81
#
# Fold 7/416
# Fold RMSE: 46.56, MAE: 21.06
#
# Fold 8/416
# Fold RMSE: 102.08, MAE: 58.40
#
# Fold 9/416
# Fold RMSE: 58.79, MAE: 36.65
#
# Fold 10/416
# Fold RMSE: 67.66, MAE: 43.81
#
# Fold 11/416
# Fold RMSE: 57.57, MAE: 30.63
#
# Fold 12/416
# Fold RMSE: 141.52, MAE: 128.66
#
# Fold 13/416
# Fold RMSE: 38.92, MAE: 26.06
#
# Fold 14/416
# Fold RMSE: 76.08, MAE: 46.17
#
# Fold 15/416
# Fold RMSE: 41.79, MAE: 20.10
#
# Fold 16/416
# Fold RMSE: 57.58, MAE: 33.69
#
# Fold 17/416
# Fold RMSE: 230.81, MAE: 212.41
#
# Fold 18/416
# Fold RMSE: 85.51, MAE: 44.02
#
# Fold 19/416
# Fold RMSE: 39.94, MAE: 26.45
#
# Fold 20/416
# Fold RMSE: 36.13, MAE: 26.21
#
# Fold 21/416
# Fold RMSE: 70.55, MAE: 55.52
#
# Fold 22/416
# Fold RMSE: 67.32, MAE: 53.22
#
# Fold 23/416
# Fold RMSE: 65.91, MAE: 51.00
#
# Fold 24/416
# Fold RMSE: 70.54, MAE: 55.14
#
# Fold 25/416
# Fold RMSE: 119.51, MAE: 103.46
#
# Fold 26/416
# Fold RMSE: 79.64, MAE: 56.19
#
# Fold 27/416
# Fold RMSE: 88.55, MAE: 68.58
#
# Fold 28/416
# Fold RMSE: 50.05, MAE: 38.66
#
# Fold 29/416
# Fold RMSE: 43.23, MAE: 36.88
#
# Fold 30/416
# Fold RMSE: 55.60, MAE: 41.38
#
# Fold 31/416
# Fold RMSE: 79.01, MAE: 68.99
#
# Fold 32/416
# Fold RMSE: 84.88, MAE: 68.49
#
# Fold 33/416
# Fold RMSE: 96.75, MAE: 79.16
#
# Fold 34/416
# Fold RMSE: 168.95, MAE: 121.63
#
# Fold 35/416
# Fold RMSE: 79.85, MAE: 51.77
#
# Fold 36/416
# Fold RMSE: 64.90, MAE: 44.02
#
# Fold 37/416
# Fold RMSE: 69.39, MAE: 44.50
#
# Fold 38/416
# Fold RMSE: 70.58, MAE: 54.30
#
# Fold 39/416
# Fold RMSE: 38.56, MAE: 26.96
#
# Fold 40/416
# Fold RMSE: 78.78, MAE: 65.37
#
# Fold 41/416
# Fold RMSE: 169.00, MAE: 151.80
#
# Fold 42/416
# Fold RMSE: 109.02, MAE: 70.61
#
# Fold 43/416
# Fold RMSE: 43.13, MAE: 26.89
#
# Fold 44/416
# Fold RMSE: 218.99, MAE: 193.48
#
# Fold 45/416
# Fold RMSE: 124.41, MAE: 71.53
#
# Fold 46/416
# Fold RMSE: 234.64, MAE: 222.99
#
# Fold 47/416
# Fold RMSE: 126.55, MAE: 98.89
#
# Fold 48/416
# Fold RMSE: 115.49, MAE: 72.61
#
# Fold 49/416
# Fold RMSE: 50.81, MAE: 31.03
#
# Fold 50/416
# Fold RMSE: 156.32, MAE: 132.41
#
# Fold 51/416
# Fold RMSE: 116.27, MAE: 66.71
#
# Fold 52/416
# Fold RMSE: 133.24, MAE: 108.82
#
# Fold 53/416
# Fold RMSE: 87.97, MAE: 60.03
#
# Fold 54/416
# Fold RMSE: 84.99, MAE: 61.90
#
# Fold 55/416
# Fold RMSE: 74.16, MAE: 47.82
#
# Fold 56/416
# Fold RMSE: 78.84, MAE: 60.80
#
# Fold 57/416
# Fold RMSE: 92.16, MAE: 55.11
#
# Fold 58/416
# Fold RMSE: 93.59, MAE: 59.22
#
# Fold 59/416
# Fold RMSE: 80.16, MAE: 49.94
#
# Fold 60/416
# Fold RMSE: 103.87, MAE: 78.14
#
# Fold 61/416
# Fold RMSE: 66.09, MAE: 46.56
#
# Fold 62/416
# Fold RMSE: 88.22, MAE: 62.50
#
# Fold 63/416
# Fold RMSE: 90.12, MAE: 71.19
#
# Fold 64/416
# Fold RMSE: 283.49, MAE: 254.53
#
# Fold 65/416
# Fold RMSE: 58.02, MAE: 39.36
#
# Fold 66/416
# Fold RMSE: 52.60, MAE: 41.50
#
# Fold 67/416
# Fold RMSE: 171.29, MAE: 159.07
#
# Fold 68/416
# Fold RMSE: 99.11, MAE: 86.28
#
# Fold 69/416
# Fold RMSE: 69.06, MAE: 59.33
#
# Fold 70/416
# Fold RMSE: 97.14, MAE: 85.68
#
# Fold 71/416
# Fold RMSE: 94.45, MAE: 75.95
#
# Fold 72/416
# Fold RMSE: 95.81, MAE: 79.15
#
# Fold 73/416
# Fold RMSE: 79.41, MAE: 59.37
#
# Fold 74/416
# Fold RMSE: 87.20, MAE: 65.65
#
# Fold 75/416
# Fold RMSE: 73.81, MAE: 58.46
#
# Fold 76/416
# Fold RMSE: 55.93, MAE: 46.13
#
# Fold 77/416
# Fold RMSE: 88.83, MAE: 59.05
#
# Fold 78/416
# Fold RMSE: 240.29, MAE: 212.63
#
# Fold 79/416
# Fold RMSE: 65.97, MAE: 53.47
#
# Fold 80/416
# Fold RMSE: 100.15, MAE: 91.67
#
# Fold 81/416
# Fold RMSE: 47.17, MAE: 41.61
#
# Fold 82/416
# Fold RMSE: 58.06, MAE: 47.54
#
# Fold 83/416
# Fold RMSE: 99.99, MAE: 83.10
#
# Fold 84/416
# Fold RMSE: 91.07, MAE: 63.69
#
# Fold 85/416
# Fold RMSE: 93.81, MAE: 77.13
#
# Fold 86/416
# Fold RMSE: 94.05, MAE: 67.56
#
# Fold 87/416
# Fold RMSE: 104.14, MAE: 78.76
#
# Fold 88/416
# Fold RMSE: 84.64, MAE: 65.52
#
# Fold 89/416
# Fold RMSE: 108.49, MAE: 80.31
#
# Fold 90/416
# Fold RMSE: 108.39, MAE: 72.69
#
# Fold 91/416
# Fold RMSE: 268.13, MAE: 246.86
#
# Fold 92/416
# Fold RMSE: 165.98, MAE: 128.56
#
# Fold 93/416
# Fold RMSE: 83.83, MAE: 56.00
#
# Fold 94/416
# Fold RMSE: 278.36, MAE: 240.36
#
# Fold 95/416
# Fold RMSE: 99.85, MAE: 65.83
#
# Fold 96/416
# Fold RMSE: 153.28, MAE: 138.83
#
# Fold 97/416
# Fold RMSE: 126.26, MAE: 94.40
#
# Fold 98/416
# Fold RMSE: 113.13, MAE: 82.52
#
# Fold 99/416
# Fold RMSE: 184.63, MAE: 133.03
#
# Fold 100/416
# Fold RMSE: 125.16, MAE: 94.64
#
# Fold 101/416
# Fold RMSE: 81.99, MAE: 65.55
#
# Fold 102/416
# Fold RMSE: 319.53, MAE: 284.57
#
# Fold 103/416
# Fold RMSE: 75.27, MAE: 51.68
#
# Fold 104/416
# Fold RMSE: 104.18, MAE: 74.44
#
# Fold 105/416
# Fold RMSE: 221.67, MAE: 129.24
#
# Fold 106/416
# Fold RMSE: 189.01, MAE: 175.89
#
# Fold 107/416
# Fold RMSE: 114.19, MAE: 76.35
#
# Fold 108/416
# Fold RMSE: 137.05, MAE: 90.91
#
# Fold 109/416
# Fold RMSE: 61.54, MAE: 40.60
#
# Fold 110/416
# Fold RMSE: 64.56, MAE: 41.56
#
# Fold 111/416
# Fold RMSE: 303.45, MAE: 277.58
#
# Fold 112/416
# Fold RMSE: 70.53, MAE: 57.50
#
# Fold 113/416
# Fold RMSE: 59.49, MAE: 47.77
#
# Fold 114/416
# Fold RMSE: 154.10, MAE: 102.00
#
# Fold 115/416
# Fold RMSE: 181.70, MAE: 171.69
#
# Fold 116/416
# Fold RMSE: 288.36, MAE: 265.75
#
# Fold 117/416
# Fold RMSE: 47.12, MAE: 37.95
#
# Fold 118/416
# Fold RMSE: 62.11, MAE: 45.82
#
# Fold 119/416
# Fold RMSE: 51.16, MAE: 40.18
#
# Fold 120/416
# Fold RMSE: 38.48, MAE: 28.93
#
# Fold 121/416
# Fold RMSE: 136.12, MAE: 83.86
#
# Fold 122/416
# Fold RMSE: 94.02, MAE: 76.47
#
# Fold 123/416
# Fold RMSE: 68.17, MAE: 57.53
#
# Fold 124/416
# Fold RMSE: 82.39, MAE: 51.36
#
# Fold 125/416
# Fold RMSE: 65.53, MAE: 47.64
#
# Fold 126/416
# Fold RMSE: 89.07, MAE: 60.74
#
# Fold 127/416
# Fold RMSE: 83.06, MAE: 62.29
#
# Fold 128/416
# Fold RMSE: 188.22, MAE: 160.86
#
# Fold 129/416
# Fold RMSE: 95.01, MAE: 68.19
#
# Fold 130/416
# Fold RMSE: 73.64, MAE: 45.06
#
# Fold 131/416
# Fold RMSE: 56.44, MAE: 30.38
#
# Fold 132/416
# Fold RMSE: 93.52, MAE: 72.69
#
# Fold 133/416
# Fold RMSE: 56.87, MAE: 40.06
#
# Fold 134/416
# Fold RMSE: 82.17, MAE: 56.27
#
# Fold 135/416
# Fold RMSE: 74.36, MAE: 52.74
#
# Fold 136/416
# Fold RMSE: 44.04, MAE: 30.61
#
# Fold 137/416
# Fold RMSE: 129.47, MAE: 87.46
#
# Fold 138/416
# Fold RMSE: 115.63, MAE: 98.48
#
# Fold 139/416
# Fold RMSE: 116.12, MAE: 88.63
#
# Fold 140/416
# Fold RMSE: 54.99, MAE: 39.39
#
# Fold 141/416
# Fold RMSE: 84.17, MAE: 61.97
#
# Fold 142/416
# Fold RMSE: 107.03, MAE: 80.88
#
# Fold 143/416
# Fold RMSE: 111.15, MAE: 86.46
#
# Fold 144/416
# Fold RMSE: 123.07, MAE: 104.70
#
# Fold 145/416
# Fold RMSE: 89.20, MAE: 70.81
#
# Fold 146/416
# Fold RMSE: 324.27, MAE: 305.42
#
# Fold 147/416
# Fold RMSE: 128.89, MAE: 106.46
#
# Fold 148/416
# Fold RMSE: 165.47, MAE: 146.33
#
# Fold 149/416
# Fold RMSE: 120.53, MAE: 99.04
#
# Fold 150/416
# Fold RMSE: 56.85, MAE: 43.42
#
# Fold 151/416
# Fold RMSE: 94.85, MAE: 67.32
#
# Fold 152/416
# Fold RMSE: 91.68, MAE: 74.05
#
# Fold 153/416
# Fold RMSE: 88.30, MAE: 63.96
#
# Fold 154/416
# Fold RMSE: 241.30, MAE: 219.28
#
# Fold 155/416
# Fold RMSE: 73.33, MAE: 54.89
#
# Fold 156/416
# Fold RMSE: 68.40, MAE: 62.46
#
# Fold 157/416
# Fold RMSE: 62.86, MAE: 35.92
#
# Fold 158/416
# Fold RMSE: 121.56, MAE: 112.37
#
# Fold 159/416
# Fold RMSE: 86.95, MAE: 78.26
#
# Fold 160/416
# Fold RMSE: 33.33, MAE: 20.20
#
# Fold 161/416
# Fold RMSE: 49.03, MAE: 26.33
#
# Fold 162/416
# Fold RMSE: 187.18, MAE: 166.83
#
# Fold 163/416
# Fold RMSE: 99.20, MAE: 61.78
#
# Fold 164/416
# Fold RMSE: 78.75, MAE: 50.18
#
# Fold 165/416
# Fold RMSE: 194.43, MAE: 159.18
#
# Fold 166/416
# Fold RMSE: 208.06, MAE: 179.31
#
# Fold 167/416
# Fold RMSE: 116.55, MAE: 103.15
#
# Fold 168/416
# Fold RMSE: 141.08, MAE: 118.91
#
# Fold 169/416
# Fold RMSE: 61.60, MAE: 54.36
#
# Fold 170/416
# Fold RMSE: 109.17, MAE: 96.96
#
# Fold 171/416
# Fold RMSE: 85.45, MAE: 67.04
#
# Fold 172/416
# Fold RMSE: 129.77, MAE: 102.49
#
# Fold 173/416
# Fold RMSE: 82.22, MAE: 67.88
#
# Fold 174/416
# Fold RMSE: 123.36, MAE: 105.69
#
# Fold 175/416
# Fold RMSE: 78.04, MAE: 62.64
#
# Fold 176/416
# Fold RMSE: 70.36, MAE: 58.75
#
# Fold 177/416
# Fold RMSE: 96.69, MAE: 71.00
#
# Fold 178/416
# Fold RMSE: 101.75, MAE: 85.76
#
# Fold 179/416
# Fold RMSE: 101.76, MAE: 80.04
#
# Fold 180/416
# Fold RMSE: 190.31, MAE: 172.72
#
# Fold 181/416
# Fold RMSE: 118.82, MAE: 97.73
#
# Fold 182/416
# Fold RMSE: 101.70, MAE: 78.66
#
# Fold 183/416
# Fold RMSE: 98.64, MAE: 78.82
#
# Fold 184/416
# Fold RMSE: 207.98, MAE: 160.92
#
# Fold 185/416
# Fold RMSE: 216.39, MAE: 189.34
#
# Fold 186/416
# Fold RMSE: 73.71, MAE: 59.67
#
# Fold 187/416
# Fold RMSE: 139.33, MAE: 117.20
#
# Fold 188/416
# Fold RMSE: 85.57, MAE: 69.29
#
# Fold 189/416
# Fold RMSE: 65.31, MAE: 51.71
#
# Fold 190/416
# Fold RMSE: 73.36, MAE: 57.14
#
# Fold 191/416
# Fold RMSE: 145.55, MAE: 118.75
#
# Fold 192/416
# Fold RMSE: 129.72, MAE: 96.73
#
# Fold 193/416
# Fold RMSE: 110.79, MAE: 80.24
#
# Fold 194/416
# Fold RMSE: 251.21, MAE: 185.76
#
# Fold 195/416
# Fold RMSE: 168.62, MAE: 110.51
#
# Fold 196/416
# Fold RMSE: 270.11, MAE: 210.51
#
# Fold 197/416
# Fold RMSE: 238.22, MAE: 207.38
#
# Fold 198/416
# Fold RMSE: 187.81, MAE: 146.68
#
# Fold 199/416
# Fold RMSE: 125.25, MAE: 90.43
#
# Fold 200/416
# Fold RMSE: 108.92, MAE: 77.62
#
# Fold 201/416
# Fold RMSE: 156.16, MAE: 148.79
#
# Fold 202/416
# Fold RMSE: 113.72, MAE: 90.69
#
# Fold 203/416
# Fold RMSE: 219.05, MAE: 202.83
#
# Fold 204/416
# Fold RMSE: 257.32, MAE: 152.45
#
# Fold 205/416
# Fold RMSE: 162.95, MAE: 121.40
#
# Fold 206/416
# Fold RMSE: 193.51, MAE: 150.88
#
# Fold 207/416
# Fold RMSE: 158.06, MAE: 117.97
#
# Fold 208/416
# Fold RMSE: 116.20, MAE: 79.71
#
# Fold 209/416
# Fold RMSE: 200.33, MAE: 173.33
#
# Fold 210/416
# Fold RMSE: 170.81, MAE: 130.06
#
# Fold 211/416
# Fold RMSE: 140.42, MAE: 103.90
#
# Fold 212/416
# Fold RMSE: 123.75, MAE: 97.26
#
# Fold 213/416
# Fold RMSE: 207.39, MAE: 190.94
#
# Fold 214/416
# Fold RMSE: 109.63, MAE: 88.31
#
# Fold 215/416
# Fold RMSE: 224.47, MAE: 176.42
#
# Fold 216/416
# Fold RMSE: 66.31, MAE: 51.46
#
# Fold 217/416
# Fold RMSE: 80.69, MAE: 60.72
#
# Fold 218/416
# Fold RMSE: 100.80, MAE: 77.10
#
# Fold 219/416
# Fold RMSE: 150.01, MAE: 115.16
#
# Fold 220/416
# Fold RMSE: 227.65, MAE: 204.84
#
# Fold 221/416
# Fold RMSE: 124.98, MAE: 101.29
#
# Fold 222/416
# Fold RMSE: 150.89, MAE: 105.23
#
# Fold 223/416
# Fold RMSE: 186.73, MAE: 129.45
#
# Fold 224/416
# Fold RMSE: 170.52, MAE: 125.87
#
# Fold 225/416
# Fold RMSE: 146.19, MAE: 106.77
#
# Fold 226/416
# Fold RMSE: 132.92, MAE: 92.12
#
# Fold 227/416
# Fold RMSE: 167.49, MAE: 120.14
#
# Fold 228/416
# Fold RMSE: 194.99, MAE: 129.87
#
# Fold 229/416
# Fold RMSE: 174.42, MAE: 133.04
#
# Fold 230/416
# Fold RMSE: 424.14, MAE: 372.64
#
# Fold 231/416
# Fold RMSE: 139.02, MAE: 102.85
#
# Fold 232/416
# Fold RMSE: 137.43, MAE: 112.46
#
# Fold 233/416
# Fold RMSE: 241.26, MAE: 188.77
#
# Fold 234/416
# Fold RMSE: 159.81, MAE: 128.36
#
# Fold 235/416
# Fold RMSE: 120.46, MAE: 94.05
#
# Fold 236/416
# Fold RMSE: 149.30, MAE: 113.92
#
# Fold 237/416
# Fold RMSE: 126.51, MAE: 100.87
#
# Fold 238/416
# Fold RMSE: 207.98, MAE: 166.91
#
# Fold 239/416
# Fold RMSE: 182.44, MAE: 138.95
#
# Fold 240/416
# Fold RMSE: 321.86, MAE: 276.74
#
# Fold 241/416
# Fold RMSE: 297.71, MAE: 248.95
#
# Fold 242/416
# Fold RMSE: 169.33, MAE: 124.82
#
# Fold 243/416
# Fold RMSE: 102.44, MAE: 84.07
#
# Fold 244/416
# Fold RMSE: 248.20, MAE: 200.14
#
# Fold 245/416
# Fold RMSE: 256.59, MAE: 204.30
#
# Fold 246/416
# Fold RMSE: 302.69, MAE: 238.40
#
# Fold 247/416
# Fold RMSE: 310.70, MAE: 251.64
#
# Fold 248/416
# Fold RMSE: 351.93, MAE: 256.79
#
# Fold 249/416
# Fold RMSE: 835.08, MAE: 660.92
#
# Fold 250/416
# Fold RMSE: 410.29, MAE: 320.41
#
# Fold 251/416
# Fold RMSE: 473.24, MAE: 359.83
#
# Fold 252/416
# Fold RMSE: 608.68, MAE: 501.98
#
# Fold 253/416
# Fold RMSE: 610.34, MAE: 426.67
#
# Fold 254/416
# Fold RMSE: 618.51, MAE: 453.09
#
# Fold 255/416
# Fold RMSE: 714.52, MAE: 503.82
#
# Fold 256/416
# Fold RMSE: 652.87, MAE: 422.02
#
# Fold 257/416
# Fold RMSE: 679.58, MAE: 495.10
#
# Fold 258/416
# Fold RMSE: 771.89, MAE: 564.23
#
# Fold 259/416
# Fold RMSE: 578.90, MAE: 505.88
#
# Fold 260/416
# Fold RMSE: 1294.18, MAE: 1006.02
#
# Fold 261/416
# Fold RMSE: 529.10, MAE: 452.74
#
# Fold 262/416
# Fold RMSE: 708.05, MAE: 584.84
#
# Fold 263/416
# Fold RMSE: 575.58, MAE: 397.69
#
# Fold 264/416
# Fold RMSE: 501.42, MAE: 366.82
#
# Fold 265/416
# Fold RMSE: 426.72, MAE: 308.55
#
# Fold 266/416
# Fold RMSE: 509.05, MAE: 409.92
#
# Fold 267/416
# Fold RMSE: 420.20, MAE: 353.43
#
# Fold 268/416
# Fold RMSE: 416.19, MAE: 365.25
#
# Fold 269/416
# Fold RMSE: 419.72, MAE: 384.39
#
# Fold 270/416
# Fold RMSE: 1006.53, MAE: 828.24
#
# Fold 271/416
# Fold RMSE: 1142.62, MAE: 876.08
#
# Fold 272/416
# Fold RMSE: 1103.89, MAE: 961.58
#
# Fold 273/416
# Fold RMSE: 617.40, MAE: 449.96
#
# Fold 274/416
# Fold RMSE: 429.94, MAE: 323.42
#
# Fold 275/416
# Fold RMSE: 439.93, MAE: 377.87
#
# Fold 276/416
# Fold RMSE: 793.72, MAE: 720.29
#
# Fold 277/416
# Fold RMSE: 444.54, MAE: 321.80
#
# Fold 278/416
# Fold RMSE: 539.14, MAE: 464.61
#
# Fold 279/416
# Fold RMSE: 301.70, MAE: 232.86
#
# Fold 280/416
# Fold RMSE: 456.57, MAE: 323.64
#
# Fold 281/416
# Fold RMSE: 520.56, MAE: 454.20
#
# Fold 282/416
# Fold RMSE: 533.94, MAE: 476.81
#
# Fold 283/416
# Fold RMSE: 1344.02, MAE: 1257.46
#
# Fold 284/416
# Fold RMSE: 360.95, MAE: 249.13
#
# Fold 285/416
# Fold RMSE: 499.75, MAE: 374.82
#
# Fold 286/416
# Fold RMSE: 834.10, MAE: 671.31
#
# Fold 287/416
# Fold RMSE: 806.47, MAE: 683.48
#
# Fold 288/416
# Fold RMSE: 541.33, MAE: 407.27
#
# Fold 289/416
# Fold RMSE: 1182.98, MAE: 979.30
#
# Fold 290/416
# Fold RMSE: 1296.64, MAE: 1105.32
#
# Fold 291/416
# Fold RMSE: 1009.47, MAE: 841.03
#
# Fold 292/416
# Fold RMSE: 815.12, MAE: 664.60
#
# Fold 293/416
# Fold RMSE: 888.07, MAE: 722.09
#
# Fold 294/416
# Fold RMSE: 1016.65, MAE: 831.83
#
# Fold 295/416
# Fold RMSE: 1210.45, MAE: 991.06
#
# Fold 296/416
# Fold RMSE: 1318.37, MAE: 977.40
#
# Fold 297/416
# Fold RMSE: 1213.24, MAE: 1033.51
#
# Fold 298/416
# Fold RMSE: 806.78, MAE: 605.61
#
# Fold 299/416
# Fold RMSE: 1903.92, MAE: 1600.96
#
# Fold 300/416
# Fold RMSE: 781.83, MAE: 600.44
#
# Fold 301/416
# Fold RMSE: 857.72, MAE: 556.53
#
# Fold 302/416
# Fold RMSE: 1349.35, MAE: 1119.76
#
# Fold 303/416
# Fold RMSE: 351.44, MAE: 272.06
#
# Fold 304/416
# Fold RMSE: 272.34, MAE: 219.96
#
# Fold 305/416
# Fold RMSE: 317.35, MAE: 240.72
#
# Fold 306/416
# Fold RMSE: 356.63, MAE: 260.84
#
# Fold 307/416
# Fold RMSE: 869.59, MAE: 747.55
#
# Fold 308/416
# Fold RMSE: 835.75, MAE: 688.98
#
# Fold 309/416
# Fold RMSE: 1063.90, MAE: 836.35
#
# Fold 310/416
# Fold RMSE: 1019.91, MAE: 820.14
#
# Fold 311/416
# Fold RMSE: 1052.66, MAE: 806.51
#
# Fold 312/416
# Fold RMSE: 634.15, MAE: 522.93
#
# Fold 313/416
# Fold RMSE: 384.07, MAE: 324.99
#
# Fold 314/416
# Fold RMSE: 774.93, MAE: 633.38
#
# Fold 315/416
# Fold RMSE: 346.00, MAE: 256.90
#
# Fold 316/416
# Fold RMSE: 725.77, MAE: 629.13
#
# Fold 317/416
# Fold RMSE: 332.22, MAE: 237.16
#
# Fold 318/416
# Fold RMSE: 325.76, MAE: 287.46
#
# Fold 319/416
# Fold RMSE: 354.09, MAE: 276.74
#
# Fold 320/416
# Fold RMSE: 439.34, MAE: 360.38
#
# Fold 321/416
# Fold RMSE: 564.26, MAE: 506.80
#
# Fold 322/416
# Fold RMSE: 412.12, MAE: 347.85
#
# Fold 323/416
# Fold RMSE: 294.45, MAE: 234.53
#
# Fold 324/416
# Fold RMSE: 253.69, MAE: 219.11
#
# Fold 325/416
# Fold RMSE: 264.53, MAE: 193.79
#
# Fold 326/416
# Fold RMSE: 684.43, MAE: 620.67
#
# Fold 327/416
# Fold RMSE: 483.59, MAE: 419.65
#
# Fold 328/416
# Fold RMSE: 357.35, MAE: 249.63
#
# Fold 329/416
# Fold RMSE: 251.81, MAE: 175.46
#
# Fold 330/416
# Fold RMSE: 216.93, MAE: 149.98
#
# Fold 331/416
# Fold RMSE: 271.21, MAE: 193.39
#
# Fold 332/416
# Fold RMSE: 205.66, MAE: 150.54
#
# Fold 333/416
# Fold RMSE: 299.67, MAE: 225.33
#
# Fold 334/416
# Fold RMSE: 276.76, MAE: 206.64
#
# Fold 335/416
# Fold RMSE: 413.93, MAE: 266.37
#
# Fold 336/416
# Fold RMSE: 246.68, MAE: 164.74
#
# Fold 337/416
# Fold RMSE: 330.61, MAE: 256.66
#
# Fold 338/416
# Fold RMSE: 221.67, MAE: 174.08
#
# Fold 339/416
# Fold RMSE: 279.63, MAE: 198.00
#
# Fold 340/416
# Fold RMSE: 627.84, MAE: 377.22
#
# Fold 341/416
# Fold RMSE: 248.81, MAE: 198.90
#
# Fold 342/416
# Fold RMSE: 399.42, MAE: 316.56
#
# Fold 343/416
# Fold RMSE: 315.71, MAE: 244.86
#
# Fold 344/416
# Fold RMSE: 318.75, MAE: 252.56
#
# Fold 345/416
# Fold RMSE: 491.80, MAE: 416.44
#
# Fold 346/416
# Fold RMSE: 250.10, MAE: 176.80
#
# Fold 347/416
# Fold RMSE: 637.18, MAE: 557.66
#
# Fold 348/416
# Fold RMSE: 181.98, MAE: 129.83
#
# Fold 349/416
# Fold RMSE: 242.82, MAE: 171.52
#
# Fold 350/416
# Fold RMSE: 445.57, MAE: 227.83
#
# Fold 351/416
# Fold RMSE: 521.85, MAE: 439.95
#
# Fold 352/416
# Fold RMSE: 509.45, MAE: 378.41
#
# Fold 353/416
# Fold RMSE: 519.48, MAE: 313.23
#
# Fold 354/416
# Fold RMSE: 612.85, MAE: 457.51
#
# Fold 355/416
# Fold RMSE: 545.53, MAE: 379.08
#
# Fold 356/416
# Fold RMSE: 430.49, MAE: 348.78
#
# Fold 357/416
# Fold RMSE: 259.36, MAE: 190.01
#
# Fold 358/416
# Fold RMSE: 392.06, MAE: 335.23
#
# Fold 359/416
# Fold RMSE: 220.09, MAE: 162.65
#
# Fold 360/416
# Fold RMSE: 316.87, MAE: 246.77
#
# Fold 361/416
# Fold RMSE: 530.04, MAE: 422.23
#
# Fold 362/416
# Fold RMSE: 171.44, MAE: 133.90
#
# Fold 363/416
# Fold RMSE: 192.61, MAE: 143.63
#
# Fold 364/416
# Fold RMSE: 190.49, MAE: 146.38
#
# Fold 365/416
# Fold RMSE: 246.60, MAE: 186.66
#
# Fold 366/416
# Fold RMSE: 354.32, MAE: 293.11
#
# Fold 367/416
# Fold RMSE: 213.49, MAE: 168.68
#
# Fold 368/416
# Fold RMSE: 169.14, MAE: 121.13
#
# Fold 369/416
# Fold RMSE: 173.25, MAE: 123.84
#
# Fold 370/416
# Fold RMSE: 111.08, MAE: 66.74
#
# Fold 371/416
# Fold RMSE: 376.39, MAE: 323.03
#
# Fold 372/416
# Fold RMSE: 92.04, MAE: 66.00
#
# Fold 373/416
# Fold RMSE: 137.65, MAE: 100.90
#
# Fold 374/416
# Fold RMSE: 103.45, MAE: 80.94
#
# Fold 375/416
# Fold RMSE: 146.02, MAE: 105.76
#
# Fold 376/416
# Fold RMSE: 157.16, MAE: 102.96
#
# Fold 377/416
# Fold RMSE: 252.37, MAE: 194.20
#
# Fold 378/416
# Fold RMSE: 214.97, MAE: 163.70
#
# Fold 379/416
# Fold RMSE: 157.35, MAE: 118.52
#
# Fold 380/416
# Fold RMSE: 238.39, MAE: 178.66
#
# Fold 381/416
# Fold RMSE: 447.13, MAE: 375.65
#
# Fold 382/416
# Fold RMSE: 292.35, MAE: 240.83
#
# Fold 383/416
# Fold RMSE: 401.03, MAE: 343.34
#
# Fold 384/416
# Fold RMSE: 278.25, MAE: 192.46
#
# Fold 385/416
# Fold RMSE: 435.84, MAE: 403.13
#
# Fold 386/416
# Fold RMSE: 384.91, MAE: 323.61
#
# Fold 387/416
# Fold RMSE: 268.27, MAE: 192.32
#
# Fold 388/416
# Fold RMSE: 321.61, MAE: 263.10
#
# Fold 389/416
# Fold RMSE: 304.57, MAE: 234.53
#
# Fold 390/416
# Fold RMSE: 447.11, MAE: 378.50
#
# Fold 391/416
# Fold RMSE: 333.01, MAE: 278.79
#
# Fold 392/416
# Fold RMSE: 522.99, MAE: 453.89
#
# Fold 393/416
# Fold RMSE: 344.79, MAE: 286.83
#
# Fold 394/416
# Fold RMSE: 377.59, MAE: 297.34
#
# Fold 395/416
# Fold RMSE: 309.33, MAE: 233.50
#
# Fold 396/416
# Fold RMSE: 347.41, MAE: 246.87
#
# Fold 397/416
# Fold RMSE: 389.59, MAE: 301.34
#
# Fold 398/416
# Fold RMSE: 623.15, MAE: 520.29
#
# Fold 399/416
# Fold RMSE: 454.63, MAE: 368.87
#
# Fold 400/416
# Fold RMSE: 425.82, MAE: 335.47
#
# Fold 401/416
# Fold RMSE: 448.79, MAE: 313.14
#
# Fold 402/416
# Fold RMSE: 385.06, MAE: 281.75
#
# Fold 403/416
# Fold RMSE: 377.67, MAE: 339.51
#
# Fold 404/416
# Fold RMSE: 390.44, MAE: 293.23
#
# Fold 405/416
# Fold RMSE: 484.10, MAE: 397.74
#
# Fold 406/416
# Fold RMSE: 264.38, MAE: 216.84
#
# Fold 407/416
# Fold RMSE: 374.87, MAE: 301.32
#
# Fold 408/416
# Fold RMSE: 336.11, MAE: 250.71
#
# Fold 409/416
# Fold RMSE: 423.74, MAE: 314.18
#
# Fold 410/416
# Fold RMSE: 642.09, MAE: 378.56
#
# Fold 411/416
# Fold RMSE: 353.46, MAE: 246.07
#
# Fold 412/416
# Fold RMSE: 708.31, MAE: 620.19
#
# Fold 413/416
# Fold RMSE: 377.13, MAE: 308.71
#
# Fold 414/416
# Fold RMSE: 502.23, MAE: 382.99
#
# Fold 415/416
# Fold RMSE: 1374.37, MAE: 795.42
#
# Fold 416/416
# Fold RMSE: 596.72, MAE: 566.20
#
# Overall RMSE: 396.41
# Overall MAE: 221.68
# Average fold RMSE: 281.36 (+/- 279.24)
# Average fold MAE: 221.68 (+/- 227.37)
# Total folds: 416
# Training winow: 8760 hours
# Forecast horizon: 168 hours
# Fold 1/416
# Fold RMSE: 161.09, MAE: 143.18
#
# Fold 2/416
# Fold RMSE: 59.59, MAE: 37.04
#
# Fold 3/416
# Fold RMSE: 119.48, MAE: 55.18
#
# Fold 4/416
# Fold RMSE: 82.25, MAE: 48.24
#
# Fold 5/416
# Fold RMSE: 77.29, MAE: 52.40
#
# Fold 6/416
# Fold RMSE: 101.42, MAE: 65.79
#
# Fold 7/416
# Fold RMSE: 62.68, MAE: 34.27
#
# Fold 8/416
# Fold RMSE: 84.47, MAE: 45.43
#
# Fold 9/416
# Fold RMSE: 58.06, MAE: 35.73
#
# Fold 10/416
# Fold RMSE: 59.94, MAE: 37.99
#
# Fold 11/416
# Fold RMSE: 57.24, MAE: 32.24
#
# Fold 12/416
# Fold RMSE: 144.12, MAE: 132.58
#
# Fold 13/416
# Fold RMSE: 46.55, MAE: 33.10
#
# Fold 14/416
# Fold RMSE: 61.20, MAE: 40.57
#
# Fold 15/416
# Fold RMSE: 37.64, MAE: 17.84
#
# Fold 16/416
# Fold RMSE: 53.99, MAE: 32.38
#
# Fold 17/416
# Fold RMSE: 235.59, MAE: 218.73
#
# Fold 18/416
# Fold RMSE: 83.77, MAE: 42.48
#
# Fold 19/416
# Fold RMSE: 40.77, MAE: 27.71
#
# Fold 20/416
# Fold RMSE: 34.81, MAE: 26.59
#
# Fold 21/416
# Fold RMSE: 70.81, MAE: 55.36
#
# Fold 22/416
# Fold RMSE: 65.80, MAE: 52.56
#
# Fold 23/416
# Fold RMSE: 60.79, MAE: 47.75
#
# Fold 24/416
# Fold RMSE: 62.25, MAE: 47.23
#
# Fold 25/416
# Fold RMSE: 126.18, MAE: 111.04
#
# Fold 26/416
# Fold RMSE: 76.92, MAE: 54.43
#
# Fold 27/416
# Fold RMSE: 84.99, MAE: 66.37
#
# Fold 28/416
# Fold RMSE: 49.55, MAE: 37.42
#
# Fold 29/416
# Fold RMSE: 43.20, MAE: 36.88
#
# Fold 30/416
# Fold RMSE: 55.24, MAE: 40.47
#
# Fold 31/416
# Fold RMSE: 73.72, MAE: 63.64
#
# Fold 32/416
# Fold RMSE: 84.18, MAE: 66.75
#
# Fold 33/416
# Fold RMSE: 100.80, MAE: 84.52
#
# Fold 34/416
# Fold RMSE: 153.46, MAE: 100.35
#
# Fold 35/416
# Fold RMSE: 89.66, MAE: 61.91
#
# Fold 36/416
# Fold RMSE: 102.89, MAE: 69.81
#
# Fold 37/416
# Fold RMSE: 69.19, MAE: 53.20
#
# Fold 38/416
# Fold RMSE: 90.18, MAE: 71.60
#
# Fold 39/416
# Fold RMSE: 76.77, MAE: 56.93
#
# Fold 40/416
# Fold RMSE: 75.04, MAE: 59.05
#
# Fold 41/416
# Fold RMSE: 102.42, MAE: 75.31
#
# Fold 42/416
# Fold RMSE: 135.15, MAE: 99.98
#
# Fold 43/416
# Fold RMSE: 69.26, MAE: 44.77
#
# Fold 44/416
# Fold RMSE: 258.52, MAE: 235.87
#
# Fold 45/416
# Fold RMSE: 139.75, MAE: 84.38
#
# Fold 46/416
# Fold RMSE: 245.16, MAE: 231.75
#
# Fold 47/416
# Fold RMSE: 126.07, MAE: 98.22
#
# Fold 48/416
# Fold RMSE: 128.00, MAE: 83.35
#
# Fold 49/416
# Fold RMSE: 53.04, MAE: 32.29
#
# Fold 50/416
# Fold RMSE: 161.34, MAE: 136.69
#
# Fold 51/416
# Fold RMSE: 130.64, MAE: 81.84
#
# Fold 52/416
# Fold RMSE: 133.74, MAE: 104.79
#
# Fold 53/416
# Fold RMSE: 76.88, MAE: 47.25
#
# Fold 54/416
# Fold RMSE: 84.24, MAE: 59.66
#
# Fold 55/416
# Fold RMSE: 72.66, MAE: 45.68
#
# Fold 56/416
# Fold RMSE: 85.25, MAE: 62.13
#
# Fold 57/416
# Fold RMSE: 93.25, MAE: 55.86
#
# Fold 58/416
# Fold RMSE: 120.97, MAE: 80.55
#
# Fold 59/416
# Fold RMSE: 69.59, MAE: 47.00
#
# Fold 60/416
# Fold RMSE: 104.31, MAE: 78.47
#
# Fold 61/416
# Fold RMSE: 271.49, MAE: 132.79
#
# Fold 62/416
# Fold RMSE: 71.43, MAE: 45.27
#
# Fold 63/416
# Fold RMSE: 81.57, MAE: 57.35
#
# Fold 64/416
# Fold RMSE: 268.37, MAE: 250.77
#
# Fold 65/416
# Fold RMSE: 66.26, MAE: 48.23
#
# Fold 66/416
# Fold RMSE: 55.02, MAE: 43.59
#
# Fold 67/416
# Fold RMSE: 172.07, MAE: 159.69
#
# Fold 68/416
# Fold RMSE: 100.18, MAE: 88.50
#
# Fold 69/416
# Fold RMSE: 69.99, MAE: 60.27
#
# Fold 70/416
# Fold RMSE: 122.99, MAE: 96.08
#
# Fold 71/416
# Fold RMSE: 95.79, MAE: 77.92
#
# Fold 72/416
# Fold RMSE: 220.26, MAE: 125.28
#
# Fold 73/416
# Fold RMSE: 138.66, MAE: 90.71
#
# Fold 74/416
# Fold RMSE: 91.86, MAE: 68.30
#
# Fold 75/416
# Fold RMSE: 74.51, MAE: 60.26
#
# Fold 76/416
# Fold RMSE: 242.44, MAE: 111.45
#
# Fold 77/416
# Fold RMSE: 62.05, MAE: 39.76
#
# Fold 78/416
# Fold RMSE: 258.25, MAE: 233.83
#
# Fold 79/416
# Fold RMSE: 69.06, MAE: 57.17
#
# Fold 80/416
# Fold RMSE: 98.90, MAE: 92.91
#
# Fold 81/416
# Fold RMSE: 47.03, MAE: 41.23
#
# Fold 82/416
# Fold RMSE: 83.29, MAE: 59.90
#
# Fold 83/416
# Fold RMSE: 126.33, MAE: 100.35
#
# Fold 84/416
# Fold RMSE: 93.54, MAE: 65.26
#
# Fold 85/416
# Fold RMSE: 96.89, MAE: 80.03
#
# Fold 86/416
# Fold RMSE: 94.37, MAE: 68.20
#
# Fold 87/416
# Fold RMSE: 109.64, MAE: 86.05
#
# Fold 88/416
# Fold RMSE: 85.16, MAE: 65.13
#
# Fold 89/416
# Fold RMSE: 86.57, MAE: 58.59
#
# Fold 90/416
# Fold RMSE: 109.72, MAE: 77.50
#
# Fold 91/416
# Fold RMSE: 279.94, MAE: 260.70
#
# Fold 92/416
# Fold RMSE: 146.40, MAE: 111.10
#
# Fold 93/416
# Fold RMSE: 134.13, MAE: 98.57
#
# Fold 94/416
# Fold RMSE: 279.27, MAE: 240.10
#
# Fold 95/416
# Fold RMSE: 114.00, MAE: 83.72
#
# Fold 96/416
# Fold RMSE: 161.12, MAE: 145.49
#
# Fold 97/416
# Fold RMSE: 129.28, MAE: 97.53
#
# Fold 98/416
# Fold RMSE: 117.45, MAE: 86.14
#
# Fold 99/416
# Fold RMSE: 189.52, MAE: 134.91
#
# Fold 100/416
# Fold RMSE: 125.38, MAE: 94.65
#
# Fold 101/416
# Fold RMSE: 92.60, MAE: 70.25
#
# Fold 102/416
# Fold RMSE: 369.44, MAE: 326.03
#
# Fold 103/416
# Fold RMSE: 84.71, MAE: 57.97
#
# Fold 104/416
# Fold RMSE: 102.69, MAE: 73.07
#
# Fold 105/416
# Fold RMSE: 219.95, MAE: 125.72
#
# Fold 106/416
# Fold RMSE: 213.91, MAE: 193.82
#
# Fold 107/416
# Fold RMSE: 111.22, MAE: 73.94
#
# Fold 108/416
# Fold RMSE: 141.72, MAE: 94.58
#
# Fold 109/416
# Fold RMSE: 70.12, MAE: 48.37
#
# Fold 110/416
# Fold RMSE: 63.17, MAE: 40.04
#
# Fold 111/416
# Fold RMSE: 316.29, MAE: 292.90
#
# Fold 112/416
# Fold RMSE: 74.19, MAE: 61.54
#
# Fold 113/416
# Fold RMSE: 60.73, MAE: 48.29
#
# Fold 114/416
# Fold RMSE: 116.65, MAE: 64.03
#
# Fold 115/416
# Fold RMSE: 186.73, MAE: 176.75
#
# Fold 116/416
# Fold RMSE: 296.61, MAE: 275.09
#
# Fold 117/416
# Fold RMSE: 48.73, MAE: 39.50
#
# Fold 118/416
# Fold RMSE: 66.10, MAE: 47.88
#
# Fold 119/416
# Fold RMSE: 51.66, MAE: 40.64
#
# Fold 120/416
# Fold RMSE: 35.27, MAE: 24.72
#
# Fold 121/416
# Fold RMSE: 122.18, MAE: 70.70
#
# Fold 122/416
# Fold RMSE: 95.48, MAE: 77.72
#
# Fold 123/416
# Fold RMSE: 82.13, MAE: 66.94
#
# Fold 124/416
# Fold RMSE: 90.34, MAE: 59.78
#
# Fold 125/416
# Fold RMSE: 66.85, MAE: 49.97
#
# Fold 126/416
# Fold RMSE: 91.06, MAE: 62.75
#
# Fold 127/416
# Fold RMSE: 83.48, MAE: 62.72
#
# Fold 128/416
# Fold RMSE: 193.94, MAE: 164.36
#
# Fold 129/416
# Fold RMSE: 95.32, MAE: 68.92
#
# Fold 130/416
# Fold RMSE: 87.17, MAE: 57.10
#
# Fold 131/416
# Fold RMSE: 48.19, MAE: 27.43
#
# Fold 132/416
# Fold RMSE: 91.28, MAE: 69.09
#
# Fold 133/416
# Fold RMSE: 56.78, MAE: 39.72
#
# Fold 134/416
# Fold RMSE: 82.28, MAE: 56.39
#
# Fold 135/416
# Fold RMSE: 74.10, MAE: 51.99
#
# Fold 136/416
# Fold RMSE: 43.00, MAE: 29.42
#
# Fold 137/416
# Fold RMSE: 69.51, MAE: 42.87
#
# Fold 138/416
# Fold RMSE: 115.87, MAE: 101.71
#
# Fold 139/416
# Fold RMSE: 116.21, MAE: 88.93
#
# Fold 140/416
# Fold RMSE: 71.88, MAE: 54.37
#
# Fold 141/416
# Fold RMSE: 86.38, MAE: 67.05
#
# Fold 142/416
# Fold RMSE: 109.07, MAE: 89.09
#
# Fold 143/416
# Fold RMSE: 109.80, MAE: 86.88
#
# Fold 144/416
# Fold RMSE: 99.86, MAE: 73.21
#
# Fold 145/416
# Fold RMSE: 132.92, MAE: 90.83
#
# Fold 146/416
# Fold RMSE: 335.94, MAE: 323.12
#
# Fold 147/416
# Fold RMSE: 93.94, MAE: 73.34
#
# Fold 148/416
# Fold RMSE: 172.18, MAE: 158.27
#
# Fold 149/416
# Fold RMSE: 123.69, MAE: 103.76
#
# Fold 150/416
# Fold RMSE: 49.55, MAE: 34.41
#
# Fold 151/416
# Fold RMSE: 84.36, MAE: 60.35
#
# Fold 152/416
# Fold RMSE: 91.46, MAE: 73.95
#
# Fold 153/416
# Fold RMSE: 91.80, MAE: 68.02
#
# Fold 154/416
# Fold RMSE: 247.98, MAE: 227.27
#
# Fold 155/416
# Fold RMSE: 68.56, MAE: 49.63
#
# Fold 156/416
# Fold RMSE: 58.20, MAE: 52.83
#
# Fold 157/416
# Fold RMSE: 68.87, MAE: 44.18
#
# Fold 158/416
# Fold RMSE: 124.69, MAE: 115.05
#
# Fold 159/416
# Fold RMSE: 84.18, MAE: 77.74
#
# Fold 160/416
# Fold RMSE: 111.71, MAE: 73.95
#
# Fold 161/416
# Fold RMSE: 46.49, MAE: 27.48
#
# Fold 162/416
# Fold RMSE: 187.65, MAE: 168.48
#
# Fold 163/416
# Fold RMSE: 96.85, MAE: 57.97
#
# Fold 164/416
# Fold RMSE: 73.27, MAE: 40.20
#
# Fold 165/416
# Fold RMSE: 189.27, MAE: 150.38
#
# Fold 166/416
# Fold RMSE: 161.25, MAE: 128.17
#
# Fold 167/416
# Fold RMSE: 113.52, MAE: 99.53
#
# Fold 168/416
# Fold RMSE: 135.67, MAE: 114.91
#
# Fold 169/416
# Fold RMSE: 62.88, MAE: 52.99
#
# Fold 170/416
# Fold RMSE: 91.66, MAE: 74.05
#
# Fold 171/416
# Fold RMSE: 74.85, MAE: 56.63
#
# Fold 172/416
# Fold RMSE: 120.40, MAE: 89.59
#
# Fold 173/416
# Fold RMSE: 80.92, MAE: 66.05
#
# Fold 174/416
# Fold RMSE: 129.03, MAE: 110.75
#
# Fold 175/416
# Fold RMSE: 98.86, MAE: 79.85
#
# Fold 176/416
# Fold RMSE: 61.24, MAE: 44.55
#
# Fold 177/416
# Fold RMSE: 120.13, MAE: 91.45
#
# Fold 178/416
# Fold RMSE: 124.81, MAE: 101.90
#
# Fold 179/416
# Fold RMSE: 110.27, MAE: 84.43
#
# Fold 180/416
# Fold RMSE: 195.43, MAE: 176.05
#
# Fold 181/416
# Fold RMSE: 124.40, MAE: 96.96
#
# Fold 182/416
# Fold RMSE: 212.06, MAE: 145.58
#
# Fold 183/416
# Fold RMSE: 94.25, MAE: 77.12
#
# Fold 184/416
# Fold RMSE: 197.79, MAE: 143.83
#
# Fold 185/416
# Fold RMSE: 217.37, MAE: 190.91
#
# Fold 186/416
# Fold RMSE: 69.97, MAE: 55.19
#
# Fold 187/416
# Fold RMSE: 129.78, MAE: 107.49
#
# Fold 188/416
# Fold RMSE: 85.75, MAE: 67.12
#
# Fold 189/416
# Fold RMSE: 106.78, MAE: 83.70
#
# Fold 190/416
# Fold RMSE: 233.13, MAE: 154.00
#
# Fold 191/416
# Fold RMSE: 184.06, MAE: 144.93
#
# Fold 192/416
# Fold RMSE: 140.43, MAE: 107.44
#
# Fold 193/416
# Fold RMSE: 137.28, MAE: 104.47
#
# Fold 194/416
# Fold RMSE: 243.68, MAE: 173.71
#
# Fold 195/416
# Fold RMSE: 165.83, MAE: 107.69
#
# Fold 196/416
# Fold RMSE: 271.51, MAE: 211.84
#
# Fold 197/416
# Fold RMSE: 199.51, MAE: 162.68
#
# Fold 198/416
# Fold RMSE: 191.01, MAE: 148.70
#
# Fold 199/416
# Fold RMSE: 129.58, MAE: 95.01
#
# Fold 200/416
# Fold RMSE: 120.62, MAE: 87.21
#
# Fold 201/416
# Fold RMSE: 156.68, MAE: 148.69
#
# Fold 202/416
# Fold RMSE: 220.33, MAE: 161.82
#
# Fold 203/416
# Fold RMSE: 226.12, MAE: 170.26
#
# Fold 204/416
# Fold RMSE: 203.00, MAE: 178.83
#
# Fold 205/416
# Fold RMSE: 278.53, MAE: 170.74
#
# Fold 206/416
# Fold RMSE: 290.67, MAE: 214.95
#
# Fold 207/416
# Fold RMSE: 290.08, MAE: 194.08
#
# Fold 208/416
# Fold RMSE: 121.44, MAE: 82.38
#
# Fold 209/416
# Fold RMSE: 175.96, MAE: 150.95
#
# Fold 210/416
# Fold RMSE: 171.50, MAE: 129.66
#
# Fold 211/416
# Fold RMSE: 147.25, MAE: 108.45
#
# Fold 212/416
# Fold RMSE: 117.54, MAE: 95.64
#
# Fold 213/416
# Fold RMSE: 245.28, MAE: 230.00
#
# Fold 214/416
# Fold RMSE: 300.26, MAE: 173.40
#
# Fold 215/416
# Fold RMSE: 329.64, MAE: 197.58
#
# Fold 216/416
# Fold RMSE: 132.55, MAE: 73.14
#
# Fold 217/416
# Fold RMSE: 72.81, MAE: 53.78
#
# Fold 218/416
# Fold RMSE: 101.27, MAE: 77.44
#
# Fold 219/416
# Fold RMSE: 155.56, MAE: 118.71
#
# Fold 220/416
# Fold RMSE: 216.59, MAE: 182.24
#
# Fold 221/416
# Fold RMSE: 134.19, MAE: 105.47
#
# Fold 222/416
# Fold RMSE: 127.68, MAE: 103.64
#
# Fold 223/416
# Fold RMSE: 159.75, MAE: 124.31
#
# Fold 224/416
# Fold RMSE: 176.15, MAE: 134.56
#
# Fold 225/416
# Fold RMSE: 157.83, MAE: 113.37
#
# Fold 226/416
# Fold RMSE: 130.63, MAE: 92.45
#
# Fold 227/416
# Fold RMSE: 122.38, MAE: 100.81
#
# Fold 228/416
# Fold RMSE: 169.36, MAE: 143.32
#
# Fold 229/416
# Fold RMSE: 175.28, MAE: 138.48
#
# Fold 230/416
# Fold RMSE: 425.50, MAE: 378.62
#
# Fold 231/416
# Fold RMSE: 127.26, MAE: 99.64
#
# Fold 232/416
# Fold RMSE: 146.61, MAE: 120.53
#
# Fold 233/416
# Fold RMSE: 230.41, MAE: 184.52
#
# Fold 234/416
# Fold RMSE: 167.02, MAE: 135.64
#
# Fold 235/416
# Fold RMSE: 118.92, MAE: 94.31
#
# Fold 236/416
# Fold RMSE: 150.23, MAE: 116.16
#
# Fold 237/416
# Fold RMSE: 131.26, MAE: 102.65
#
# Fold 238/416
# Fold RMSE: 201.05, MAE: 170.24
#
# Fold 239/416
# Fold RMSE: 182.44, MAE: 138.95
#
# Fold 240/416
# Fold RMSE: 321.05, MAE: 273.71
#
# Fold 241/416
# Fold RMSE: 285.20, MAE: 237.69
#
# Fold 242/416
# Fold RMSE: 158.11, MAE: 129.22
#
# Fold 243/416
# Fold RMSE: 115.03, MAE: 97.79
#
# Fold 244/416
# Fold RMSE: 247.55, MAE: 198.58
#
# Fold 245/416
# Fold RMSE: 257.60, MAE: 205.75
#
# Fold 246/416
# Fold RMSE: 308.56, MAE: 251.40
#
# Fold 247/416
# Fold RMSE: 473.67, MAE: 381.43
#
# Fold 248/416
# Fold RMSE: 553.10, MAE: 458.41
#
# Fold 249/416
# Fold RMSE: 1253.37, MAE: 1053.98
#
# Fold 250/416
# Fold RMSE: 497.35, MAE: 397.53
#
# Fold 251/416
# Fold RMSE: 812.37, MAE: 597.95
#
# Fold 252/416
# Fold RMSE: 678.56, MAE: 542.15
#
# Fold 253/416
# Fold RMSE: 627.87, MAE: 469.75
#
# Fold 254/416
# Fold RMSE: 1013.13, MAE: 809.07
#
# Fold 255/416
# Fold RMSE: 764.00, MAE: 613.21
#
# Fold 256/416
# Fold RMSE: 1231.89, MAE: 971.19
#
# Fold 257/416
# Fold RMSE: 715.63, MAE: 533.84
#
# Fold 258/416
# Fold RMSE: 1100.75, MAE: 856.67
#
# Fold 259/416
# Fold RMSE: 781.48, MAE: 648.30
#
# Fold 260/416
# Fold RMSE: 1315.27, MAE: 1050.96
#
# Fold 261/416
# Fold RMSE: 529.41, MAE: 456.67
#
# Fold 262/416
# Fold RMSE: 704.61, MAE: 560.45
#
# Fold 263/416
# Fold RMSE: 685.66, MAE: 527.70
#
# Fold 264/416
# Fold RMSE: 625.04, MAE: 491.52
#
# Fold 265/416
# Fold RMSE: 520.93, MAE: 417.35
#
# Fold 266/416
# Fold RMSE: 956.32, MAE: 791.81
#
# Fold 267/416
# Fold RMSE: 652.42, MAE: 535.49
#
# Fold 268/416
# Fold RMSE: 649.97, MAE: 571.25
#
# Fold 269/416
# Fold RMSE: 523.38, MAE: 432.36
#
# Fold 270/416
# Fold RMSE: 1075.63, MAE: 905.74
#
# Fold 271/416
# Fold RMSE: 1191.75, MAE: 895.25
#
# Fold 272/416
# Fold RMSE: 1105.55, MAE: 916.41
#
# Fold 273/416
# Fold RMSE: 687.06, MAE: 512.61
#
# Fold 274/416
# Fold RMSE: 1363.51, MAE: 1244.33
#
# Fold 275/416
# Fold RMSE: 507.22, MAE: 444.96
#
# Fold 276/416
# Fold RMSE: 1111.24, MAE: 907.46
#
# Fold 277/416
# Fold RMSE: 465.24, MAE: 342.01
#
# Fold 278/416
# Fold RMSE: 1180.88, MAE: 1084.13
#
# Fold 279/416
# Fold RMSE: 348.65, MAE: 272.64
#
# Fold 280/416
# Fold RMSE: 650.08, MAE: 450.07
#
# Fold 281/416
# Fold RMSE: 1358.38, MAE: 1244.85
#
# Fold 282/416
# Fold RMSE: 571.35, MAE: 525.56
#
# Fold 283/416
# Fold RMSE: 1355.92, MAE: 1268.28
#
# Fold 284/416
# Fold RMSE: 355.57, MAE: 249.14
#
# Fold 285/416
# Fold RMSE: 549.74, MAE: 413.12
#
# Fold 286/416
# Fold RMSE: 838.04, MAE: 682.41
#
# Fold 287/416
# Fold RMSE: 810.76, MAE: 688.92
#
# Fold 288/416
# Fold RMSE: 650.66, MAE: 475.42
#
# Fold 289/416
# Fold RMSE: 1701.08, MAE: 1083.25
#
# Fold 290/416
# Fold RMSE: 1193.41, MAE: 980.75
#
# Fold 291/416
# Fold RMSE: 1367.24, MAE: 1144.08
#
# Fold 292/416
# Fold RMSE: 1215.89, MAE: 972.98
#
# Fold 293/416
# Fold RMSE: 1376.29, MAE: 1213.54
#
# Fold 294/416
# Fold RMSE: 1033.25, MAE: 850.05
#
# Fold 295/416
# Fold RMSE: 1210.45, MAE: 991.06
#
# Fold 296/416
# Fold RMSE: 1353.31, MAE: 999.20
#
# Fold 297/416
# Fold RMSE: 1484.06, MAE: 1246.44
#
# Fold 298/416
# Fold RMSE: 830.20, MAE: 637.88
#
# Fold 299/416
# Fold RMSE: 1903.37, MAE: 1598.84
#
# Fold 300/416
# Fold RMSE: 791.74, MAE: 612.74
#
# Fold 301/416
# Fold RMSE: 908.04, MAE: 584.00
#
# Fold 302/416
# Fold RMSE: 1351.81, MAE: 1124.52
#
# Fold 303/416
# Fold RMSE: 423.90, MAE: 309.32
#
# Fold 304/416
# Fold RMSE: 289.38, MAE: 229.08
#
# Fold 305/416
# Fold RMSE: 747.51, MAE: 646.04
#
# Fold 306/416
# Fold RMSE: 388.78, MAE: 300.24
#
# Fold 307/416
# Fold RMSE: 952.72, MAE: 817.80
#
# Fold 308/416
# Fold RMSE: 837.12, MAE: 690.84
#
# Fold 309/416
# Fold RMSE: 1086.20, MAE: 853.54
#
# Fold 310/416
# Fold RMSE: 1030.81, MAE: 830.99
#
# Fold 311/416
# Fold RMSE: 1055.76, MAE: 809.36
#
# Fold 312/416
# Fold RMSE: 705.09, MAE: 575.91
#
# Fold 313/416
# Fold RMSE: 361.47, MAE: 302.29
#
# Fold 314/416
# Fold RMSE: 747.91, MAE: 617.63
#
# Fold 315/416
# Fold RMSE: 327.47, MAE: 250.37
#
# Fold 316/416
# Fold RMSE: 577.15, MAE: 440.30
#
# Fold 317/416
# Fold RMSE: 378.83, MAE: 296.11
#
# Fold 318/416
# Fold RMSE: 542.29, MAE: 466.63
#
# Fold 319/416
# Fold RMSE: 553.81, MAE: 497.85
#
# Fold 320/416
# Fold RMSE: 658.05, MAE: 541.85
#
# Fold 321/416
# Fold RMSE: 530.71, MAE: 408.89
#
# Fold 322/416
# Fold RMSE: 777.74, MAE: 673.04
#
# Fold 323/416
# Fold RMSE: 736.60, MAE: 695.87
#
# Fold 324/416
# Fold RMSE: 236.78, MAE: 203.70
#
# Fold 325/416
# Fold RMSE: 322.38, MAE: 266.61
#
# Fold 326/416
# Fold RMSE: 596.05, MAE: 521.72
#
# Fold 327/416
# Fold RMSE: 589.25, MAE: 505.01
#
# Fold 328/416
# Fold RMSE: 331.28, MAE: 278.63
#
# Fold 329/416
# Fold RMSE: 289.98, MAE: 245.97
#
# Fold 330/416
# Fold RMSE: 284.97, MAE: 225.94
#
# Fold 331/416
# Fold RMSE: 288.49, MAE: 229.26
#
# Fold 332/416
# Fold RMSE: 288.04, MAE: 230.35
#
# Fold 333/416
# Fold RMSE: 333.36, MAE: 244.63
#
# Fold 334/416
# Fold RMSE: 288.22, MAE: 224.73
#
# Fold 335/416
# Fold RMSE: 317.25, MAE: 230.71
#
# Fold 336/416
# Fold RMSE: 251.67, MAE: 181.92
#
# Fold 337/416
# Fold RMSE: 595.55, MAE: 522.50
#
# Fold 338/416
# Fold RMSE: 221.17, MAE: 173.59
#
# Fold 339/416
# Fold RMSE: 267.18, MAE: 191.72
#
# Fold 340/416
# Fold RMSE: 382.77, MAE: 326.64
#
# Fold 341/416
# Fold RMSE: 254.29, MAE: 206.10
#
# Fold 342/416
# Fold RMSE: 397.47, MAE: 318.37
#
# Fold 343/416
# Fold RMSE: 325.27, MAE: 254.86
#
# Fold 344/416
# Fold RMSE: 313.52, MAE: 246.51
#
# Fold 345/416
# Fold RMSE: 495.89, MAE: 421.14
#
# Fold 346/416
# Fold RMSE: 248.73, MAE: 174.94
#
# Fold 347/416
# Fold RMSE: 637.33, MAE: 557.93
#
# Fold 348/416
# Fold RMSE: 182.02, MAE: 129.74
#
# Fold 349/416
# Fold RMSE: 242.70, MAE: 171.40
#
# Fold 350/416
# Fold RMSE: 443.93, MAE: 221.79
#
# Fold 351/416
# Fold RMSE: 512.51, MAE: 431.94
#
# Fold 352/416
# Fold RMSE: 507.14, MAE: 373.75
#
# Fold 353/416
# Fold RMSE: 519.49, MAE: 313.99
#
# Fold 354/416
# Fold RMSE: 613.29, MAE: 452.59
#
# Fold 355/416
# Fold RMSE: 526.53, MAE: 320.83
#
# Fold 356/416
# Fold RMSE: 612.69, MAE: 523.81
#
# Fold 357/416
# Fold RMSE: 253.48, MAE: 200.52
#
# Fold 358/416
# Fold RMSE: 319.19, MAE: 242.38
#
# Fold 359/416
# Fold RMSE: 222.94, MAE: 165.71
#
# Fold 360/416
# Fold RMSE: 381.73, MAE: 310.36
#
# Fold 361/416
# Fold RMSE: 855.16, MAE: 777.82
#
# Fold 362/416
# Fold RMSE: 356.36, MAE: 225.79
#
# Fold 363/416
# Fold RMSE: 256.48, MAE: 181.52
#
# Fold 364/416
# Fold RMSE: 180.20, MAE: 156.91
#
# Fold 365/416
# Fold RMSE: 253.95, MAE: 211.25
#
# Fold 366/416
# Fold RMSE: 662.61, MAE: 407.93
#
# Fold 367/416
# Fold RMSE: 201.50, MAE: 155.41
#
# Fold 368/416
# Fold RMSE: 287.83, MAE: 164.45
#
# Fold 369/416
# Fold RMSE: 183.78, MAE: 142.53
#
# Fold 370/416
# Fold RMSE: 271.86, MAE: 205.05
#
# Fold 371/416
# Fold RMSE: 434.47, MAE: 377.50
#
# Fold 372/416
# Fold RMSE: 116.77, MAE: 82.54
#
# Fold 373/416
# Fold RMSE: 268.72, MAE: 233.52
#
# Fold 374/416
# Fold RMSE: 128.83, MAE: 96.73
#
# Fold 375/416
# Fold RMSE: 142.04, MAE: 99.29
#
# Fold 376/416
# Fold RMSE: 162.18, MAE: 112.03
#
# Fold 377/416
# Fold RMSE: 294.76, MAE: 228.38
#
# Fold 378/416
# Fold RMSE: 209.75, MAE: 159.27
#
# Fold 379/416
# Fold RMSE: 183.10, MAE: 139.09
#
# Fold 380/416
# Fold RMSE: 266.18, MAE: 207.44
#
# Fold 381/416
# Fold RMSE: 445.32, MAE: 371.56
#
# Fold 382/416
# Fold RMSE: 295.15, MAE: 243.03
#
# Fold 383/416
# Fold RMSE: 402.54, MAE: 346.08
#
# Fold 384/416
# Fold RMSE: 279.96, MAE: 197.70
#
# Fold 385/416
# Fold RMSE: 530.34, MAE: 498.49
#
# Fold 386/416
# Fold RMSE: 375.41, MAE: 320.17
#
# Fold 387/416
# Fold RMSE: 274.79, MAE: 191.53
#
# Fold 388/416
# Fold RMSE: 360.32, MAE: 289.84
#
# Fold 389/416
# Fold RMSE: 317.55, MAE: 252.32
#
# Fold 390/416
# Fold RMSE: 455.55, MAE: 382.78
#
# Fold 391/416
# Fold RMSE: 324.93, MAE: 273.08
#
# Fold 392/416
# Fold RMSE: 502.95, MAE: 428.78
#
# Fold 393/416
# Fold RMSE: 354.64, MAE: 295.55
#
# Fold 394/416
# Fold RMSE: 505.60, MAE: 405.71
#
# Fold 395/416
# Fold RMSE: 306.00, MAE: 233.40
#
# Fold 396/416
# Fold RMSE: 354.26, MAE: 254.24
#
# Fold 397/416
# Fold RMSE: 374.29, MAE: 286.71
#
# Fold 398/416
# Fold RMSE: 619.71, MAE: 505.78
#
# Fold 399/416
# Fold RMSE: 445.68, MAE: 359.83
#
# Fold 400/416
# Fold RMSE: 436.56, MAE: 349.47
#
# Fold 401/416
# Fold RMSE: 449.17, MAE: 315.23
#
# Fold 402/416
# Fold RMSE: 388.77, MAE: 283.08
#
# Fold 403/416
# Fold RMSE: 491.68, MAE: 434.98
#
# Fold 404/416
# Fold RMSE: 410.13, MAE: 314.16
#
# Fold 405/416
# Fold RMSE: 478.17, MAE: 379.04
#
# Fold 406/416
# Fold RMSE: 288.67, MAE: 232.75
#
# Fold 407/416
# Fold RMSE: 387.39, MAE: 312.57
#
# Fold 408/416
# Fold RMSE: 333.67, MAE: 244.66
#
# Fold 409/416
# Fold RMSE: 424.17, MAE: 314.82
#
# Fold 410/416
# Fold RMSE: 647.54, MAE: 388.43
#
# Fold 411/416
# Fold RMSE: 359.89, MAE: 250.00
#
# Fold 412/416
# Fold RMSE: 682.88, MAE: 585.82
#
# Fold 413/416
# Fold RMSE: 377.43, MAE: 302.67
#
# Fold 414/416
# Fold RMSE: 516.15, MAE: 404.69
#
# Fold 415/416
# Fold RMSE: 1392.17, MAE: 804.58
#
# Fold 416/416
# Fold RMSE: 580.07, MAE: 548.97
#
# Overall RMSE: 457.52
# Overall MAE: 253.80
# Average fold RMSE: 320.22 (+/- 326.77)
# Average fold MAE: 253.80 (+/- 268.63)

# %%
title_DK1 = 'Walk-Forward Validation - Naive Persistence: Actual vs. Predicted for DK1'

plot_walk_forward_results(
        predictions_DK1, 
        actuals_DK1, 
        title_DK1)

title_DK2 = 'Walk-Forward Validation - Naive Persistence: Actual vs. Predicted for DK2'

plot_walk_forward_results(
        predictions_DK2, 
        actuals_DK2, 
        title_DK2)
