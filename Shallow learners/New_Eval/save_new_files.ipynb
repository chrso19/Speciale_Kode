# %%
import pandas as pd

price_zone = "DK2"

if price_zone == "DK1":
    # filename_lasso_DK = "DK1_Lasso_predictions.csv"
    # df_lasso = pd.read_csv(filename_lasso_DK, decimal = ",")

    # filename_SVR_DK = "DK1_SVR_predictions.csv"
    # df_SVR = pd.read_csv(filename_SVR_DK, decimal = ",")

    # filename_XGB_DK = "DK1_XGBoost_predictions.csv"
    # df_XGB = pd.read_csv(filename_XGB_DK, decimal = ",")

    # filename_lightgbm_DK = "DK1_LightGBM_predictions.csv"
    # df_lightgbm = pd.read_csv(filename_lightgbm_DK, decimal = ",")

    # filename_RF_DK = "DK1_RF_predictions.csv"
    # df_RF = pd.read_csv(filename_RF_DK, decimal = ",")

    filename_arima_DK = "DK1_ARIMA_predictions.csv"
    df_arima = pd.read_csv(filename_arima_DK, decimal = ",", sep = ";")

elif price_zone == "DK2":
    # filename_lasso_DK = "DK2_Lasso_predictions.csv"
    # df_lasso = pd.read_csv(filename_lasso_DK, decimal = ",")

    # filename_SVR_DK = "DK2_SVR_predictions.csv"
    # df_SVR = pd.read_csv(filename_SVR_DK, decimal = ",")

    # filename_XGB_DK = "DK2_XGBoost_predictions.csv"
    # df_XGB = pd.read_csv(filename_XGB_DK, decimal = ",")

    # filename_lightgbm_DK = "DK2_LightGBM_predictions.csv"
    # df_lightgbm = pd.read_csv(filename_lightgbm_DK, decimal = ",")

    # filename_RF_DK = "DK2_RF_predictions.csv"
    # df_RF = pd.read_csv(filename_RF_DK, decimal = ",")

    filename_arima_DK = "DK2_ARIMA_predictions.csv"
    df_arima = pd.read_csv(filename_arima_DK, decimal = ",", sep = ";")


# df_lasso.to_csv(filename_lasso_DK, decimal = ".")
# df_SVR.to_csv(filename_SVR_DK, decimal = ".")
# df_XGB.to_csv(filename_XGB_DK, decimal = ".")
# df_lightgbm.to_csv(filename_lightgbm_DK, decimal = ".")
# df_RF.to_csv(filename_RF_DK, decimal = ".")
df_arima.to_csv(filename_arima_DK, decimal = ".")
