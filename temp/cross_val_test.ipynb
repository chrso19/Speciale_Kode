# %%
# Importing packages

import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
import datetime as dt
from pandas.tseries.offsets import DateOffset
from tqdm import tqdm
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset, Dataset
import torchvision
import os

# %%
# Load data 

file_dir = os.path.dirname(os.path.realpath('cross_val_test.ipynb'))
python_dir = os.path.dirname(file_dir)
# speciale_path = os.path.join(python_dir, 'Speciale_Kode')
# temp_path = os.path.join(speciale_path, 'temp')
temp_path = os.path.join(python_dir, 'temp')
data_path = os.path.join(temp_path, 'GenerationProdTypeExchange.csv')

df = pd.read_csv(data_path, sep=';', decimal=',')
df_filtered = df[df['PriceArea'] == 'DK1']
df_DK1 = df_filtered[["TimeDK", "GrossCon"]]
df_DK1 = df_DK1.sort_values(by='TimeDK', ascending=True)
df_DK1.reset_index(drop=True, inplace=True)
df_DK1['TimeDK'] = pd.to_datetime(df_DK1['TimeDK'])
df_DK1['GrossCon'] = df_DK1['GrossCon'].astype(float)

train_set = df_DK1.copy()

# train_set = df_DK1.loc[df_DK1['TimeDK'] < pd.Timestamp('2026-02-07')]
# train_set.reset_index(drop=True, inplace=True)
# test_set = df_DK1.loc[df_DK1['TimeDK'] >= pd.Timestamp('2026-02-07')]
# test_set.reset_index(drop=True, inplace=True)

print(f"Training data shape: {train_set.shape}")
# print(f"Test data shape: {test_set.shape}")
# print(f"Test set fraction: {len(test_set)/len(train_set):.2%}")
# Out:
# Training data shape: (17520, 2)

# %%
np.random.seed(42)
torch.manual_seed(42)

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
    print("CUDA version:", torch.version.cuda)
    print("Device count:", torch.cuda.device_count())

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# CUDA available: True
# GPU: NVIDIA GeForce GTX 1660
# CUDA version: 12.1
# Device count: 1

# %%
class SequenceDataset(Dataset):
    def __init__(self, data, sequence_length=24):
        """
        data: numpy array of shape (n_samples,)
        sequence_length: how many past timesteps to use
        """
        self.sequence_length = sequence_length
        self.data = torch.FloatTensor(data).unsqueeze(1)  # Add feature dimension
        
    def __len__(self):
        return len(self.data) - self.sequence_length
    
    def __getitem__(self, idx):
        # Get sequence of past values
        x = self.data[idx:idx + self.sequence_length]
        # Target is the next value
        y = self.data[idx + self.sequence_length]
        return x, y

# %%
class LSTMModel(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers, output_size):
        super(LSTMModel, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True)
        self.fc = nn.Linear(hidden_size, output_size)
    
    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        c0 = torch.zeros(self.num_layers, x.size(0), self.hidden_size).to(x.device)
        out, _ = self.lstm(x, (h0, c0))
        out = self.fc(out[:, -1, :])  # Take last time step
        return out

# %%
def perform_walk_forward_validation_lstm(
    data_series, 
    training_window=1440,  
    forecast_horizon=720,  
    sequence_length=24,   
    hidden_size=64,
    num_layers=2,
    learning_rate=0.001,
    num_epochs=50,
    batch_size=16
):
    """
    Walk-forward validation for PyTorch LSTM.
    """
    all_predictions = []
    all_actuals = []
    fold_errors = []

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    
    # Calculate number of folds
    num_folds = (len(data_series) - training_window - forecast_horizon) // forecast_horizon + 1
    
    print(f"Total folds: {num_folds}")
    print(f"Training window: {training_window} hours")
    print(f"Forecast horizon: {forecast_horizon} hours")
    print(f"Sequence length: {sequence_length} hours\n")
    
    for fold in range(num_folds):
        start = fold * forecast_horizon
        
        # Check if we have enough data
        if start + training_window + forecast_horizon > len(data_series):
            break
            
        print(f"Fold {fold + 1}/{num_folds}")
        
        # Split data
        train_data = data_series[start:start + training_window]
        val_data = data_series[start + training_window:start + training_window + forecast_horizon]
        
        # Standardize using training statistics
        train_mean = train_data.mean()
        train_std = train_data.std()
        
        train_data_scaled = (train_data - train_mean) / train_std
        val_data_scaled = (val_data - train_mean) / train_std
        
        # Create datasets
        train_dataset = SequenceDataset(train_data_scaled, sequence_length)
        val_dataset = SequenceDataset(val_data_scaled, sequence_length)
        
        # Create dataloaders
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=False)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)
        
        # Initialize model for this fold
        model = LSTMModel(
            input_size=1,  # Single feature (GrossCon)
            hidden_size=hidden_size,
            num_layers=num_layers,
            output_size=1
        ).to(device) 
        
        criterion = nn.MSELoss()
        optimizer = optim.Adam(model.parameters(), lr=learning_rate)
        
        # Training loop
        model.train()
        for epoch in range(num_epochs):
            epoch_loss = 0
            for X_batch, y_batch in train_loader:
                X_batch = X_batch.to(device)
                y_batch = y_batch.to(device)
                optimizer.zero_grad()
                output = model(X_batch)
                loss = criterion(output, y_batch)
                loss.backward()
                optimizer.step()
                epoch_loss += loss.item()
            
            if (epoch + 1) % 10 == 0:
                avg_loss = epoch_loss / len(train_loader)
                print(f"  Epoch {epoch+1}/{num_epochs}, Loss: {avg_loss:.4f}")
        
        # Make predictions - autoregressive
        model.eval()
        predictions = []

        with torch.no_grad():
            # Seed with the last sequence_length hours of real training data
            input_seq = torch.FloatTensor(train_data_scaled[-sequence_length:]).unsqueeze(0).unsqueeze(-1).to(device)
            # Shape: (1, sequence_length, 1)
            
            for step in range(forecast_horizon):
                # Predict next step
                output = model(input_seq)
                next_val = output.squeeze().item()
                predictions.append(next_val)
                
                # Drop oldest timestep, append new prediction
                next_tensor = torch.FloatTensor([[[next_val]]]).to(device)
                input_seq = torch.cat([input_seq[:, 1:, :], next_tensor], dim=1)
        
        # Un-standardize
        predictions = np.array(predictions) * train_std + train_mean
        actuals = np.array(val_data)

        print(f"  Predictions shape: {predictions.shape}")
        print(f"  Actuals shape: {actuals.shape}")
        assert len(predictions) == forecast_horizon, f"Expected {forecast_horizon} predictions, got {len(predictions)}"
        assert len(actuals) == forecast_horizon, f"Expected {forecast_horizon} actuals, got {len(actuals)}"
        
        # Calculate error
        fold_mse = mean_squared_error(actuals, predictions)
        fold_rmse = np.sqrt(fold_mse)
        fold_mae = mean_absolute_error(actuals, predictions)
        
        fold_errors.append(fold_rmse)
        all_predictions.extend(predictions)
        all_actuals.extend(actuals)
        
        print(f"  Fold RMSE: {fold_rmse:.2f}, MAE: {fold_mae:.2f}\n")
    
    # Overall metrics
    overall_rmse = np.sqrt(mean_squared_error(all_actuals, all_predictions))
    overall_mae = mean_absolute_error(all_actuals, all_predictions)
    
    print(f"Overall RMSE: {overall_rmse:.2f}")
    print(f"Overall MAE: {overall_mae:.2f}")
    print(f"Average Fold RMSE: {np.mean(fold_errors):.2f} (+/- {np.std(fold_errors):.2f})")
    
    return all_predictions, all_actuals, fold_errors

# %%
def plot_walk_forward_results(predictions, actuals, training_window=1440, forecast_horizon=720):
    """
    Plot walk-forward validation results.
    """
    plt.figure(figsize=(15, 6))
    
    # Create x-axis (fold numbers repeated for each prediction in that fold)
    x = []
    fold_num = 0
    for i in range(len(predictions)):
        if i % (forecast_horizon) == 0 and i > 0:
            fold_num += 1
        x.append(fold_num)
    
    plt.plot(actuals, label='Actual', alpha=0.7, linewidth=2)
    plt.plot(predictions, label='Predicted', alpha=0.7, linewidth=2)
    
    # Add vertical lines to separate folds
    for i in range(0, len(predictions), forecast_horizon):
        plt.axvline(x=i, color='gray', linestyle='--', alpha=0.3)
    
    plt.xlabel('Time Step')
    plt.ylabel('Gross Consumption')
    plt.title('Walk-Forward Validation: Predicted vs Actual')
    plt.legend()
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.show()

# %%
predictions, actuals, fold_errors = perform_walk_forward_validation_lstm(
    data_series=train_set['GrossCon'].values,
    training_window=1440,  
    forecast_horizon=168,  
    sequence_length=24,   
    hidden_size=64,
    num_layers=2,
    learning_rate=0.001,
    num_epochs=50,
    batch_size=16
)

# Plot results
plot_walk_forward_results(predictions, actuals)
# Out:
# Using device: cuda
# Total folds: 95
# Training window: 1440 hours
# Forecast horizon: 168 hours
# Sequence length: 24 hours
#
# Fold 1/95
#   Epoch 10/50, Loss: 0.0651
#   Epoch 20/50, Loss: 0.0526
#   Epoch 30/50, Loss: 0.0510
#   Epoch 40/50, Loss: 0.0464
#   Epoch 50/50, Loss: 0.0424
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 573.02, MAE: 492.45
#
# Fold 2/95
#   Epoch 10/50, Loss: 0.0613
#   Epoch 20/50, Loss: 0.0540
#   Epoch 30/50, Loss: 0.0507
#   Epoch 40/50, Loss: 0.0497
#   Epoch 50/50, Loss: 0.0464
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 300.72, MAE: 251.45
#
# Fold 3/95
#   Epoch 10/50, Loss: 0.0683
#   Epoch 20/50, Loss: 0.0599
#   Epoch 30/50, Loss: 0.0567
#   Epoch 40/50, Loss: 0.0527
#   Epoch 50/50, Loss: 0.0454
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 432.74, MAE: 356.11
#
# Fold 4/95
#   Epoch 10/50, Loss: 0.0678
#   Epoch 20/50, Loss: 0.0582
#   Epoch 30/50, Loss: 0.0555
#   Epoch 40/50, Loss: 0.0528
#   Epoch 50/50, Loss: 0.0503
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 578.43, MAE: 482.08
#
# Fold 5/95
#   Epoch 10/50, Loss: 0.0705
#   Epoch 20/50, Loss: 0.0586
#   Epoch 30/50, Loss: 0.0507
#   Epoch 40/50, Loss: 0.0457
#   Epoch 50/50, Loss: 0.0438
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 728.20, MAE: 595.73
#
# Fold 6/95
#   Epoch 10/50, Loss: 0.0737
#   Epoch 20/50, Loss: 0.0632
#   Epoch 30/50, Loss: 0.0560
#   Epoch 40/50, Loss: 0.0499
#   Epoch 50/50, Loss: 0.0438
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 518.91, MAE: 418.71
#
# Fold 7/95
#   Epoch 10/50, Loss: 0.0751
#   Epoch 20/50, Loss: 0.0638
#   Epoch 30/50, Loss: 0.0576
#   Epoch 40/50, Loss: 0.0502
#   Epoch 50/50, Loss: 0.0467
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 615.62, MAE: 551.10
#
# Fold 8/95
#   Epoch 10/50, Loss: 0.0734
#   Epoch 20/50, Loss: 0.0607
#   Epoch 30/50, Loss: 0.0547
#   Epoch 40/50, Loss: 0.0484
#   Epoch 50/50, Loss: 0.0433
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 320.08, MAE: 249.77
#
# Fold 9/95
#   Epoch 10/50, Loss: 0.0650
#   Epoch 20/50, Loss: 0.0514
#   Epoch 30/50, Loss: 0.0464
#   Epoch 40/50, Loss: 0.0429
#   Epoch 50/50, Loss: 0.0377
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 438.65, MAE: 351.25
#
# Fold 10/95
#   Epoch 10/50, Loss: 0.0627
#   Epoch 20/50, Loss: 0.0536
#   Epoch 30/50, Loss: 0.0455
#   Epoch 40/50, Loss: 0.0400
#   Epoch 50/50, Loss: 0.0364
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 320.10, MAE: 223.84
#
# Fold 11/95
#   Epoch 10/50, Loss: 0.0537
#   Epoch 20/50, Loss: 0.0451
#   Epoch 30/50, Loss: 0.0433
#   Epoch 40/50, Loss: 0.0407
#   Epoch 50/50, Loss: 0.0346
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 389.08, MAE: 310.07
#
# Fold 12/95
#   Epoch 10/50, Loss: 0.0461
#   Epoch 20/50, Loss: 0.0404
#   Epoch 30/50, Loss: 0.0384
#   Epoch 40/50, Loss: 0.0361
#   Epoch 50/50, Loss: 0.0343
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 343.91, MAE: 264.55
#
# Fold 13/95
#   Epoch 10/50, Loss: 0.0441
#   Epoch 20/50, Loss: 0.0394
#   Epoch 30/50, Loss: 0.0367
#   Epoch 40/50, Loss: 0.0356
#   Epoch 50/50, Loss: 0.0317
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 350.05, MAE: 259.38
#
# Fold 14/95
#   Epoch 10/50, Loss: 0.0472
#   Epoch 20/50, Loss: 0.0372
#   Epoch 30/50, Loss: 0.0349
#   Epoch 40/50, Loss: 0.0317
#   Epoch 50/50, Loss: 0.0272
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 1158.78, MAE: 1070.24
#
# Fold 15/95
#   Epoch 10/50, Loss: 0.0394
#   Epoch 20/50, Loss: 0.0353
#   Epoch 30/50, Loss: 0.0315
#   Epoch 40/50, Loss: 0.0276
#   Epoch 50/50, Loss: 0.0244
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 493.83, MAE: 379.08
#
# Fold 16/95
#   Epoch 10/50, Loss: 0.0342
#   Epoch 20/50, Loss: 0.0302
#   Epoch 30/50, Loss: 0.0273
#   Epoch 40/50, Loss: 0.0229
#   Epoch 50/50, Loss: 0.0217
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 271.65, MAE: 214.64
#
# Fold 17/95
#   Epoch 10/50, Loss: 0.0321
#   Epoch 20/50, Loss: 0.0291
#   Epoch 30/50, Loss: 0.0265
#   Epoch 40/50, Loss: 0.0239
#   Epoch 50/50, Loss: 0.0205
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 443.35, MAE: 322.68
#
# Fold 18/95
#   Epoch 10/50, Loss: 0.0321
#   Epoch 20/50, Loss: 0.0282
#   Epoch 30/50, Loss: 0.0253
#   Epoch 40/50, Loss: 0.0227
#   Epoch 50/50, Loss: 0.0205
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 312.72, MAE: 217.85
#
# Fold 19/95
#   Epoch 10/50, Loss: 0.0320
#   Epoch 20/50, Loss: 0.0281
#   Epoch 30/50, Loss: 0.0258
#   Epoch 40/50, Loss: 0.0228
#   Epoch 50/50, Loss: 0.0205
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 365.68, MAE: 268.37
#
# Fold 20/95
#   Epoch 10/50, Loss: 0.0309
#   Epoch 20/50, Loss: 0.0259
#   Epoch 30/50, Loss: 0.0222
#   Epoch 40/50, Loss: 0.0198
#   Epoch 50/50, Loss: 0.0187
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 300.84, MAE: 254.96
#
# Fold 21/95
#   Epoch 10/50, Loss: 0.0285
#   Epoch 20/50, Loss: 0.0234
#   Epoch 30/50, Loss: 0.0215
#   Epoch 40/50, Loss: 0.0198
#   Epoch 50/50, Loss: 0.0193
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 301.53, MAE: 232.28
#
# Fold 22/95
#   Epoch 10/50, Loss: 0.0272
#   Epoch 20/50, Loss: 0.0237
#   Epoch 30/50, Loss: 0.0209
#   Epoch 40/50, Loss: 0.0185
#   Epoch 50/50, Loss: 0.0173
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 306.23, MAE: 242.81
#
# Fold 23/95
#   Epoch 10/50, Loss: 0.0253
#   Epoch 20/50, Loss: 0.0213
#   Epoch 30/50, Loss: 0.0212
#   Epoch 40/50, Loss: 0.0188
#   Epoch 50/50, Loss: 0.0169
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 506.79, MAE: 418.18
#
# Fold 24/95
#   Epoch 10/50, Loss: 0.0239
#   Epoch 20/50, Loss: 0.0178
#   Epoch 30/50, Loss: 0.0158
#   Epoch 40/50, Loss: 0.0157
#   Epoch 50/50, Loss: 0.0141
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 244.23, MAE: 185.27
#
# Fold 25/95
#   Epoch 10/50, Loss: 0.0223
#   Epoch 20/50, Loss: 0.0174
#   Epoch 30/50, Loss: 0.0152
#   Epoch 40/50, Loss: 0.0133
#   Epoch 50/50, Loss: 0.0126
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 265.11, MAE: 174.34
#
# Fold 26/95
#   Epoch 10/50, Loss: 0.0232
#   Epoch 20/50, Loss: 0.0171
#   Epoch 30/50, Loss: 0.0146
#   Epoch 40/50, Loss: 0.0131
#   Epoch 50/50, Loss: 0.0119
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 269.38, MAE: 185.30
#
# Fold 27/95
#   Epoch 10/50, Loss: 0.0227
#   Epoch 20/50, Loss: 0.0148
#   Epoch 30/50, Loss: 0.0135
#   Epoch 40/50, Loss: 0.0126
#   Epoch 50/50, Loss: 0.0117
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 294.79, MAE: 228.56
#
# Fold 28/95
#   Epoch 10/50, Loss: 0.0237
#   Epoch 20/50, Loss: 0.0164
#   Epoch 30/50, Loss: 0.0145
#   Epoch 40/50, Loss: 0.0135
#   Epoch 50/50, Loss: 0.0121
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 502.51, MAE: 368.77
#
# Fold 29/95
#   Epoch 10/50, Loss: 0.0232
#   Epoch 20/50, Loss: 0.0181
#   Epoch 30/50, Loss: 0.0146
#   Epoch 40/50, Loss: 0.0127
#   Epoch 50/50, Loss: 0.0115
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 266.01, MAE: 206.29
#
# Fold 30/95
#   Epoch 10/50, Loss: 0.0238
#   Epoch 20/50, Loss: 0.0186
#   Epoch 30/50, Loss: 0.0162
#   Epoch 40/50, Loss: 0.0143
#   Epoch 50/50, Loss: 0.0126
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 441.18, MAE: 328.82
#
# Fold 31/95
#   Epoch 10/50, Loss: 0.0249
#   Epoch 20/50, Loss: 0.0198
#   Epoch 30/50, Loss: 0.0158
#   Epoch 40/50, Loss: 0.0144
#   Epoch 50/50, Loss: 0.0133
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 261.63, MAE: 195.24
#
# Fold 32/95
#   Epoch 10/50, Loss: 0.0278
#   Epoch 20/50, Loss: 0.0210
#   Epoch 30/50, Loss: 0.0191
#   Epoch 40/50, Loss: 0.0164
#   Epoch 50/50, Loss: 0.0163
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 318.78, MAE: 259.34
#
# Fold 33/95
#   Epoch 10/50, Loss: 0.0363
#   Epoch 20/50, Loss: 0.0297
#   Epoch 30/50, Loss: 0.0274
#   Epoch 40/50, Loss: 0.0246
#   Epoch 50/50, Loss: 0.0232
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 674.42, MAE: 542.99
#
# Fold 34/95
#   Epoch 10/50, Loss: 0.0375
#   Epoch 20/50, Loss: 0.0342
#   Epoch 30/50, Loss: 0.0301
#   Epoch 40/50, Loss: 0.0277
#   Epoch 50/50, Loss: 0.0269
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 328.43, MAE: 247.06
#
# Fold 35/95
#   Epoch 10/50, Loss: 0.0469
#   Epoch 20/50, Loss: 0.0415
#   Epoch 30/50, Loss: 0.0378
#   Epoch 40/50, Loss: 0.0336
#   Epoch 50/50, Loss: 0.0306
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 562.29, MAE: 459.98
#
# Fold 36/95
#   Epoch 10/50, Loss: 0.0508
#   Epoch 20/50, Loss: 0.0435
#   Epoch 30/50, Loss: 0.0403
#   Epoch 40/50, Loss: 0.0382
#   Epoch 50/50, Loss: 0.0376
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 612.57, MAE: 452.44
#
# Fold 37/95
#   Epoch 10/50, Loss: 0.0559
#   Epoch 20/50, Loss: 0.0492
#   Epoch 30/50, Loss: 0.0442
#   Epoch 40/50, Loss: 0.0409
#   Epoch 50/50, Loss: 0.0358
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 522.46, MAE: 382.81
#
# Fold 38/95
#   Epoch 10/50, Loss: 0.0629
#   Epoch 20/50, Loss: 0.0551
#   Epoch 30/50, Loss: 0.0504
#   Epoch 40/50, Loss: 0.0483
#   Epoch 50/50, Loss: 0.0444
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 429.89, MAE: 365.63
#
# Fold 39/95
#   Epoch 10/50, Loss: 0.0633
#   Epoch 20/50, Loss: 0.0525
#   Epoch 30/50, Loss: 0.0481
#   Epoch 40/50, Loss: 0.0433
#   Epoch 50/50, Loss: 0.0414
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 662.80, MAE: 549.40
#
# Fold 40/95
#   Epoch 10/50, Loss: 0.0647
#   Epoch 20/50, Loss: 0.0540
#   Epoch 30/50, Loss: 0.0507
#   Epoch 40/50, Loss: 0.0482
#   Epoch 50/50, Loss: 0.0467
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 474.75, MAE: 369.92
#
# Fold 41/95
#   Epoch 10/50, Loss: 0.0662
#   Epoch 20/50, Loss: 0.0592
#   Epoch 30/50, Loss: 0.0515
#   Epoch 40/50, Loss: 0.0475
#   Epoch 50/50, Loss: 0.0455
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 300.91, MAE: 224.22
#
# Fold 42/95
#   Epoch 10/50, Loss: 0.0642
#   Epoch 20/50, Loss: 0.0539
#   Epoch 30/50, Loss: 0.0500
#   Epoch 40/50, Loss: 0.0462
#   Epoch 50/50, Loss: 0.0428
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 247.47, MAE: 196.38
#
# Fold 43/95
#   Epoch 10/50, Loss: 0.0636
#   Epoch 20/50, Loss: 0.0531
#   Epoch 30/50, Loss: 0.0465
#   Epoch 40/50, Loss: 0.0406
#   Epoch 50/50, Loss: 0.0386
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 340.55, MAE: 281.03
#
# Fold 44/95
#   Epoch 10/50, Loss: 0.0658
#   Epoch 20/50, Loss: 0.0544
#   Epoch 30/50, Loss: 0.0475
#   Epoch 40/50, Loss: 0.0410
#   Epoch 50/50, Loss: 0.0370
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 395.47, MAE: 330.37
#
# Fold 45/95
#   Epoch 10/50, Loss: 0.0730
#   Epoch 20/50, Loss: 0.0589
#   Epoch 30/50, Loss: 0.0506
#   Epoch 40/50, Loss: 0.0483
#   Epoch 50/50, Loss: 0.0446
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 312.97, MAE: 262.40
#
# Fold 46/95
#   Epoch 10/50, Loss: 0.0641
#   Epoch 20/50, Loss: 0.0577
#   Epoch 30/50, Loss: 0.0532
#   Epoch 40/50, Loss: 0.0462
#   Epoch 50/50, Loss: 0.0435
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 396.97, MAE: 306.08
#
# Fold 47/95
#   Epoch 10/50, Loss: 0.0707
#   Epoch 20/50, Loss: 0.0598
#   Epoch 30/50, Loss: 0.0534
#   Epoch 40/50, Loss: 0.0483
#   Epoch 50/50, Loss: 0.0423
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 497.03, MAE: 399.09
#
# Fold 48/95
#   Epoch 10/50, Loss: 0.0701
#   Epoch 20/50, Loss: 0.0599
#   Epoch 30/50, Loss: 0.0546
#   Epoch 40/50, Loss: 0.0500
#   Epoch 50/50, Loss: 0.0427
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 387.55, MAE: 294.84
#
# Fold 49/95
#   Epoch 10/50, Loss: 0.0919
#   Epoch 20/50, Loss: 0.0745
#   Epoch 30/50, Loss: 0.0652
#   Epoch 40/50, Loss: 0.0549
#   Epoch 50/50, Loss: 0.0460
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 463.66, MAE: 370.52
#
# Fold 50/95
#   Epoch 10/50, Loss: 0.1006
#   Epoch 20/50, Loss: 0.0826
#   Epoch 30/50, Loss: 0.0669
#   Epoch 40/50, Loss: 0.0589
#   Epoch 50/50, Loss: 0.0546
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 605.14, MAE: 494.02
#
# Fold 51/95
#   Epoch 10/50, Loss: 0.1083
#   Epoch 20/50, Loss: 0.0889
#   Epoch 30/50, Loss: 0.0796
#   Epoch 40/50, Loss: 0.0687
#   Epoch 50/50, Loss: 0.0660
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 505.79, MAE: 399.48
#
# Fold 52/95
#   Epoch 10/50, Loss: 0.1137
#   Epoch 20/50, Loss: 0.0973
#   Epoch 30/50, Loss: 0.0893
#   Epoch 40/50, Loss: 0.0782
#   Epoch 50/50, Loss: 0.0667
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 389.14, MAE: 322.09
#
# Fold 53/95
#   Epoch 10/50, Loss: 0.1205
#   Epoch 20/50, Loss: 0.1057
#   Epoch 30/50, Loss: 0.0938
#   Epoch 40/50, Loss: 0.0878
#   Epoch 50/50, Loss: 0.0709
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 259.13, MAE: 190.16
#
# Fold 54/95
#   Epoch 10/50, Loss: 0.1313
#   Epoch 20/50, Loss: 0.1134
#   Epoch 30/50, Loss: 0.1029
#   Epoch 40/50, Loss: 0.0893
#   Epoch 50/50, Loss: 0.0815
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 468.20, MAE: 383.15
#
# Fold 55/95
#   Epoch 10/50, Loss: 0.1299
#   Epoch 20/50, Loss: 0.1158
#   Epoch 30/50, Loss: 0.1063
#   Epoch 40/50, Loss: 0.0956
#   Epoch 50/50, Loss: 0.0826
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 545.98, MAE: 477.12
#
# Fold 56/95
#   Epoch 10/50, Loss: 0.1254
#   Epoch 20/50, Loss: 0.1111
#   Epoch 30/50, Loss: 0.1009
#   Epoch 40/50, Loss: 0.0899
#   Epoch 50/50, Loss: 0.0826
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 980.12, MAE: 867.41
#
# Fold 57/95
#   Epoch 10/50, Loss: 0.1400
#   Epoch 20/50, Loss: 0.1275
#   Epoch 30/50, Loss: 0.1138
#   Epoch 40/50, Loss: 0.1007
#   Epoch 50/50, Loss: 0.0897
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 543.02, MAE: 470.81
#
# Fold 58/95
#   Epoch 10/50, Loss: 0.1320
#   Epoch 20/50, Loss: 0.1237
#   Epoch 30/50, Loss: 0.1100
#   Epoch 40/50, Loss: 0.0954
#   Epoch 50/50, Loss: 0.0804
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 449.83, MAE: 385.75
#
# Fold 59/95
#   Epoch 10/50, Loss: 0.1214
#   Epoch 20/50, Loss: 0.1130
#   Epoch 30/50, Loss: 0.0996
#   Epoch 40/50, Loss: 0.0946
#   Epoch 50/50, Loss: 0.0864
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 370.92, MAE: 310.03
#
# Fold 60/95
#   Epoch 10/50, Loss: 0.1173
#   Epoch 20/50, Loss: 0.1015
#   Epoch 30/50, Loss: 0.0941
#   Epoch 40/50, Loss: 0.0922
#   Epoch 50/50, Loss: 0.0847
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 420.93, MAE: 347.98
#
# Fold 61/95
#   Epoch 10/50, Loss: 0.1078
#   Epoch 20/50, Loss: 0.0936
#   Epoch 30/50, Loss: 0.0927
#   Epoch 40/50, Loss: 0.0862
#   Epoch 50/50, Loss: 0.0788
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 610.27, MAE: 469.44
#
# Fold 62/95
#   Epoch 10/50, Loss: 0.0949
#   Epoch 20/50, Loss: 0.0882
#   Epoch 30/50, Loss: 0.0881
#   Epoch 40/50, Loss: 0.0799
#   Epoch 50/50, Loss: 0.0711
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 410.09, MAE: 284.33
#
# Fold 63/95
#   Epoch 10/50, Loss: 0.1071
#   Epoch 20/50, Loss: 0.0914
#   Epoch 30/50, Loss: 0.0882
#   Epoch 40/50, Loss: 0.0826
#   Epoch 50/50, Loss: 0.0778
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 514.22, MAE: 381.68
#
# Fold 64/95
#   Epoch 10/50, Loss: 0.0977
#   Epoch 20/50, Loss: 0.0875
#   Epoch 30/50, Loss: 0.0796
#   Epoch 40/50, Loss: 0.0742
#   Epoch 50/50, Loss: 0.0696
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 299.46, MAE: 265.86
#
# Fold 65/95
#   Epoch 10/50, Loss: 0.0912
#   Epoch 20/50, Loss: 0.0812
#   Epoch 30/50, Loss: 0.0778
#   Epoch 40/50, Loss: 0.0726
#   Epoch 50/50, Loss: 0.0709
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 205.18, MAE: 169.28
#
# Fold 66/95
#   Epoch 10/50, Loss: 0.0793
#   Epoch 20/50, Loss: 0.0743
#   Epoch 30/50, Loss: 0.0701
#   Epoch 40/50, Loss: 0.0643
#   Epoch 50/50, Loss: 0.0596
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 374.01, MAE: 274.58
#
# Fold 67/95
#   Epoch 10/50, Loss: 0.0725
#   Epoch 20/50, Loss: 0.0662
#   Epoch 30/50, Loss: 0.0619
#   Epoch 40/50, Loss: 0.0585
#   Epoch 50/50, Loss: 0.0540
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 631.57, MAE: 461.39
#
# Fold 68/95
#   Epoch 10/50, Loss: 0.0642
#   Epoch 20/50, Loss: 0.0584
#   Epoch 30/50, Loss: 0.0532
#   Epoch 40/50, Loss: 0.0495
#   Epoch 50/50, Loss: 0.0439
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 450.95, MAE: 329.06
#
# Fold 69/95
#   Epoch 10/50, Loss: 0.0588
#   Epoch 20/50, Loss: 0.0532
#   Epoch 30/50, Loss: 0.0494
#   Epoch 40/50, Loss: 0.0454
#   Epoch 50/50, Loss: 0.0396
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 207.54, MAE: 164.57
#
# Fold 70/95
#   Epoch 10/50, Loss: 0.0584
#   Epoch 20/50, Loss: 0.0499
#   Epoch 30/50, Loss: 0.0464
#   Epoch 40/50, Loss: 0.0416
#   Epoch 50/50, Loss: 0.0380
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 245.24, MAE: 197.44
#
# Fold 71/95
#   Epoch 10/50, Loss: 0.0437
#   Epoch 20/50, Loss: 0.0406
#   Epoch 30/50, Loss: 0.0367
#   Epoch 40/50, Loss: 0.0353
#   Epoch 50/50, Loss: 0.0353
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 388.60, MAE: 315.60
#
# Fold 72/95
#   Epoch 10/50, Loss: 0.0311
#   Epoch 20/50, Loss: 0.0280
#   Epoch 30/50, Loss: 0.0263
#   Epoch 40/50, Loss: 0.0256
#   Epoch 50/50, Loss: 0.0223
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 598.71, MAE: 484.10
#
# Fold 73/95
#   Epoch 10/50, Loss: 0.0290
#   Epoch 20/50, Loss: 0.0234
#   Epoch 30/50, Loss: 0.0212
#   Epoch 40/50, Loss: 0.0192
#   Epoch 50/50, Loss: 0.0186
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 496.04, MAE: 460.76
#
# Fold 74/95
#   Epoch 10/50, Loss: 0.0238
#   Epoch 20/50, Loss: 0.0203
#   Epoch 30/50, Loss: 0.0175
#   Epoch 40/50, Loss: 0.0167
#   Epoch 50/50, Loss: 0.0150
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 153.30, MAE: 112.68
#
# Fold 75/95
#   Epoch 10/50, Loss: 0.0231
#   Epoch 20/50, Loss: 0.0188
#   Epoch 30/50, Loss: 0.0173
#   Epoch 40/50, Loss: 0.0158
#   Epoch 50/50, Loss: 0.0136
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 549.81, MAE: 373.14
#
# Fold 76/95
#   Epoch 10/50, Loss: 0.0227
#   Epoch 20/50, Loss: 0.0197
#   Epoch 30/50, Loss: 0.0179
#   Epoch 40/50, Loss: 0.0156
#   Epoch 50/50, Loss: 0.0133
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 379.27, MAE: 297.37
#
# Fold 77/95
#   Epoch 10/50, Loss: 0.0243
#   Epoch 20/50, Loss: 0.0198
#   Epoch 30/50, Loss: 0.0182
#   Epoch 40/50, Loss: 0.0157
#   Epoch 50/50, Loss: 0.0145
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 284.36, MAE: 207.20
#
# Fold 78/95
#   Epoch 10/50, Loss: 0.0281
#   Epoch 20/50, Loss: 0.0207
#   Epoch 30/50, Loss: 0.0199
#   Epoch 40/50, Loss: 0.0194
#   Epoch 50/50, Loss: 0.0185
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 230.56, MAE: 180.84
#
# Fold 79/95
#   Epoch 10/50, Loss: 0.0254
#   Epoch 20/50, Loss: 0.0199
#   Epoch 30/50, Loss: 0.0180
#   Epoch 40/50, Loss: 0.0157
#   Epoch 50/50, Loss: 0.0136
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 465.89, MAE: 335.99
#
# Fold 80/95
#   Epoch 10/50, Loss: 0.0238
#   Epoch 20/50, Loss: 0.0185
#   Epoch 30/50, Loss: 0.0164
#   Epoch 40/50, Loss: 0.0142
#   Epoch 50/50, Loss: 0.0137
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 443.26, MAE: 338.70
#
# Fold 81/95
#   Epoch 10/50, Loss: 0.0231
#   Epoch 20/50, Loss: 0.0193
#   Epoch 30/50, Loss: 0.0177
#   Epoch 40/50, Loss: 0.0162
#   Epoch 50/50, Loss: 0.0149
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 491.90, MAE: 401.39
#
# Fold 82/95
#   Epoch 10/50, Loss: 0.0271
#   Epoch 20/50, Loss: 0.0239
#   Epoch 30/50, Loss: 0.0216
#   Epoch 40/50, Loss: 0.0187
#   Epoch 50/50, Loss: 0.0167
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 666.47, MAE: 548.30
#
# Fold 83/95
#   Epoch 10/50, Loss: 0.0295
#   Epoch 20/50, Loss: 0.0232
#   Epoch 30/50, Loss: 0.0212
#   Epoch 40/50, Loss: 0.0189
#   Epoch 50/50, Loss: 0.0186
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 639.01, MAE: 534.53
#
# Fold 84/95
#   Epoch 10/50, Loss: 0.0391
#   Epoch 20/50, Loss: 0.0274
#   Epoch 30/50, Loss: 0.0239
#   Epoch 40/50, Loss: 0.0227
#   Epoch 50/50, Loss: 0.0212
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 335.50, MAE: 274.69
#
# Fold 85/95
#   Epoch 10/50, Loss: 0.0371
#   Epoch 20/50, Loss: 0.0296
#   Epoch 30/50, Loss: 0.0263
#   Epoch 40/50, Loss: 0.0246
#   Epoch 50/50, Loss: 0.0223
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 301.51, MAE: 239.18
#
# Fold 86/95
#   Epoch 10/50, Loss: 0.0358
#   Epoch 20/50, Loss: 0.0302
#   Epoch 30/50, Loss: 0.0273
#   Epoch 40/50, Loss: 0.0256
#   Epoch 50/50, Loss: 0.0237
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 704.20, MAE: 587.20
#
# Fold 87/95
#   Epoch 10/50, Loss: 0.0364
#   Epoch 20/50, Loss: 0.0313
#   Epoch 30/50, Loss: 0.0289
#   Epoch 40/50, Loss: 0.0270
#   Epoch 50/50, Loss: 0.0260
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 804.08, MAE: 674.98
#
# Fold 88/95
#   Epoch 10/50, Loss: 0.0407
#   Epoch 20/50, Loss: 0.0373
#   Epoch 30/50, Loss: 0.0346
#   Epoch 40/50, Loss: 0.0328
#   Epoch 50/50, Loss: 0.0319
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 336.33, MAE: 279.96
#
# Fold 89/95
#   Epoch 10/50, Loss: 0.0472
#   Epoch 20/50, Loss: 0.0439
#   Epoch 30/50, Loss: 0.0404
#   Epoch 40/50, Loss: 0.0375
#   Epoch 50/50, Loss: 0.0337
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 333.79, MAE: 252.79
#
# Fold 90/95
#   Epoch 10/50, Loss: 0.0519
#   Epoch 20/50, Loss: 0.0481
#   Epoch 30/50, Loss: 0.0461
#   Epoch 40/50, Loss: 0.0440
#   Epoch 50/50, Loss: 0.0401
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 326.01, MAE: 236.74
#
# Fold 91/95
#   Epoch 10/50, Loss: 0.0592
#   Epoch 20/50, Loss: 0.0540
#   Epoch 30/50, Loss: 0.0503
#   Epoch 40/50, Loss: 0.0488
#   Epoch 50/50, Loss: 0.0458
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 494.25, MAE: 426.86
#
# Fold 92/95
#   Epoch 10/50, Loss: 0.0581
#   Epoch 20/50, Loss: 0.0538
#   Epoch 30/50, Loss: 0.0478
#   Epoch 40/50, Loss: 0.0446
#   Epoch 50/50, Loss: 0.0434
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 1181.84, MAE: 1098.22
#
# Fold 93/95
#   Epoch 10/50, Loss: 0.0617
#   Epoch 20/50, Loss: 0.0576
#   Epoch 30/50, Loss: 0.0525
#   Epoch 40/50, Loss: 0.0452
#   Epoch 50/50, Loss: 0.0410
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 288.33, MAE: 209.13
#
# Fold 94/95
#   Epoch 10/50, Loss: 0.0764
#   Epoch 20/50, Loss: 0.0634
#   Epoch 30/50, Loss: 0.0535
#   Epoch 40/50, Loss: 0.0465
#   Epoch 50/50, Loss: 0.0402
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 811.38, MAE: 680.30
#
# Fold 95/95
#   Epoch 10/50, Loss: 0.0821
#   Epoch 20/50, Loss: 0.0664
#   Epoch 30/50, Loss: 0.0602
#   Epoch 40/50, Loss: 0.0514
#   Epoch 50/50, Loss: 0.0414
#   Predictions shape: (168,)
#   Actuals shape: (168,)
#   Fold RMSE: 320.33, MAE: 273.52
#
# Overall RMSE: 482.50
# Overall MAE: 358.57
# Average Fold RMSE: 445.85 (+/- 184.45)
